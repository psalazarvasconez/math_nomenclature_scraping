# %%
import pandas as pd
import requests
import re
import os

from bs4 import BeautifulSoup

import selenium
from selenium.webdriver.chrome.service import Service
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from selenium.webdriver.common.action_chains import ActionChains

# %%
url = 'https://en.wikipedia.org/wiki/Fundamental_theorem_of_calculus'
page = requests.get(url)
page.status_code
# Out:
# 200

# %%
soup = BeautifulSoup(page.content, 'html.parser') 

# Find all the links within the list items ('li') in the sidebar
list_items = soup.select('.sidebar-content-with-subgroup li')

# Loop through the list items and format the links
formatted_links = []
for item in list_items:
    link = item.find('a')
    if link:
        link_url = link.get('href')
        formatted_link = f"https://en.wikipedia.org{link_url}"
        formatted_links.append(formatted_link)

# Print the formatted links
for link in formatted_links:
    print(link)

# %%
soup = BeautifulSoup(page.content, 'html.parser') 

# Find all the links within the list items ('li') in the sidebar
list_items = soup.select('.sidebar-content-with-subgroup li')

# Loop through the list items and format the links
formatted_links = []
titles = []
for item in list_items:
    link = item.find('a')
    if link:
        link_url = link.get('href')
        formatted_link = f"https://en.wikipedia.org{link_url}"
        response = requests.get(formatted_link)
        page_content = response.content
    
    # Parse the HTML content using BeautifulSoup
    soup = BeautifulSoup(page_content, 'html.parser')
    
    # Find the title of the page
    title_element = soup.find('title')
    if title_element:
        title = title_element.get_text().split('-')[0].strip()
        titles.append(title)

# Print the extracted titles
for title in titles:
    print(title)
# Out:
# Derivative
# Differential (mathematics)
# Differential (mathematics)
# Differential of a function
# Differential of a function
# Notation for differentiation
# Second derivative
# Implicit function
# Logarithmic differentiation
# Related rates
# Taylor's theorem
# Differentiation rules
# Product rule
# Chain rule
# Power rule
# Quotient rule
# L'Hôpital's rule
# Inverse function rule
# General Leibniz rule
# Faà di Bruno's formula
# Reynolds transport theorem
# Lists of integrals
# Integral transform
# Leibniz integral rule
# Antiderivative
# Integral
# Riemann integral
# Lebesgue integration
# Contour integration
# Integral of inverse functions
# Integration by parts
# Disc integration
# Shell integration
# Integration by substitution
# Integration using Euler's formula
# Partial fraction decomposition
# Order of integration (calculus)
# Integration by reduction formulae
# Leibniz integral rule
# Risch algorithm
# Geometric series
# Harmonic series (mathematics)
# Alternating series
# Power series
# Binomial series
# Taylor series
# nth
# Ratio test
# Root test
# Integral test for convergence
# Direct comparison test
# Limit comparison test
# Alternating series test
# Cauchy condensation test
# Dirichlet's test
# Abel's test
# Gradient
# Divergence
# Curl (mathematics)
# Laplace operator
# Directional derivative
# Vector calculus identities
# Gradient theorem
# Green's theorem
# Stokes' theorem
# Divergence theorem
# Generalized Stokes theorem
# Matrix calculus
# Tensor calculus
# Exterior derivative
# Geometric calculus
# Partial derivative
# Multiple integral
# Line integral
# Surface integral
# Volume integral
# Jacobian matrix and determinant
# Hessian matrix
# Calculus on Euclidean space
# Generalized function
# Limit of distributions

# %%
url = 'https://en.wikipedia.org/wiki/Limit_(mathematics)'
page = requests.get(url)
page.status_code
# Out:
# 200

# %%
import requests
from bs4 import BeautifulSoup

# URL of the Wikipedia page
url = "https://en.wikipedia.org/wiki/Limit_(mathematics)"

# Send a GET request to the URL
response = requests.get(url)

# Parse the HTML content using BeautifulSoup
soup = BeautifulSoup(response.content, 'html.parser')

# Find the interlanguage links
interlanguage_links = soup.find_all("li", class_="interlanguage-link")

# Extract and print the language and correct title of each interlanguage link
for link in interlanguage_links:
    lang = link.find("a")['lang']
    title = link.find("a")['title'].split(" – ")[0]  # Extracting only the title part
    print(f"Language: {lang}, Title: {title}")
# Out:
# Language: af, Title: Limiet
# Language: am, Title: ጥግ
# Language: ar, Title: نهاية (رياضيات)
# Language: ast, Title: Llende matemática
# Language: az, Title: Limit (riyaziyyat)
# Language: bn, Title: সীমা (গণিত)
# Language: ba, Title: Сикләмә (математика)
# Language: be, Title: Ліміт (матэматыка)
# Language: bh, Title: सीमा (गणित)
# Language: bg, Title: Граница (математика)
# Language: bs, Title: Limes (matematika)
# Language: ca, Title: Límit
# Language: cv, Title: Чикĕ (математика)
# Language: cs, Title: Limita
# Language: cy, Title: Terfan (mathemateg)
# Language: da, Title: Grænseværdi (matematik)
# Language: el, Title: Όριο (μαθηματικά)
# Language: es, Title: Límite (matemática)
# Language: eo, Title: Limeso
# Language: eu, Title: Limite
# Language: fa, Title: حد (ریاضی)
# Language: fr, Title: Limite (mathématiques)
# Language: ga, Title: Teorainn (matamaitic)
# Language: gl, Title: Límite matemático
# Language: gan, Title: 極限
# Language: hak, Title: Khi̍t-han (Sú-ho̍k)
# Language: ko, Title: 극한
# Language: hy, Title: Սահման (մաթեմատիկա)
# Language: hi, Title: सीमा (गणित)
# Language: hr, Title: Limes (matematika)
# Language: io, Title: Limito
# Language: id, Title: Limit (matematika)
# Language: is, Title: Markgildi
# Language: it, Title: Limite (matematica)
# Language: he, Title: גבול (מתמטיקה)
# Language: kk, Title: Шек
# Language: gcr, Title: Limit (matématik)
# Language: la, Title: Limes (mathematica)
# Language: lv, Title: Robeža (matemātika)
# Language: lt, Title: Riba (matematika)
# Language: lmo, Title: Limit (matematega)
# Language: hu, Title: Határérték
# Language: mk, Title: Гранична вредност
# Language: mr, Title: सीमा (गणित)
# Language: ms, Title: Had (matematik)
# Language: nl, Title: Limiet
# Language: ja, Title: 極限
# Language: nb, Title: Grenseverdi
# Language: nn, Title: Grense i matematikk
# Language: uz, Title: Limit
# Language: jam, Title: Limit (matimatix)
# Language: km, Title: លីមីត
# Language: pl, Title: Granica (matematyka)
# Language: pt, Title: Limite
# Language: ro, Title: Limită (matematică)
# Language: ru, Title: Предел (математика)
# Language: sq, Title: Limiti
# Language: scn, Title: Lìmiti
# Language: en-simple, Title: Limit (mathematics)
# Language: sk, Title: Limita
# Language: ckb, Title: ڕادە (ماتماتیک)
# Language: sr, Title: Гранична вредност
# Language: sh, Title: Limes (matematika)
# Language: fi, Title: Raja-arvo
# Language: sv, Title: Gränsvärde
# Language: ta, Title: எல்லை (கணிதம்)
# Language: tr, Title: Limit
# Language: uk, Title: Границя
# Language: ur, Title: حد (ریاضی)
# Language: vec, Title: Limite
# Language: vi, Title: Giới hạn (toán học)
# Language: vls, Title: Limiet
# Language: wuu, Title: 极限（数学）
# Language: yue, Title: 極限 (數學)
# Language: diq, Title: Limit
# Language: zh, Title: 极限 (数学)

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# List of links to scrape
links = [
    "https://en.wikipedia.org/wiki/Derivative",
    "https://en.wikipedia.org/wiki/Differential_(mathematics)",
    "https://en.wikipedia.org/wiki/Differential_(infinitesimal)",
    "https://en.wikipedia.org/wiki/Differential_of_a_function",
    "https://en.wikipedia.org/wiki/Differential_of_a_function,#Differentials_in_several_variables",
    "https://en.wikipedia.org/wiki/Notation_for_differentiation",
    "https://en.wikipedia.org/wiki/Second_derivative",
    "https://en.wikipedia.org/wiki/Implicit_function",
    "https://en.wikipedia.org/wiki/Logarithmic_differentiation"
]

# Initialize lists to store data
titles = []
languages = []

# Loop through the links
for link in links:
    response = requests.get(link)
    page_content = response.content
    
    # Parse the HTML content using BeautifulSoup
    link_soup = BeautifulSoup(page_content, 'html.parser')
    
    # Find the title of the page
    title_element = link_soup.find('title')
    if title_element:
        title = title_element.get_text().split('-')[0].strip()
        titles.append(title)
    else:
        titles.append(None)
        
    # Find the language of the page using the 'lang' attribute
    lang_attribute = link_soup.find('html')['lang']
    if lang_attribute:
        languages.append(lang_attribute)
    else:
        languages.append(None)

# Create a pandas DataFrame
data = {
    "Language": languages,
    "Title": titles
}

df = pd.DataFrame(data)

# Print the DataFrame
print(df)
# Out:
#   Language                         Title
# 0       en                    Derivative
# 1       en    Differential (mathematics)
# 2       en    Differential (mathematics)
# 3       en    Differential of a function
# 4       en   Differential of a function,
# 5       en  Notation for differentiation
# 6       en             Second derivative
# 7       en             Implicit function
# 8       en   Logarithmic differentiation

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# List of Wikipedia page URLs
links = [
    "https://en.wikipedia.org/wiki/Limit_(mathematics)",
    "https://en.wikipedia.org/wiki/Derivative",
    # Add more links here
]

# Loop through the list of links
for link in links:
    response = requests.get(link)
    soup = BeautifulSoup(response.content, 'html.parser')
    
    # Find the interlanguage links
    interlanguage_links = soup.find_all("li", class_="interlanguage-link")
    
    # Initialize lists to store data for this link
    languages = []
    titles = []
    
    # Extract and store the language and correct title of each interlanguage link
    for interlanguage_link in interlanguage_links:
        lang = interlanguage_link.find("a")['lang']
        title = interlanguage_link.find("a")['title'].split(" – ")[0]
        languages.append(lang)
        titles.append(title)
    
    # Create a pandas DataFrame for this link
    data = {
        "Language": languages,
        "Title": titles
    }
    df = pd.DataFrame(data)
    
    # Print the DataFrame for this link
    print(f"DataFrame for {link}:\n{df}\n")
# Out:
# DataFrame for https://en.wikipedia.org/wiki/Limit_(mathematics):
#    Language               Title
# 0        af              Limiet
# 1        am                  ጥግ
# 2        ar     نهاية (رياضيات)
# 3       ast   Llende matemática
# 4        az  Limit (riyaziyyat)
# ..      ...                 ...
# 71      vls              Limiet
# 72      wuu              极限（数学）
# 73      yue             極限 (數學)
# 74      diq               Limit
# 75       zh             极限 (数学)
#
# [76 rows x 2 columns]
#
# DataFrame for https://en.wikipedia.org/wiki/Derivative:
#    Language           Title
# 0        af       Afgeleide
# 1        am            ውድድር
# 2        ar  مشتق (رياضيات)
# 3        an        Derivada
# 4       ast        Derivada
# ..      ...             ...
# 82      lzh              導數
# 83      wuu              導數
# 84       yi     דעריוואטיוו
# 85      yue              導數
# 86       zh              导数
#
# [87 rows x 2 columns]

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import os

# Create a directory to store the CSV files
if not os.path.exists("dataframes"):
    os.makedirs("dataframes")

# List of Wikipedia page URLs
links = [
    "https://en.wikipedia.org/wiki/Limit_(mathematics)",
    "https://en.wikipedia.org/wiki/Derivative",
    # Add more links here
]

# Loop through the list of links
for link in links:
    response = requests.get(link)
    soup = BeautifulSoup(response.content, 'html.parser')
    
    # Find the interlanguage links
    interlanguage_links = soup.find_all("li", class_="interlanguage-link")
    
    # Initialize lists to store data for this link
    languages = []
    titles = []
    
    # Extract and store the language and correct title of each interlanguage link
    for interlanguage_link in interlanguage_links:
        lang = interlanguage_link.find("a")['lang']
        title = interlanguage_link.find("a")['title'].split(" – ")[0]
        languages.append(lang)
        titles.append(title)
    
    # Create a pandas DataFrame for this link
    data = {
        "Language": languages,
        "Title": titles
    }
    df = pd.DataFrame(data)
    
    # Create a CSV file name based on the link title
    csv_file_name = f"dataframes/{link.split('/')[-1]}.csv"
    
    # Save the DataFrame as a CSV file
    df.to_csv(csv_file_name, index=False)
    
    print(f"CSV saved: {csv_file_name}")
# Out:
# CSV saved: dataframes/Limit_(mathematics).csv
# CSV saved: dataframes/Derivative.csv

# %%
url = 'https://en.wikipedia.org/wiki/Fundamental_theorem_of_calculus'
page = requests.get(url)
page.status_code
# Out:
# 200

# %%
soup = BeautifulSoup(page.content, 'html.parser') 

# Find all the links within the list items ('li') in the sidebar
list_items = soup.select('.sidebar-content-with-subgroup li')

# Loop through the list items and format the links
formatted_links = []
for item in list_items:
    link = item.find('a')
    if link:
        link_url = link.get('href')
        formatted_link = f"https://en.wikipedia.org{link_url}"
        formatted_links.append(formatted_link)

# %%
for link in formatted_links:
    response = requests.get(link)
    soup = BeautifulSoup(response.content, 'html.parser')
    
    # Find the interlanguage links
    interlanguage_links = soup.find_all("li", class_="interlanguage-link")
    
    # Initialize lists to store data for this link
    languages = []
    titles = []
    
    # Extract and store the language and correct title of each interlanguage link
    for interlanguage_link in interlanguage_links:
        lang = interlanguage_link.find("a")['lang']
        title = interlanguage_link.find("a")['title'].split(" – ")[0]
        languages.append(lang)
        titles.append(title)
    
    # Create a pandas DataFrame for this link
    data = {
        "Language": languages,
        "Title": titles
    }
    df = pd.DataFrame(data)
    
    # Create a CSV file name based on the link title
    csv_file_name = f"dataframes/{link.split('/')[-1]}.csv"
    
    # Save the DataFrame as a CSV file
    df.to_csv(csv_file_name, index=False)
    
    print(f"CSV saved: {csv_file_name}")
# Out:
# CSV saved: dataframes/Derivative.csv
# CSV saved: dataframes/Differential_(mathematics).csv
# CSV saved: dataframes/Differential_(infinitesimal).csv
# CSV saved: dataframes/Differential_of_a_function.csv
# CSV saved: dataframes/Differential_of_a_function#Differentials_in_several_variables.csv
# CSV saved: dataframes/Notation_for_differentiation.csv
# CSV saved: dataframes/Second_derivative.csv
# CSV saved: dataframes/Implicit_function.csv
# CSV saved: dataframes/Logarithmic_differentiation.csv
# CSV saved: dataframes/Related_rates.csv
# CSV saved: dataframes/Taylor%27s_theorem.csv
# CSV saved: dataframes/Sum_rule_in_differentiation.csv
# CSV saved: dataframes/Product_rule.csv
# CSV saved: dataframes/Chain_rule.csv
# CSV saved: dataframes/Power_rule.csv
# CSV saved: dataframes/Quotient_rule.csv
# CSV saved: dataframes/L%27H%C3%B4pital%27s_rule.csv
# CSV saved: dataframes/Inverse_function_rule.csv
# CSV saved: dataframes/General_Leibniz_rule.csv
# CSV saved: dataframes/Fa%C3%A0_di_Bruno%27s_formula.csv
# CSV saved: dataframes/Reynolds_transport_theorem.csv
# CSV saved: dataframes/Lists_of_integrals.csv
# CSV saved: dataframes/Integral_transform.csv
# CSV saved: dataframes/Leibniz_integral_rule.csv
# CSV saved: dataframes/Antiderivative.csv
# CSV saved: dataframes/Integral.csv
# CSV saved: dataframes/Riemann_integral.csv
# CSV saved: dataframes/Lebesgue_integration.csv
# CSV saved: dataframes/Contour_integration.csv
# CSV saved: dataframes/Integral_of_inverse_functions.csv
# CSV saved: dataframes/Integration_by_parts.csv
# CSV saved: dataframes/Disc_integration.csv
# CSV saved: dataframes/Shell_integration.csv
# CSV saved: dataframes/Integration_by_substitution.csv
# CSV saved: dataframes/Integration_using_Euler%27s_formula.csv
# CSV saved: dataframes/Partial_fractions_in_integration.csv
# CSV saved: dataframes/Order_of_integration_(calculus).csv
# CSV saved: dataframes/Integration_by_reduction_formulae.csv
# CSV saved: dataframes/Leibniz_integral_rule#Evaluating_definite_integrals.csv
# CSV saved: dataframes/Risch_algorithm.csv
# CSV saved: dataframes/Geometric_series.csv
# CSV saved: dataframes/Harmonic_series_(mathematics).csv
# CSV saved: dataframes/Alternating_series.csv
# CSV saved: dataframes/Power_series.csv
# CSV saved: dataframes/Binomial_series.csv
# CSV saved: dataframes/Taylor_series.csv
# CSV saved: dataframes/Term_test.csv
# CSV saved: dataframes/Ratio_test.csv
# CSV saved: dataframes/Root_test.csv
# CSV saved: dataframes/Integral_test_for_convergence.csv
# CSV saved: dataframes/Direct_comparison_test.csv
# CSV saved: dataframes/Limit_comparison_test.csv
# CSV saved: dataframes/Alternating_series_test.csv
# CSV saved: dataframes/Cauchy_condensation_test.csv
# CSV saved: dataframes/Dirichlet%27s_test.csv
# CSV saved: dataframes/Abel%27s_test.csv
# CSV saved: dataframes/Gradient.csv
# CSV saved: dataframes/Divergence.csv
# CSV saved: dataframes/Curl_(mathematics).csv
# CSV saved: dataframes/Laplace_operator.csv
# CSV saved: dataframes/Directional_derivative.csv
# CSV saved: dataframes/Vector_calculus_identities.csv
# CSV saved: dataframes/Gradient_theorem.csv
# CSV saved: dataframes/Green%27s_theorem.csv
# CSV saved: dataframes/Stokes%27_theorem.csv
# CSV saved: dataframes/Divergence_theorem.csv
# CSV saved: dataframes/Generalized_Stokes%27_theorem.csv
# CSV saved: dataframes/Matrix_calculus.csv
# CSV saved: dataframes/Tensor_calculus.csv
# CSV saved: dataframes/Exterior_derivative.csv
# CSV saved: dataframes/Geometric_calculus.csv
# CSV saved: dataframes/Partial_derivative.csv
# CSV saved: dataframes/Multiple_integral.csv
# CSV saved: dataframes/Line_integral.csv
# CSV saved: dataframes/Surface_integral.csv
# CSV saved: dataframes/Volume_integral.csv
# CSV saved: dataframes/Jacobian_matrix_and_determinant.csv
# CSV saved: dataframes/Hessian_matrix.csv
# CSV saved: dataframes/Calculus_on_Euclidean_space.csv
# CSV saved: dataframes/Generalized_function.csv
# CSV saved: dataframes/Limit_of_distributions.csv

# %%
url = 'https://en.wikipedia.org/wiki/List_of_calculus_topics'
page = requests.get(url)
page.status_code
soup = BeautifulSoup(page.content, 'html.parser') 

# Find all the links within the list items ('li') in the sidebar
list_items = soup.select('.sidebar-content-with-subgroup li')

# Loop through the list items and format the links
formatted_links = []
for item in list_items:
    link = item.find('a')
    if link:
        link_url = link.get('href')
        formatted_link = f"https://en.wikipedia.org{link_url}"
        formatted_links.append(formatted_link)
for link in formatted_links:
    response = requests.get(link)
    soup = BeautifulSoup(response.content, 'html.parser')
    
    # Find the interlanguage links
    interlanguage_links = soup.find_all("li", class_="interlanguage-link")
    
    # Initialize lists to store data for this link
    languages = []
    titles = []
    
    # Extract and store the language and correct title of each interlanguage link
    for interlanguage_link in interlanguage_links:
        lang = interlanguage_link.find("a")['lang']
        title = interlanguage_link.find("a")['title'].split(" – ")[0]
        languages.append(lang)
        titles.append(title)
    
    # Create a pandas DataFrame for this link
    data = {
        "Language": languages,
        "Title": titles
    }
    df = pd.DataFrame(data)
    
    # Create a CSV file name based on the link title
    csv_file_name = f"dataframes/{link.split('/')[-1]}.csv"
    
    # Save the DataFrame as a CSV file
    df.to_csv(csv_file_name, index=False)
    
    print(f"CSV saved: {csv_file_name}")
# Out:
# CSV saved: dataframes/Derivative.csv
# CSV saved: dataframes/Differential_(mathematics).csv
# CSV saved: dataframes/Differential_(infinitesimal).csv
# CSV saved: dataframes/Differential_of_a_function.csv
# CSV saved: dataframes/Differential_of_a_function#Differentials_in_several_variables.csv
# CSV saved: dataframes/Notation_for_differentiation.csv
# CSV saved: dataframes/Second_derivative.csv
# CSV saved: dataframes/Implicit_function.csv
# CSV saved: dataframes/Logarithmic_differentiation.csv
# CSV saved: dataframes/Related_rates.csv
# CSV saved: dataframes/Taylor%27s_theorem.csv
# CSV saved: dataframes/Sum_rule_in_differentiation.csv
# CSV saved: dataframes/Product_rule.csv
# CSV saved: dataframes/Chain_rule.csv
# CSV saved: dataframes/Power_rule.csv
# CSV saved: dataframes/Quotient_rule.csv
# CSV saved: dataframes/L%27H%C3%B4pital%27s_rule.csv
# CSV saved: dataframes/Inverse_function_rule.csv
# CSV saved: dataframes/General_Leibniz_rule.csv
# CSV saved: dataframes/Fa%C3%A0_di_Bruno%27s_formula.csv
# CSV saved: dataframes/Reynolds_transport_theorem.csv
# CSV saved: dataframes/Lists_of_integrals.csv
# CSV saved: dataframes/Integral_transform.csv
# CSV saved: dataframes/Leibniz_integral_rule.csv
# CSV saved: dataframes/Antiderivative.csv
# CSV saved: dataframes/Integral.csv
# CSV saved: dataframes/Riemann_integral.csv
# CSV saved: dataframes/Lebesgue_integration.csv
# CSV saved: dataframes/Contour_integration.csv
# CSV saved: dataframes/Integral_of_inverse_functions.csv
# CSV saved: dataframes/Integration_by_parts.csv
# CSV saved: dataframes/Disc_integration.csv
# CSV saved: dataframes/Shell_integration.csv
# CSV saved: dataframes/Integration_by_substitution.csv
# CSV saved: dataframes/Integration_using_Euler%27s_formula.csv
# CSV saved: dataframes/Partial_fractions_in_integration.csv
# CSV saved: dataframes/Order_of_integration_(calculus).csv
# CSV saved: dataframes/Integration_by_reduction_formulae.csv
# CSV saved: dataframes/Leibniz_integral_rule#Evaluating_definite_integrals.csv
# CSV saved: dataframes/Risch_algorithm.csv
# CSV saved: dataframes/Geometric_series.csv
# CSV saved: dataframes/Harmonic_series_(mathematics).csv
# CSV saved: dataframes/Alternating_series.csv
# CSV saved: dataframes/Power_series.csv
# CSV saved: dataframes/Binomial_series.csv
# CSV saved: dataframes/Taylor_series.csv
# CSV saved: dataframes/Term_test.csv
# CSV saved: dataframes/Ratio_test.csv
# CSV saved: dataframes/Root_test.csv
# CSV saved: dataframes/Integral_test_for_convergence.csv
# CSV saved: dataframes/Direct_comparison_test.csv
# CSV saved: dataframes/Limit_comparison_test.csv
# CSV saved: dataframes/Alternating_series_test.csv
# CSV saved: dataframes/Cauchy_condensation_test.csv
# CSV saved: dataframes/Dirichlet%27s_test.csv
# CSV saved: dataframes/Abel%27s_test.csv
# CSV saved: dataframes/Gradient.csv
# CSV saved: dataframes/Divergence.csv
# CSV saved: dataframes/Curl_(mathematics).csv
# CSV saved: dataframes/Laplace_operator.csv
# CSV saved: dataframes/Directional_derivative.csv
# CSV saved: dataframes/Vector_calculus_identities.csv
# CSV saved: dataframes/Gradient_theorem.csv
# CSV saved: dataframes/Green%27s_theorem.csv
# CSV saved: dataframes/Stokes%27_theorem.csv
# CSV saved: dataframes/Divergence_theorem.csv
# CSV saved: dataframes/Generalized_Stokes%27_theorem.csv
# CSV saved: dataframes/Matrix_calculus.csv
# CSV saved: dataframes/Tensor_calculus.csv
# CSV saved: dataframes/Exterior_derivative.csv
# CSV saved: dataframes/Geometric_calculus.csv
# CSV saved: dataframes/Partial_derivative.csv
# CSV saved: dataframes/Multiple_integral.csv
# CSV saved: dataframes/Line_integral.csv
# CSV saved: dataframes/Surface_integral.csv
# CSV saved: dataframes/Volume_integral.csv
# CSV saved: dataframes/Jacobian_matrix_and_determinant.csv
# CSV saved: dataframes/Hessian_matrix.csv
# CSV saved: dataframes/Calculus_on_Euclidean_space.csv
# CSV saved: dataframes/Generalized_function.csv
# CSV saved: dataframes/Limit_of_distributions.csv

# %%
def scrape_wikipedia_links(webpage_url):
    # Send an HTTP GET request to the webpage_url
    page = requests.get(webpage_url)
    
    # Check if the request was successful (status code 200)
    if page.status_code == 200:
        # Parse the HTML content of the webpage
        soup = BeautifulSoup(page.content, 'html.parser')
        
        # Find all the links within the list items ('li') in the sidebar
        list_items = soup.select('.sidebar-content-with-subgroup li')
        
        # Loop through the list items and format the links
        formatted_links = []
        for item in list_items:
            link = item.find('a')
            if link:
                link_url = link.get('href')
                formatted_link = f"https://en.wikipedia.org{link_url}"
                formatted_links.append(formatted_link)
        
        for link in formatted_links:
            response = requests.get(link)
            soup = BeautifulSoup(response.content, 'html.parser')
            
            # Find the interlanguage links
            interlanguage_links = soup.find_all("li", class_="interlanguage-link")
            
            # Initialize lists to store data for this link
            languages = []
            titles = []
            
            # Extract and store the language and correct title of each interlanguage link
            for interlanguage_link in interlanguage_links:
                lang = interlanguage_link.find("a")['lang']
                title = interlanguage_link.find("a")['title'].split(" – ")[0]
                languages.append(lang)
                titles.append(title)
            
            # Create a pandas DataFrame for this link
            data = {
                "Language": languages,
                "Title": titles
            }
            df = pd.DataFrame(data)
            
            # Create a CSV file name based on the link title
            csv_file_name = f"dataframes/{link.split('/')[-1]}.csv"
            
            # Save the DataFrame as a CSV file
            df.to_csv(csv_file_name, index=False)
            
            print(f"CSV saved: {csv_file_name}")
    else:
        print(f"Failed to retrieve the webpage. Status code: {page.status_code}")

# %%
# Out:
# 10

# %%
import requests
from bs4 import BeautifulSoup

def scrape_links_after_toc(webpage_url):
    try:
        # Send an HTTP GET request to the webpage_url
        response = requests.get(webpage_url)

        # Check if the request was successful (status code 200)
        if response.status_code == 200:
            # Parse the HTML content of the webpage
            soup = BeautifulSoup(response.content, 'html.parser')

            # Find the <meta> tag with property="mw:PageProp/toc"
            toc_meta_tag = soup.find('meta', attrs={'property': 'mw:PageProp/toc'})

            # Check if the <meta> tag exists
            if toc_meta_tag:
                # Find the <ul> (unordered list) tag that follows the <meta> tag
                ul_tag = toc_meta_tag.find_next('ul')

                # Find all the <a> (anchor) tags within the <ul> tag
                links = ul_tag.find_all('a')

                # Extract and print the href attribute of each <a> tag
                for link in links:
                    href = link.get('href')
                    title = link.get('title')
                    print(f"Link: {href}, Title: {title}")

            else:
                print("No <meta> tag with property='mw:PageProp/toc' found on the page.")

        else:
            print(f"Failed to retrieve the webpage. Status code: {response.status_code}")

    except requests.exceptions.RequestException as e:
        print(f"Error: {e}")

# Example usage:
webpage_url = 'https://en.wikipedia.org/wiki/List_of_geometry_topics'
scrape_links_after_toc(webpage_url)
# Out:
# Link: /wiki/Absolute_geometry, Title: Absolute geometry
# Link: /wiki/Affine_geometry, Title: Affine geometry
# Link: /wiki/Algebraic_geometry, Title: Algebraic geometry
# Link: /wiki/Analytic_geometry, Title: Analytic geometry
# Link: /wiki/Archimedes%27_use_of_infinitesimals, Title: Archimedes' use of infinitesimals
# Link: /wiki/Birational_geometry, Title: Birational geometry
# Link: /wiki/Complex_geometry, Title: Complex geometry
# Link: /wiki/Combinatorial_geometry, Title: Combinatorial geometry
# Link: /wiki/Computational_geometry, Title: Computational geometry
# Link: /wiki/Conformal_geometry, Title: Conformal geometry
# Link: /wiki/Constructive_solid_geometry, Title: Constructive solid geometry
# Link: /wiki/Contact_geometry, Title: Contact geometry
# Link: /wiki/Convex_geometry, Title: Convex geometry
# Link: /wiki/Descriptive_geometry, Title: Descriptive geometry
# Link: /wiki/Differential_geometry, Title: Differential geometry
# Link: /wiki/Digital_geometry, Title: Digital geometry
# Link: /wiki/Discrete_geometry, Title: Discrete geometry
# Link: /wiki/Distance_geometry, Title: Distance geometry
# Link: /wiki/Elliptic_geometry, Title: Elliptic geometry
# Link: /wiki/Enumerative_geometry, Title: Enumerative geometry
# Link: /wiki/Epipolar_geometry, Title: Epipolar geometry
# Link: /wiki/Finite_geometry, Title: Finite geometry
# Link: /wiki/Fractal_geometry, Title: Fractal geometry
# Link: /wiki/Geometry_of_numbers, Title: Geometry of numbers
# Link: /wiki/Hyperbolic_geometry, Title: Hyperbolic geometry
# Link: /wiki/Incidence_geometry, Title: Incidence geometry
# Link: /wiki/Information_geometry, Title: Information geometry
# Link: /wiki/Integral_geometry, Title: Integral geometry
# Link: /wiki/Inversive_geometry, Title: Inversive geometry
# Link: /wiki/Inversive_ring_geometry, Title: Inversive ring geometry
# Link: /wiki/Klein_geometry, Title: Klein geometry
# Link: /wiki/Lie_sphere_geometry, Title: Lie sphere geometry
# Link: /wiki/Non-Euclidean_geometry, Title: Non-Euclidean geometry
# Link: /wiki/Noncommutative_algebraic_geometry, Title: Noncommutative algebraic geometry
# Link: /wiki/Noncommutative_geometry, Title: Noncommutative geometry
# Link: /wiki/Computational_geometry#Numerical_computational_geometry, Title: Computational geometry
# Link: /wiki/Ordered_geometry, Title: Ordered geometry
# Link: /wiki/Parabolic_geometry_(differential_geometry), Title: Parabolic geometry (differential geometry)
# Link: /wiki/Euclidean_plane_geometry, Title: Euclidean plane geometry
# Link: /wiki/Projective_geometry, Title: Projective geometry
# Link: /wiki/Quantum_geometry, Title: Quantum geometry
# Link: /wiki/Riemannian_geometry, Title: Riemannian geometry
# Link: /wiki/Ruppeiner_geometry, Title: Ruppeiner geometry
# Link: /wiki/Spherical_geometry, Title: Spherical geometry
# Link: /wiki/Symplectic_geometry, Title: Symplectic geometry
# Link: /wiki/Synthetic_geometry, Title: Synthetic geometry
# Link: /wiki/Systolic_geometry, Title: Systolic geometry
# Link: /wiki/Taxicab_geometry, Title: Taxicab geometry
# Link: /wiki/Toric_geometry, Title: Toric geometry
# Link: /wiki/Transformation_geometry, Title: Transformation geometry
# Link: /wiki/Tropical_geometry, Title: Tropical geometry

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

def process_link(link):
    try:
        response = requests.get(link)
        
        if response.status_code == 200:
            soup = BeautifulSoup(response.content, 'html.parser')
            
            interlanguage_links = soup.find_all("li", class_="interlanguage-link")
            languages = []
            titles = []
            
            for interlanguage_link in interlanguage_links:
                lang = interlanguage_link.find("a")['lang']
                title = interlanguage_link.find("a")['title'].split(" – ")[0]
                languages.append(lang)
                titles.append(title)
            
            data = {
                "Language": languages,
                "Title": titles
            }
            df = pd.DataFrame(data)
            
            csv_file_name = f"dataframes/{link.split('/')[-1]}.csv"
            df.to_csv(csv_file_name, index=False)
            
            print(f"CSV saved: {csv_file_name}")
        else:
            print(f"Failed to retrieve the link: {link}. Status code: {response.status_code}")

    except requests.exceptions.RequestException as e:
        print(f"Error: {e}")

def scrape_links_after_toc(webpage_url):
    # ... (code to extract links after <meta property="mw:PageProp/toc" />)
    
    for link in formatted_links:
        full_link = f"https://en.wikipedia.org{link}"
        process_link(full_link)

# Example usage:
webpage_url = 'https://en.wikipedia.org/wiki/List_of_geometry_topics'
scrape_links_after_toc(webpage_url)

# %%
import requests
from bs4 import BeautifulSoup

def scrape_links_after_toc(webpage_url):
    formatted_links = []  # Create an empty list to store the URLs
    
    try:
        # Send an HTTP GET request to the webpage_url
        response = requests.get(webpage_url)

        # Check if the request was successful (status code 200)
        if response.status_code == 200:
            # Parse the HTML content of the webpage
            soup = BeautifulSoup(response.content, 'html.parser')

            # Find the <meta> tag with property="mw:PageProp/toc"
            toc_meta_tag = soup.find('meta', attrs={'property': 'mw:PageProp/toc'})

            # Check if the <meta> tag exists
            if toc_meta_tag:
                # Find the <ul> (unordered list) tag that follows the <meta> tag
                ul_tag = toc_meta_tag.find_next('ul')

                # Find all the <a> (anchor) tags within the <ul> tag
                links = ul_tag.find_all('a')

                # Extract and append the href attribute of each <a> tag to the formatted_links list
                for link in links:
                    href = link.get('href')
                    formatted_link = f"https://en.wikipedia.org{href}"
                    formatted_links.append(formatted_link)  # Append the formatted URL to the list
                    title = link.get('title')
                    print(f"Link: {formatted_link}, Title: {title}")

            else:
                print("No <meta> tag with property='mw:PageProp/toc' found on the page.")

        else:
            print(f"Failed to retrieve the webpage. Status code: {response.status_code}")

    except requests.exceptions.RequestException as e:
        print(f"Error: {e}")
    
    return formatted_links  # Return the list of formatted links


webpage_url = 'https://en.wikipedia.org/wiki/List_of_geometry_topics'
formatted_links = scrape_links_after_toc(webpage_url)
# Out:
# Link: https://en.wikipedia.org/wiki/Absolute_geometry, Title: Absolute geometry
# Link: https://en.wikipedia.org/wiki/Affine_geometry, Title: Affine geometry
# Link: https://en.wikipedia.org/wiki/Algebraic_geometry, Title: Algebraic geometry
# Link: https://en.wikipedia.org/wiki/Analytic_geometry, Title: Analytic geometry
# Link: https://en.wikipedia.org/wiki/Archimedes%27_use_of_infinitesimals, Title: Archimedes' use of infinitesimals
# Link: https://en.wikipedia.org/wiki/Birational_geometry, Title: Birational geometry
# Link: https://en.wikipedia.org/wiki/Complex_geometry, Title: Complex geometry
# Link: https://en.wikipedia.org/wiki/Combinatorial_geometry, Title: Combinatorial geometry
# Link: https://en.wikipedia.org/wiki/Computational_geometry, Title: Computational geometry
# Link: https://en.wikipedia.org/wiki/Conformal_geometry, Title: Conformal geometry
# Link: https://en.wikipedia.org/wiki/Constructive_solid_geometry, Title: Constructive solid geometry
# Link: https://en.wikipedia.org/wiki/Contact_geometry, Title: Contact geometry
# Link: https://en.wikipedia.org/wiki/Convex_geometry, Title: Convex geometry
# Link: https://en.wikipedia.org/wiki/Descriptive_geometry, Title: Descriptive geometry
# Link: https://en.wikipedia.org/wiki/Differential_geometry, Title: Differential geometry
# Link: https://en.wikipedia.org/wiki/Digital_geometry, Title: Digital geometry
# Link: https://en.wikipedia.org/wiki/Discrete_geometry, Title: Discrete geometry
# Link: https://en.wikipedia.org/wiki/Distance_geometry, Title: Distance geometry
# Link: https://en.wikipedia.org/wiki/Elliptic_geometry, Title: Elliptic geometry
# Link: https://en.wikipedia.org/wiki/Enumerative_geometry, Title: Enumerative geometry
# Link: https://en.wikipedia.org/wiki/Epipolar_geometry, Title: Epipolar geometry
# Link: https://en.wikipedia.org/wiki/Finite_geometry, Title: Finite geometry
# Link: https://en.wikipedia.org/wiki/Fractal_geometry, Title: Fractal geometry
# Link: https://en.wikipedia.org/wiki/Geometry_of_numbers, Title: Geometry of numbers
# Link: https://en.wikipedia.org/wiki/Hyperbolic_geometry, Title: Hyperbolic geometry
# Link: https://en.wikipedia.org/wiki/Incidence_geometry, Title: Incidence geometry
# Link: https://en.wikipedia.org/wiki/Information_geometry, Title: Information geometry
# Link: https://en.wikipedia.org/wiki/Integral_geometry, Title: Integral geometry
# Link: https://en.wikipedia.org/wiki/Inversive_geometry, Title: Inversive geometry
# Link: https://en.wikipedia.org/wiki/Inversive_ring_geometry, Title: Inversive ring geometry
# Link: https://en.wikipedia.org/wiki/Klein_geometry, Title: Klein geometry
# Link: https://en.wikipedia.org/wiki/Lie_sphere_geometry, Title: Lie sphere geometry
# Link: https://en.wikipedia.org/wiki/Non-Euclidean_geometry, Title: Non-Euclidean geometry
# Link: https://en.wikipedia.org/wiki/Noncommutative_algebraic_geometry, Title: Noncommutative algebraic geometry
# Link: https://en.wikipedia.org/wiki/Noncommutative_geometry, Title: Noncommutative geometry
# Link: https://en.wikipedia.org/wiki/Computational_geometry#Numerical_computational_geometry, Title: Computational geometry
# Link: https://en.wikipedia.org/wiki/Ordered_geometry, Title: Ordered geometry
# Link: https://en.wikipedia.org/wiki/Parabolic_geometry_(differential_geometry), Title: Parabolic geometry (differential geometry)
# Link: https://en.wikipedia.org/wiki/Euclidean_plane_geometry, Title: Euclidean plane geometry
# Link: https://en.wikipedia.org/wiki/Projective_geometry, Title: Projective geometry
# Link: https://en.wikipedia.org/wiki/Quantum_geometry, Title: Quantum geometry
# Link: https://en.wikipedia.org/wiki/Riemannian_geometry, Title: Riemannian geometry
# Link: https://en.wikipedia.org/wiki/Ruppeiner_geometry, Title: Ruppeiner geometry
# Link: https://en.wikipedia.org/wiki/Spherical_geometry, Title: Spherical geometry
# Link: https://en.wikipedia.org/wiki/Symplectic_geometry, Title: Symplectic geometry
# Link: https://en.wikipedia.org/wiki/Synthetic_geometry, Title: Synthetic geometry
# Link: https://en.wikipedia.org/wiki/Systolic_geometry, Title: Systolic geometry
# Link: https://en.wikipedia.org/wiki/Taxicab_geometry, Title: Taxicab geometry
# Link: https://en.wikipedia.org/wiki/Toric_geometry, Title: Toric geometry
# Link: https://en.wikipedia.org/wiki/Transformation_geometry, Title: Transformation geometry
# Link: https://en.wikipedia.org/wiki/Tropical_geometry, Title: Tropical geometry

# %%
formatted_links
# Out:
# ['https://en.wikipedia.org/wiki/Absolute_geometry',
#  'https://en.wikipedia.org/wiki/Affine_geometry',
#  'https://en.wikipedia.org/wiki/Algebraic_geometry',
#  'https://en.wikipedia.org/wiki/Analytic_geometry',
#  'https://en.wikipedia.org/wiki/Archimedes%27_use_of_infinitesimals',
#  'https://en.wikipedia.org/wiki/Birational_geometry',
#  'https://en.wikipedia.org/wiki/Complex_geometry',
#  'https://en.wikipedia.org/wiki/Combinatorial_geometry',
#  'https://en.wikipedia.org/wiki/Computational_geometry',
#  'https://en.wikipedia.org/wiki/Conformal_geometry',
#  'https://en.wikipedia.org/wiki/Constructive_solid_geometry',
#  'https://en.wikipedia.org/wiki/Contact_geometry',
#  'https://en.wikipedia.org/wiki/Convex_geometry',
#  'https://en.wikipedia.org/wiki/Descriptive_geometry',
#  'https://en.wikipedia.org/wiki/Differential_geometry',
#  'https://en.wikipedia.org/wiki/Digital_geometry',
#  'https://en.wikipedia.org/wiki/Discrete_geometry',
#  'https://en.wikipedia.org/wiki/Distance_geometry',
#  'https://en.wikipedia.org/wiki/Elliptic_geometry',
#  'https://en.wikipedia.org/wiki/Enumerative_geometry',
#  'https://en.wikipedia.org/wiki/Epipolar_geometry',
#  'https://en.wikipedia.org/wiki/Finite_geometry',
#  'https://en.wikipedia.org/wiki/Fractal_geometry',
#  'https://en.wikipedia.org/wiki/Geometry_of_numbers',
#  'https://en.wikipedia.org/wiki/Hyperbolic_geometry',
#  'https://en.wikipedia.org/wiki/Incidence_geometry',
#  'https://en.wikipedia.org/wiki/Information_geometry',
#  'https://en.wikipedia.org/wiki/Integral_geometry',
#  'https://en.wikipedia.org/wiki/Inversive_geometry',
#  'https://en.wikipedia.org/wiki/Inversive_ring_geometry',
#  'https://en.wikipedia.org/wiki/Klein_geometry',
#  'https://en.wikipedia.org/wiki/Lie_sphere_geometry',
#  'https://en.wikipedia.org/wiki/Non-Euclidean_geometry',
#  'https://en.wikipedia.org/wiki/Noncommutative_algebraic_geometry',
#  'https://en.wikipedia.org/wiki/Noncommutative_geometry',
#  'https://en.wikipedia.org/wiki/Computational_geometry#Numerical_computational_geometry',
#  'https://en.wikipedia.org/wiki/Ordered_geometry',
#  'https://en.wikipedia.org/wiki/Parabolic_geometry_(differential_geometry)',
#  'https://en.wikipedia.org/wiki/Euclidean_plane_geometry',
#  'https://en.wikipedia.org/wiki/Projective_geometry',
#  'https://en.wikipedia.org/wiki/Quantum_geometry',
#  'https://en.wikipedia.org/wiki/Riemannian_geometry',
#  'https://en.wikipedia.org/wiki/Ruppeiner_geometry',
#  'https://en.wikipedia.org/wiki/Spherical_geometry',
#  'https://en.wikipedia.org/wiki/Symplectic_geometry',
#  'https://en.wikipedia.org/wiki/Synthetic_geometry',
#  'https://en.wikipedia.org/wiki/Systolic_geometry',
#  'https://en.wikipedia.org/wiki/Taxicab_geometry',
#  'https://en.wikipedia.org/wiki/Toric_geometry',
#  'https://en.wikipedia.org/wiki/Transformation_geometry',
#  'https://en.wikipedia.org/wiki/Tropical_geometry']

# %%
for link in formatted_links:
    response = requests.get(link)
    soup = BeautifulSoup(response.content, 'html.parser')
    
    # Find the interlanguage links
    interlanguage_links = soup.find_all("li", class_="interlanguage-link")
    
    # Initialize lists to store data for this link
    languages = []
    titles = []
    
    # Extract and store the language and correct title of each interlanguage link
    for interlanguage_link in interlanguage_links:
        lang = interlanguage_link.find("a")['lang']
        title = interlanguage_link.find("a")['title'].split(" – ")[0]
        languages.append(lang)
        titles.append(title)
    
    # Create a pandas DataFrame for this link
    data = {
        "Language": languages,
        "Title": titles
    }
    df = pd.DataFrame(data)
    
    # Create a CSV file name based on the link title
    csv_file_name = f"dataframes/{link.split('/')[-1]}.csv"
    
    # Save the DataFrame as a CSV file
    df.to_csv(csv_file_name, index=False)
    
    print(f"CSV saved: {csv_file_name}")
# Out:
# CSV saved: dataframes/Absolute_geometry.csv
# CSV saved: dataframes/Affine_geometry.csv
# CSV saved: dataframes/Algebraic_geometry.csv
# CSV saved: dataframes/Analytic_geometry.csv
# CSV saved: dataframes/Archimedes%27_use_of_infinitesimals.csv
# CSV saved: dataframes/Birational_geometry.csv
# CSV saved: dataframes/Complex_geometry.csv
# CSV saved: dataframes/Combinatorial_geometry.csv
# CSV saved: dataframes/Computational_geometry.csv
# CSV saved: dataframes/Conformal_geometry.csv
# CSV saved: dataframes/Constructive_solid_geometry.csv
# CSV saved: dataframes/Contact_geometry.csv
# CSV saved: dataframes/Convex_geometry.csv
# CSV saved: dataframes/Descriptive_geometry.csv
# CSV saved: dataframes/Differential_geometry.csv
# CSV saved: dataframes/Digital_geometry.csv
# CSV saved: dataframes/Discrete_geometry.csv
# CSV saved: dataframes/Distance_geometry.csv
# CSV saved: dataframes/Elliptic_geometry.csv
# CSV saved: dataframes/Enumerative_geometry.csv
# CSV saved: dataframes/Epipolar_geometry.csv
# CSV saved: dataframes/Finite_geometry.csv
# CSV saved: dataframes/Fractal_geometry.csv
# CSV saved: dataframes/Geometry_of_numbers.csv
# CSV saved: dataframes/Hyperbolic_geometry.csv
# CSV saved: dataframes/Incidence_geometry.csv
# CSV saved: dataframes/Information_geometry.csv
# CSV saved: dataframes/Integral_geometry.csv
# CSV saved: dataframes/Inversive_geometry.csv
# CSV saved: dataframes/Inversive_ring_geometry.csv
# CSV saved: dataframes/Klein_geometry.csv
# CSV saved: dataframes/Lie_sphere_geometry.csv
# CSV saved: dataframes/Non-Euclidean_geometry.csv
# CSV saved: dataframes/Noncommutative_algebraic_geometry.csv
# CSV saved: dataframes/Noncommutative_geometry.csv
# CSV saved: dataframes/Computational_geometry#Numerical_computational_geometry.csv
# CSV saved: dataframes/Ordered_geometry.csv
# CSV saved: dataframes/Parabolic_geometry_(differential_geometry).csv
# CSV saved: dataframes/Euclidean_plane_geometry.csv
# CSV saved: dataframes/Projective_geometry.csv
# CSV saved: dataframes/Quantum_geometry.csv
# CSV saved: dataframes/Riemannian_geometry.csv
# CSV saved: dataframes/Ruppeiner_geometry.csv
# CSV saved: dataframes/Spherical_geometry.csv
# CSV saved: dataframes/Symplectic_geometry.csv
# CSV saved: dataframes/Synthetic_geometry.csv
# CSV saved: dataframes/Systolic_geometry.csv
# CSV saved: dataframes/Taxicab_geometry.csv
# CSV saved: dataframes/Toric_geometry.csv
# CSV saved: dataframes/Transformation_geometry.csv
# CSV saved: dataframes/Tropical_geometry.csv

# %%
webpage_url = 'https://en.wikipedia.org/wiki/List_of_geometry_topics'
formatted_links = scrape_links_after_toc(webpage_url)

for link in formatted_links:
    response = requests.get(link)
    soup = BeautifulSoup(response.content, 'html.parser')
    
    # Find the interlanguage links
    interlanguage_links = soup.find_all("li", class_="interlanguage-link")
    
    # Initialize lists to store data for this link
    languages = []
    titles = []
    
    # Extract and store the language and correct title of each interlanguage link
    for interlanguage_link in interlanguage_links:
        lang = interlanguage_link.find("a")['lang']
        title = interlanguage_link.find("a")['title'].split(" – ")[0]
        languages.append(lang)
        titles.append(title)
    
    # Create a pandas DataFrame for this link
    data = {
        "Language": languages,
        "Title": titles
    }
    df = pd.DataFrame(data)
    
    # Create a CSV file name based on the link title
    csv_file_name = f"dataframes/{link.split('/')[-1]}.csv"
    
    # Save the DataFrame as a CSV file
    df.to_csv(csv_file_name, index=False)
    
    print(f"CSV saved: {csv_file_name}")
# Out:
# Link: https://en.wikipedia.org/wiki/Absolute_geometry, Title: Absolute geometry
# Link: https://en.wikipedia.org/wiki/Affine_geometry, Title: Affine geometry
# Link: https://en.wikipedia.org/wiki/Algebraic_geometry, Title: Algebraic geometry
# Link: https://en.wikipedia.org/wiki/Analytic_geometry, Title: Analytic geometry
# Link: https://en.wikipedia.org/wiki/Archimedes%27_use_of_infinitesimals, Title: Archimedes' use of infinitesimals
# Link: https://en.wikipedia.org/wiki/Birational_geometry, Title: Birational geometry
# Link: https://en.wikipedia.org/wiki/Complex_geometry, Title: Complex geometry
# Link: https://en.wikipedia.org/wiki/Combinatorial_geometry, Title: Combinatorial geometry
# Link: https://en.wikipedia.org/wiki/Computational_geometry, Title: Computational geometry
# Link: https://en.wikipedia.org/wiki/Conformal_geometry, Title: Conformal geometry
# Link: https://en.wikipedia.org/wiki/Constructive_solid_geometry, Title: Constructive solid geometry
# Link: https://en.wikipedia.org/wiki/Contact_geometry, Title: Contact geometry
# Link: https://en.wikipedia.org/wiki/Convex_geometry, Title: Convex geometry
# Link: https://en.wikipedia.org/wiki/Descriptive_geometry, Title: Descriptive geometry
# Link: https://en.wikipedia.org/wiki/Differential_geometry, Title: Differential geometry
# Link: https://en.wikipedia.org/wiki/Digital_geometry, Title: Digital geometry
# Link: https://en.wikipedia.org/wiki/Discrete_geometry, Title: Discrete geometry
# Link: https://en.wikipedia.org/wiki/Distance_geometry, Title: Distance geometry
# Link: https://en.wikipedia.org/wiki/Elliptic_geometry, Title: Elliptic geometry
# Link: https://en.wikipedia.org/wiki/Enumerative_geometry, Title: Enumerative geometry
# Link: https://en.wikipedia.org/wiki/Epipolar_geometry, Title: Epipolar geometry
# Link: https://en.wikipedia.org/wiki/Finite_geometry, Title: Finite geometry
# Link: https://en.wikipedia.org/wiki/Fractal_geometry, Title: Fractal geometry
# Link: https://en.wikipedia.org/wiki/Geometry_of_numbers, Title: Geometry of numbers
# Link: https://en.wikipedia.org/wiki/Hyperbolic_geometry, Title: Hyperbolic geometry
# Link: https://en.wikipedia.org/wiki/Incidence_geometry, Title: Incidence geometry
# Link: https://en.wikipedia.org/wiki/Information_geometry, Title: Information geometry
# Link: https://en.wikipedia.org/wiki/Integral_geometry, Title: Integral geometry
# Link: https://en.wikipedia.org/wiki/Inversive_geometry, Title: Inversive geometry
# Link: https://en.wikipedia.org/wiki/Inversive_ring_geometry, Title: Inversive ring geometry
# Link: https://en.wikipedia.org/wiki/Klein_geometry, Title: Klein geometry
# Link: https://en.wikipedia.org/wiki/Lie_sphere_geometry, Title: Lie sphere geometry
# Link: https://en.wikipedia.org/wiki/Non-Euclidean_geometry, Title: Non-Euclidean geometry
# Link: https://en.wikipedia.org/wiki/Noncommutative_algebraic_geometry, Title: Noncommutative algebraic geometry
# Link: https://en.wikipedia.org/wiki/Noncommutative_geometry, Title: Noncommutative geometry
# Link: https://en.wikipedia.org/wiki/Computational_geometry#Numerical_computational_geometry, Title: Computational geometry
# Link: https://en.wikipedia.org/wiki/Ordered_geometry, Title: Ordered geometry
# Link: https://en.wikipedia.org/wiki/Parabolic_geometry_(differential_geometry), Title: Parabolic geometry (differential geometry)
# Link: https://en.wikipedia.org/wiki/Euclidean_plane_geometry, Title: Euclidean plane geometry
# Link: https://en.wikipedia.org/wiki/Projective_geometry, Title: Projective geometry
# Link: https://en.wikipedia.org/wiki/Quantum_geometry, Title: Quantum geometry
# Link: https://en.wikipedia.org/wiki/Riemannian_geometry, Title: Riemannian geometry
# Link: https://en.wikipedia.org/wiki/Ruppeiner_geometry, Title: Ruppeiner geometry
# Link: https://en.wikipedia.org/wiki/Spherical_geometry, Title: Spherical geometry
# Link: https://en.wikipedia.org/wiki/Symplectic_geometry, Title: Symplectic geometry
# Link: https://en.wikipedia.org/wiki/Synthetic_geometry, Title: Synthetic geometry
# Link: https://en.wikipedia.org/wiki/Systolic_geometry, Title: Systolic geometry
# Link: https://en.wikipedia.org/wiki/Taxicab_geometry, Title: Taxicab geometry
# Link: https://en.wikipedia.org/wiki/Toric_geometry, Title: Toric geometry
# Link: https://en.wikipedia.org/wiki/Transformation_geometry, Title: Transformation geometry
# Link: https://en.wikipedia.org/wiki/Tropical_geometry, Title: Tropical geometry

# %%
def scrape_links_and_process(webpage_url):
    try:
        # Send an HTTP GET request to the webpage_url
        response = requests.get(webpage_url)

        # Check if the request was successful (status code 200)
        if response.status_code == 200:
            # Parse the HTML content of the webpage
            soup = BeautifulSoup(response.content, 'html.parser')

            # Find the <meta> tag with property="mw:PageProp/toc"
            toc_meta_tag = soup.find('meta', attrs={'property': 'mw:PageProp/toc'})

            # Check if the <meta> tag exists
            if toc_meta_tag:
                # Find the <ul> (unordered list) tag that follows the <meta> tag
                ul_tag = toc_meta_tag.find_next('ul')

                # Find all the <a> (anchor) tags within the <ul> tag
                links = ul_tag.find_all('a')

                # Extract and append the href attribute of each <a> tag to the formatted_links list
                formatted_links = []
                for link in links:
                    href = link.get('href')
                    formatted_link = f"https://en.wikipedia.org{href}"
                    formatted_links.append(formatted_link)  # Append the formatted URL to the list
                    title = link.get('title')
                    print(f"Link: {formatted_link}, Title: {title}")

                # Process each link
                for link in formatted_links:
                    response = requests.get(link)
                    soup = BeautifulSoup(response.content, 'html.parser')

                    # Find the interlanguage links
                    interlanguage_links = soup.find_all("li", class_="interlanguage-link")

                    # Initialize lists to store data for this link
                    languages = []
                    titles = []

                    # Extract and store the language and correct title of each interlanguage link
                    for interlanguage_link in interlanguage_links:
                        lang = interlanguage_link.find("a")['lang']
                        title = interlanguage_link.find("a")['title'].split(" – ")[0]
                        languages.append(lang)
                        titles.append(title)

                    # Create a pandas DataFrame for this link
                    data = {
                        "Language": languages,
                        "Title": titles
                    }
                    df = pd.DataFrame(data)

                    # Create a CSV file name based on the link title
                    csv_file_name = f"dataframes/{link.split('/')[-1]}.csv"

                    # Save the DataFrame as a CSV file
                    df.to_csv(csv_file_name, index=False)

                    print(f"CSV saved: {csv_file_name}")

            else:
                print("No <meta> tag with property='mw:PageProp/toc' found on the page.")

        else:
            print(f"Failed to retrieve the webpage. Status code: {response.status_code}")

    except requests.exceptions.RequestException as e:
        print(f"Error: {e}")

# Example usage:
webpage_url = 'https://en.wikipedia.org/wiki/List_of_geometry_topics'
scrape_links_and_process(webpage_url)
# Out:
# Link: https://en.wikipedia.org/wiki/Absolute_geometry, Title: Absolute geometry
# Link: https://en.wikipedia.org/wiki/Affine_geometry, Title: Affine geometry
# Link: https://en.wikipedia.org/wiki/Algebraic_geometry, Title: Algebraic geometry
# Link: https://en.wikipedia.org/wiki/Analytic_geometry, Title: Analytic geometry
# Link: https://en.wikipedia.org/wiki/Archimedes%27_use_of_infinitesimals, Title: Archimedes' use of infinitesimals
# Link: https://en.wikipedia.org/wiki/Birational_geometry, Title: Birational geometry
# Link: https://en.wikipedia.org/wiki/Complex_geometry, Title: Complex geometry
# Link: https://en.wikipedia.org/wiki/Combinatorial_geometry, Title: Combinatorial geometry
# Link: https://en.wikipedia.org/wiki/Computational_geometry, Title: Computational geometry
# Link: https://en.wikipedia.org/wiki/Conformal_geometry, Title: Conformal geometry
# Link: https://en.wikipedia.org/wiki/Constructive_solid_geometry, Title: Constructive solid geometry
# Link: https://en.wikipedia.org/wiki/Contact_geometry, Title: Contact geometry
# Link: https://en.wikipedia.org/wiki/Convex_geometry, Title: Convex geometry
# Link: https://en.wikipedia.org/wiki/Descriptive_geometry, Title: Descriptive geometry
# Link: https://en.wikipedia.org/wiki/Differential_geometry, Title: Differential geometry
# Link: https://en.wikipedia.org/wiki/Digital_geometry, Title: Digital geometry
# Link: https://en.wikipedia.org/wiki/Discrete_geometry, Title: Discrete geometry
# Link: https://en.wikipedia.org/wiki/Distance_geometry, Title: Distance geometry
# Link: https://en.wikipedia.org/wiki/Elliptic_geometry, Title: Elliptic geometry
# Link: https://en.wikipedia.org/wiki/Enumerative_geometry, Title: Enumerative geometry
# Link: https://en.wikipedia.org/wiki/Epipolar_geometry, Title: Epipolar geometry
# Link: https://en.wikipedia.org/wiki/Finite_geometry, Title: Finite geometry
# Link: https://en.wikipedia.org/wiki/Fractal_geometry, Title: Fractal geometry
# Link: https://en.wikipedia.org/wiki/Geometry_of_numbers, Title: Geometry of numbers
# Link: https://en.wikipedia.org/wiki/Hyperbolic_geometry, Title: Hyperbolic geometry
# Link: https://en.wikipedia.org/wiki/Incidence_geometry, Title: Incidence geometry
# Link: https://en.wikipedia.org/wiki/Information_geometry, Title: Information geometry
# Link: https://en.wikipedia.org/wiki/Integral_geometry, Title: Integral geometry
# Link: https://en.wikipedia.org/wiki/Inversive_geometry, Title: Inversive geometry
# Link: https://en.wikipedia.org/wiki/Inversive_ring_geometry, Title: Inversive ring geometry
# Link: https://en.wikipedia.org/wiki/Klein_geometry, Title: Klein geometry
# Link: https://en.wikipedia.org/wiki/Lie_sphere_geometry, Title: Lie sphere geometry
# Link: https://en.wikipedia.org/wiki/Non-Euclidean_geometry, Title: Non-Euclidean geometry
# Link: https://en.wikipedia.org/wiki/Noncommutative_algebraic_geometry, Title: Noncommutative algebraic geometry
# Link: https://en.wikipedia.org/wiki/Noncommutative_geometry, Title: Noncommutative geometry
# Link: https://en.wikipedia.org/wiki/Computational_geometry#Numerical_computational_geometry, Title: Computational geometry
# Link: https://en.wikipedia.org/wiki/Ordered_geometry, Title: Ordered geometry
# Link: https://en.wikipedia.org/wiki/Parabolic_geometry_(differential_geometry), Title: Parabolic geometry (differential geometry)
# Link: https://en.wikipedia.org/wiki/Euclidean_plane_geometry, Title: Euclidean plane geometry
# Link: https://en.wikipedia.org/wiki/Projective_geometry, Title: Projective geometry
# Link: https://en.wikipedia.org/wiki/Quantum_geometry, Title: Quantum geometry
# Link: https://en.wikipedia.org/wiki/Riemannian_geometry, Title: Riemannian geometry
# Link: https://en.wikipedia.org/wiki/Ruppeiner_geometry, Title: Ruppeiner geometry
# Link: https://en.wikipedia.org/wiki/Spherical_geometry, Title: Spherical geometry
# Link: https://en.wikipedia.org/wiki/Symplectic_geometry, Title: Symplectic geometry
# Link: https://en.wikipedia.org/wiki/Synthetic_geometry, Title: Synthetic geometry
# Link: https://en.wikipedia.org/wiki/Systolic_geometry, Title: Systolic geometry
# Link: https://en.wikipedia.org/wiki/Taxicab_geometry, Title: Taxicab geometry
# Link: https://en.wikipedia.org/wiki/Toric_geometry, Title: Toric geometry
# Link: https://en.wikipedia.org/wiki/Transformation_geometry, Title: Transformation geometry
# Link: https://en.wikipedia.org/wiki/Tropical_geometry, Title: Tropical geometry
# CSV saved: dataframes/Absolute_geometry.csv
# CSV saved: dataframes/Affine_geometry.csv
# CSV saved: dataframes/Algebraic_geometry.csv
# CSV saved: dataframes/Analytic_geometry.csv
# CSV saved: dataframes/Archimedes%27_use_of_infinitesimals.csv
# CSV saved: dataframes/Birational_geometry.csv
# CSV saved: dataframes/Complex_geometry.csv
# CSV saved: dataframes/Combinatorial_geometry.csv
# CSV saved: dataframes/Computational_geometry.csv
# CSV saved: dataframes/Conformal_geometry.csv
# CSV saved: dataframes/Constructive_solid_geometry.csv
# CSV saved: dataframes/Contact_geometry.csv
# CSV saved: dataframes/Convex_geometry.csv
# CSV saved: dataframes/Descriptive_geometry.csv
# CSV saved: dataframes/Differential_geometry.csv
# CSV saved: dataframes/Digital_geometry.csv
# CSV saved: dataframes/Discrete_geometry.csv
# CSV saved: dataframes/Distance_geometry.csv
# CSV saved: dataframes/Elliptic_geometry.csv
# CSV saved: dataframes/Enumerative_geometry.csv
# CSV saved: dataframes/Epipolar_geometry.csv
# CSV saved: dataframes/Finite_geometry.csv
# CSV saved: dataframes/Fractal_geometry.csv
# CSV saved: dataframes/Geometry_of_numbers.csv
# CSV saved: dataframes/Hyperbolic_geometry.csv
# CSV saved: dataframes/Incidence_geometry.csv
# CSV saved: dataframes/Information_geometry.csv
# CSV saved: dataframes/Integral_geometry.csv
# CSV saved: dataframes/Inversive_geometry.csv
# CSV saved: dataframes/Inversive_ring_geometry.csv
# CSV saved: dataframes/Klein_geometry.csv
# CSV saved: dataframes/Lie_sphere_geometry.csv
# CSV saved: dataframes/Non-Euclidean_geometry.csv
# CSV saved: dataframes/Noncommutative_algebraic_geometry.csv
# CSV saved: dataframes/Noncommutative_geometry.csv
# CSV saved: dataframes/Computational_geometry#Numerical_computational_geometry.csv
# CSV saved: dataframes/Ordered_geometry.csv
# CSV saved: dataframes/Parabolic_geometry_(differential_geometry).csv
# CSV saved: dataframes/Euclidean_plane_geometry.csv
# CSV saved: dataframes/Projective_geometry.csv
# CSV saved: dataframes/Quantum_geometry.csv
# CSV saved: dataframes/Riemannian_geometry.csv
# CSV saved: dataframes/Ruppeiner_geometry.csv
# CSV saved: dataframes/Spherical_geometry.csv
# CSV saved: dataframes/Symplectic_geometry.csv
# CSV saved: dataframes/Synthetic_geometry.csv
# CSV saved: dataframes/Systolic_geometry.csv
# CSV saved: dataframes/Taxicab_geometry.csv
# CSV saved: dataframes/Toric_geometry.csv
# CSV saved: dataframes/Transformation_geometry.csv
# CSV saved: dataframes/Tropical_geometry.csv

# %%
webpage_url = 'https://en.wikipedia.org/wiki/List_of_geometry_topics'
scrape_links_and_process(webpage_url)
# Out:
# Link: https://en.wikipedia.org/wiki/Absolute_geometry, Title: Absolute geometry
# Link: https://en.wikipedia.org/wiki/Affine_geometry, Title: Affine geometry
# Link: https://en.wikipedia.org/wiki/Algebraic_geometry, Title: Algebraic geometry
# Link: https://en.wikipedia.org/wiki/Analytic_geometry, Title: Analytic geometry
# Link: https://en.wikipedia.org/wiki/Archimedes%27_use_of_infinitesimals, Title: Archimedes' use of infinitesimals
# Link: https://en.wikipedia.org/wiki/Birational_geometry, Title: Birational geometry
# Link: https://en.wikipedia.org/wiki/Complex_geometry, Title: Complex geometry
# Link: https://en.wikipedia.org/wiki/Combinatorial_geometry, Title: Combinatorial geometry
# Link: https://en.wikipedia.org/wiki/Computational_geometry, Title: Computational geometry
# Link: https://en.wikipedia.org/wiki/Conformal_geometry, Title: Conformal geometry
# Link: https://en.wikipedia.org/wiki/Constructive_solid_geometry, Title: Constructive solid geometry
# Link: https://en.wikipedia.org/wiki/Contact_geometry, Title: Contact geometry
# Link: https://en.wikipedia.org/wiki/Convex_geometry, Title: Convex geometry
# Link: https://en.wikipedia.org/wiki/Descriptive_geometry, Title: Descriptive geometry
# Link: https://en.wikipedia.org/wiki/Differential_geometry, Title: Differential geometry
# Link: https://en.wikipedia.org/wiki/Digital_geometry, Title: Digital geometry
# Link: https://en.wikipedia.org/wiki/Discrete_geometry, Title: Discrete geometry
# Link: https://en.wikipedia.org/wiki/Distance_geometry, Title: Distance geometry
# Link: https://en.wikipedia.org/wiki/Elliptic_geometry, Title: Elliptic geometry
# Link: https://en.wikipedia.org/wiki/Enumerative_geometry, Title: Enumerative geometry
# Link: https://en.wikipedia.org/wiki/Epipolar_geometry, Title: Epipolar geometry
# Link: https://en.wikipedia.org/wiki/Finite_geometry, Title: Finite geometry
# Link: https://en.wikipedia.org/wiki/Fractal_geometry, Title: Fractal geometry
# Link: https://en.wikipedia.org/wiki/Geometry_of_numbers, Title: Geometry of numbers
# Link: https://en.wikipedia.org/wiki/Hyperbolic_geometry, Title: Hyperbolic geometry
# Link: https://en.wikipedia.org/wiki/Incidence_geometry, Title: Incidence geometry
# Link: https://en.wikipedia.org/wiki/Information_geometry, Title: Information geometry
# Link: https://en.wikipedia.org/wiki/Integral_geometry, Title: Integral geometry
# Link: https://en.wikipedia.org/wiki/Inversive_geometry, Title: Inversive geometry
# Link: https://en.wikipedia.org/wiki/Inversive_ring_geometry, Title: Inversive ring geometry
# Link: https://en.wikipedia.org/wiki/Klein_geometry, Title: Klein geometry
# Link: https://en.wikipedia.org/wiki/Lie_sphere_geometry, Title: Lie sphere geometry
# Link: https://en.wikipedia.org/wiki/Non-Euclidean_geometry, Title: Non-Euclidean geometry
# Link: https://en.wikipedia.org/wiki/Noncommutative_algebraic_geometry, Title: Noncommutative algebraic geometry
# Link: https://en.wikipedia.org/wiki/Noncommutative_geometry, Title: Noncommutative geometry
# Link: https://en.wikipedia.org/wiki/Computational_geometry#Numerical_computational_geometry, Title: Computational geometry
# Link: https://en.wikipedia.org/wiki/Ordered_geometry, Title: Ordered geometry
# Link: https://en.wikipedia.org/wiki/Parabolic_geometry_(differential_geometry), Title: Parabolic geometry (differential geometry)
# Link: https://en.wikipedia.org/wiki/Euclidean_plane_geometry, Title: Euclidean plane geometry
# Link: https://en.wikipedia.org/wiki/Projective_geometry, Title: Projective geometry
# Link: https://en.wikipedia.org/wiki/Quantum_geometry, Title: Quantum geometry
# Link: https://en.wikipedia.org/wiki/Riemannian_geometry, Title: Riemannian geometry
# Link: https://en.wikipedia.org/wiki/Ruppeiner_geometry, Title: Ruppeiner geometry
# Link: https://en.wikipedia.org/wiki/Spherical_geometry, Title: Spherical geometry
# Link: https://en.wikipedia.org/wiki/Symplectic_geometry, Title: Symplectic geometry
# Link: https://en.wikipedia.org/wiki/Synthetic_geometry, Title: Synthetic geometry
# Link: https://en.wikipedia.org/wiki/Systolic_geometry, Title: Systolic geometry
# Link: https://en.wikipedia.org/wiki/Taxicab_geometry, Title: Taxicab geometry
# Link: https://en.wikipedia.org/wiki/Toric_geometry, Title: Toric geometry
# Link: https://en.wikipedia.org/wiki/Transformation_geometry, Title: Transformation geometry
# Link: https://en.wikipedia.org/wiki/Tropical_geometry, Title: Tropical geometry
# CSV saved: dataframes/Absolute_geometry.csv
# CSV saved: dataframes/Affine_geometry.csv
# CSV saved: dataframes/Algebraic_geometry.csv
# CSV saved: dataframes/Analytic_geometry.csv
# CSV saved: dataframes/Archimedes%27_use_of_infinitesimals.csv
# CSV saved: dataframes/Birational_geometry.csv
# CSV saved: dataframes/Complex_geometry.csv
# CSV saved: dataframes/Combinatorial_geometry.csv
# CSV saved: dataframes/Computational_geometry.csv
# CSV saved: dataframes/Conformal_geometry.csv
# CSV saved: dataframes/Constructive_solid_geometry.csv
# CSV saved: dataframes/Contact_geometry.csv
# CSV saved: dataframes/Convex_geometry.csv
# CSV saved: dataframes/Descriptive_geometry.csv
# CSV saved: dataframes/Differential_geometry.csv
# CSV saved: dataframes/Digital_geometry.csv
# CSV saved: dataframes/Discrete_geometry.csv
# CSV saved: dataframes/Distance_geometry.csv
# CSV saved: dataframes/Elliptic_geometry.csv
# CSV saved: dataframes/Enumerative_geometry.csv
# CSV saved: dataframes/Epipolar_geometry.csv
# CSV saved: dataframes/Finite_geometry.csv
# CSV saved: dataframes/Fractal_geometry.csv
# CSV saved: dataframes/Geometry_of_numbers.csv
# CSV saved: dataframes/Hyperbolic_geometry.csv
# CSV saved: dataframes/Incidence_geometry.csv
# CSV saved: dataframes/Information_geometry.csv
# CSV saved: dataframes/Integral_geometry.csv
# CSV saved: dataframes/Inversive_geometry.csv
# CSV saved: dataframes/Inversive_ring_geometry.csv
# CSV saved: dataframes/Klein_geometry.csv
# CSV saved: dataframes/Lie_sphere_geometry.csv
# CSV saved: dataframes/Non-Euclidean_geometry.csv
# CSV saved: dataframes/Noncommutative_algebraic_geometry.csv
# CSV saved: dataframes/Noncommutative_geometry.csv
# CSV saved: dataframes/Computational_geometry#Numerical_computational_geometry.csv
# CSV saved: dataframes/Ordered_geometry.csv
# CSV saved: dataframes/Parabolic_geometry_(differential_geometry).csv
# CSV saved: dataframes/Euclidean_plane_geometry.csv
# CSV saved: dataframes/Projective_geometry.csv
# CSV saved: dataframes/Quantum_geometry.csv
# CSV saved: dataframes/Riemannian_geometry.csv
# CSV saved: dataframes/Ruppeiner_geometry.csv
# CSV saved: dataframes/Spherical_geometry.csv
# CSV saved: dataframes/Symplectic_geometry.csv
# CSV saved: dataframes/Synthetic_geometry.csv
# CSV saved: dataframes/Systolic_geometry.csv
# CSV saved: dataframes/Taxicab_geometry.csv
# CSV saved: dataframes/Toric_geometry.csv
# CSV saved: dataframes/Transformation_geometry.csv
# CSV saved: dataframes/Tropical_geometry.csv

# %%
import requests
from bs4 import BeautifulSoup

def get_links(webpage_url):
    formatted_links = []  # Create an empty list to store the URLs
    
    try:
        # Send an HTTP GET request to the webpage_url
        response = requests.get(webpage_url)

        # Check if the request was successful (status code 200)
        if response.status_code == 200:
            # Parse the HTML content of the webpage
            soup = BeautifulSoup(response.content, 'html.parser')

            # Find the <meta> tag with property="mw:PageProp/toc"
            toc_meta_tag = soup.find('meta', attrs={'property': 'mw:PageProp/toc'})

            # Check if the <meta> tag exists
            if toc_meta_tag:
                # Find the <ul> (unordered list) tag that follows the <meta> tag
                ul_tag = toc_meta_tag.find_next('ul')

                # Find all the <a> (anchor) tags within the <ul> tag
                links = ul_tag.find_all('a')

                # Extract and append the href attribute of each <a> tag to the formatted_links list
                for link in links:
                    href = link.get('href')
                    formatted_link = f"https://en.wikipedia.org{href}"
                    formatted_links.append(formatted_link)  # Append the formatted URL to the list
                    title = link.get('title')
                    # Optionally, you can print the links if needed
                    # print(f"Link: {formatted_link}, Title: {title}")

            else:
                print("No <meta> tag with property='mw:PageProp/toc' found on the page.")

        else:
            print(f"Failed to retrieve the webpage. Status code: {response.status_code}")

    except requests.exceptions.RequestException as e:
        print(f"Error: {e}")
    
    return formatted_links  # Return the list of formatted links

# Example usage:
webpage_url = 'https://en.wikipedia.org/wiki/List_of_geometry_topics'
formatted_links = get_links(webpage_url)
# Now, formatted_links contains all the URLs extracted from the webpage.
formatted_links
# Out:
# ['https://en.wikipedia.org/wiki/Absolute_geometry',
#  'https://en.wikipedia.org/wiki/Affine_geometry',
#  'https://en.wikipedia.org/wiki/Algebraic_geometry',
#  'https://en.wikipedia.org/wiki/Analytic_geometry',
#  'https://en.wikipedia.org/wiki/Archimedes%27_use_of_infinitesimals',
#  'https://en.wikipedia.org/wiki/Birational_geometry',
#  'https://en.wikipedia.org/wiki/Complex_geometry',
#  'https://en.wikipedia.org/wiki/Combinatorial_geometry',
#  'https://en.wikipedia.org/wiki/Computational_geometry',
#  'https://en.wikipedia.org/wiki/Conformal_geometry',
#  'https://en.wikipedia.org/wiki/Constructive_solid_geometry',
#  'https://en.wikipedia.org/wiki/Contact_geometry',
#  'https://en.wikipedia.org/wiki/Convex_geometry',
#  'https://en.wikipedia.org/wiki/Descriptive_geometry',
#  'https://en.wikipedia.org/wiki/Differential_geometry',
#  'https://en.wikipedia.org/wiki/Digital_geometry',
#  'https://en.wikipedia.org/wiki/Discrete_geometry',
#  'https://en.wikipedia.org/wiki/Distance_geometry',
#  'https://en.wikipedia.org/wiki/Elliptic_geometry',
#  'https://en.wikipedia.org/wiki/Enumerative_geometry',
#  'https://en.wikipedia.org/wiki/Epipolar_geometry',
#  'https://en.wikipedia.org/wiki/Finite_geometry',
#  'https://en.wikipedia.org/wiki/Fractal_geometry',
#  'https://en.wikipedia.org/wiki/Geometry_of_numbers',
#  'https://en.wikipedia.org/wiki/Hyperbolic_geometry',
#  'https://en.wikipedia.org/wiki/Incidence_geometry',
#  'https://en.wikipedia.org/wiki/Information_geometry',
#  'https://en.wikipedia.org/wiki/Integral_geometry',
#  'https://en.wikipedia.org/wiki/Inversive_geometry',
#  'https://en.wikipedia.org/wiki/Inversive_ring_geometry',
#  'https://en.wikipedia.org/wiki/Klein_geometry',
#  'https://en.wikipedia.org/wiki/Lie_sphere_geometry',
#  'https://en.wikipedia.org/wiki/Non-Euclidean_geometry',
#  'https://en.wikipedia.org/wiki/Noncommutative_algebraic_geometry',
#  'https://en.wikipedia.org/wiki/Noncommutative_geometry',
#  'https://en.wikipedia.org/wiki/Computational_geometry#Numerical_computational_geometry',
#  'https://en.wikipedia.org/wiki/Ordered_geometry',
#  'https://en.wikipedia.org/wiki/Parabolic_geometry_(differential_geometry)',
#  'https://en.wikipedia.org/wiki/Euclidean_plane_geometry',
#  'https://en.wikipedia.org/wiki/Projective_geometry',
#  'https://en.wikipedia.org/wiki/Quantum_geometry',
#  'https://en.wikipedia.org/wiki/Riemannian_geometry',
#  'https://en.wikipedia.org/wiki/Ruppeiner_geometry',
#  'https://en.wikipedia.org/wiki/Spherical_geometry',
#  'https://en.wikipedia.org/wiki/Symplectic_geometry',
#  'https://en.wikipedia.org/wiki/Synthetic_geometry',
#  'https://en.wikipedia.org/wiki/Systolic_geometry',
#  'https://en.wikipedia.org/wiki/Taxicab_geometry',
#  'https://en.wikipedia.org/wiki/Toric_geometry',
#  'https://en.wikipedia.org/wiki/Transformation_geometry',
#  'https://en.wikipedia.org/wiki/Tropical_geometry']

# %%
def two_level_scrape_links_and_process(webpage_url):
    links = get_links(webpage_url)
    
    for link in links:
        scrape_links_and_process(link)

webpage_url = 'https://en.wikipedia.org/wiki/Lists_of_mathematics_topics'
two_level_scrape_links_and_process(webpage_url)
# Out:
# Link: https://en.wikipedia.org/wiki/Elementary_arithmetic, Title: Elementary arithmetic
# Link: https://en.wikipedia.org/wiki/Decimal_arithmetic, Title: Decimal arithmetic
# Link: https://en.wikipedia.org/wiki/Decimal_point, Title: Decimal point
# Link: https://en.wikipedia.org/wiki/Numeral_system, Title: Numeral system
# Link: https://en.wikipedia.org/wiki/Place_value, Title: Place value
# Link: https://en.wikipedia.org/wiki/Face_value, Title: Face value
# CSV saved: dataframes/Elementary_arithmetic.csv
# CSV saved: dataframes/Decimal_arithmetic.csv
# CSV saved: dataframes/Decimal_point.csv
# CSV saved: dataframes/Numeral_system.csv
# CSV saved: dataframes/Place_value.csv
# CSV saved: dataframes/Face_value.csv
# Link: https://en.wikipedia.org/wiki/Logic, Title: Logic
# CSV saved: dataframes/Logic.csv
# Link: https://en.wikipedia.org/wiki/Limit_(mathematics), Title: Limit (mathematics)
# Link: https://en.wikipedia.org/wiki/Limit_of_a_function, Title: Limit of a function
# Link: https://en.wikipedia.org/wiki/One-sided_limit, Title: One-sided limit
# Link: https://en.wikipedia.org/wiki/Limit_of_a_sequence, Title: Limit of a sequence
# Link: https://en.wikipedia.org/wiki/Indeterminate_form, Title: Indeterminate form
# Link: https://en.wikipedia.org/wiki/Orders_of_approximation, Title: Orders of approximation
# Link: https://en.wikipedia.org/wiki/(%CE%B5,_%CE%B4)-definition_of_limit, Title: (ε, δ)-definition of limit
# Link: https://en.wikipedia.org/wiki/Continuous_function, Title: Continuous function
# CSV saved: dataframes/Limit_(mathematics).csv
# CSV saved: dataframes/Limit_of_a_function.csv
# CSV saved: dataframes/One-sided_limit.csv
# CSV saved: dataframes/Limit_of_a_sequence.csv
# CSV saved: dataframes/Indeterminate_form.csv
# CSV saved: dataframes/Orders_of_approximation.csv
# CSV saved: dataframes/(%CE%B5,_%CE%B4)-definition_of_limit.csv
# CSV saved: dataframes/Continuous_function.csv
# Link: https://en.wikipedia.org/wiki/Absolute_geometry, Title: Absolute geometry
# Link: https://en.wikipedia.org/wiki/Affine_geometry, Title: Affine geometry
# Link: https://en.wikipedia.org/wiki/Algebraic_geometry, Title: Algebraic geometry
# Link: https://en.wikipedia.org/wiki/Analytic_geometry, Title: Analytic geometry
# Link: https://en.wikipedia.org/wiki/Archimedes%27_use_of_infinitesimals, Title: Archimedes' use of infinitesimals
# Link: https://en.wikipedia.org/wiki/Birational_geometry, Title: Birational geometry
# Link: https://en.wikipedia.org/wiki/Complex_geometry, Title: Complex geometry
# Link: https://en.wikipedia.org/wiki/Combinatorial_geometry, Title: Combinatorial geometry
# Link: https://en.wikipedia.org/wiki/Computational_geometry, Title: Computational geometry
# Link: https://en.wikipedia.org/wiki/Conformal_geometry, Title: Conformal geometry
# Link: https://en.wikipedia.org/wiki/Constructive_solid_geometry, Title: Constructive solid geometry
# Link: https://en.wikipedia.org/wiki/Contact_geometry, Title: Contact geometry
# Link: https://en.wikipedia.org/wiki/Convex_geometry, Title: Convex geometry
# Link: https://en.wikipedia.org/wiki/Descriptive_geometry, Title: Descriptive geometry
# Link: https://en.wikipedia.org/wiki/Differential_geometry, Title: Differential geometry
# Link: https://en.wikipedia.org/wiki/Digital_geometry, Title: Digital geometry
# Link: https://en.wikipedia.org/wiki/Discrete_geometry, Title: Discrete geometry
# Link: https://en.wikipedia.org/wiki/Distance_geometry, Title: Distance geometry
# Link: https://en.wikipedia.org/wiki/Elliptic_geometry, Title: Elliptic geometry
# Link: https://en.wikipedia.org/wiki/Enumerative_geometry, Title: Enumerative geometry
# Link: https://en.wikipedia.org/wiki/Epipolar_geometry, Title: Epipolar geometry
# Link: https://en.wikipedia.org/wiki/Finite_geometry, Title: Finite geometry
# Link: https://en.wikipedia.org/wiki/Fractal_geometry, Title: Fractal geometry
# Link: https://en.wikipedia.org/wiki/Geometry_of_numbers, Title: Geometry of numbers
# Link: https://en.wikipedia.org/wiki/Hyperbolic_geometry, Title: Hyperbolic geometry
# Link: https://en.wikipedia.org/wiki/Incidence_geometry, Title: Incidence geometry
# Link: https://en.wikipedia.org/wiki/Information_geometry, Title: Information geometry
# Link: https://en.wikipedia.org/wiki/Integral_geometry, Title: Integral geometry
# Link: https://en.wikipedia.org/wiki/Inversive_geometry, Title: Inversive geometry
# Link: https://en.wikipedia.org/wiki/Inversive_ring_geometry, Title: Inversive ring geometry
# Link: https://en.wikipedia.org/wiki/Klein_geometry, Title: Klein geometry
# Link: https://en.wikipedia.org/wiki/Lie_sphere_geometry, Title: Lie sphere geometry
# Link: https://en.wikipedia.org/wiki/Non-Euclidean_geometry, Title: Non-Euclidean geometry
# Link: https://en.wikipedia.org/wiki/Noncommutative_algebraic_geometry, Title: Noncommutative algebraic geometry
# Link: https://en.wikipedia.org/wiki/Noncommutative_geometry, Title: Noncommutative geometry
# Link: https://en.wikipedia.org/wiki/Computational_geometry#Numerical_computational_geometry, Title: Computational geometry
# Link: https://en.wikipedia.org/wiki/Ordered_geometry, Title: Ordered geometry
# Link: https://en.wikipedia.org/wiki/Parabolic_geometry_(differential_geometry), Title: Parabolic geometry (differential geometry)
# Link: https://en.wikipedia.org/wiki/Euclidean_plane_geometry, Title: Euclidean plane geometry
# Link: https://en.wikipedia.org/wiki/Projective_geometry, Title: Projective geometry
# Link: https://en.wikipedia.org/wiki/Quantum_geometry, Title: Quantum geometry
# Link: https://en.wikipedia.org/wiki/Riemannian_geometry, Title: Riemannian geometry
# Link: https://en.wikipedia.org/wiki/Ruppeiner_geometry, Title: Ruppeiner geometry
# Link: https://en.wikipedia.org/wiki/Spherical_geometry, Title: Spherical geometry
# Link: https://en.wikipedia.org/wiki/Symplectic_geometry, Title: Symplectic geometry
# Link: https://en.wikipedia.org/wiki/Synthetic_geometry, Title: Synthetic geometry
# Link: https://en.wikipedia.org/wiki/Systolic_geometry, Title: Systolic geometry
# Link: https://en.wikipedia.org/wiki/Taxicab_geometry, Title: Taxicab geometry
# Link: https://en.wikipedia.org/wiki/Toric_geometry, Title: Toric geometry
# Link: https://en.wikipedia.org/wiki/Transformation_geometry, Title: Transformation geometry
# Link: https://en.wikipedia.org/wiki/Tropical_geometry, Title: Tropical geometry
# CSV saved: dataframes/Absolute_geometry.csv
# CSV saved: dataframes/Affine_geometry.csv
# CSV saved: dataframes/Algebraic_geometry.csv
# CSV saved: dataframes/Analytic_geometry.csv
# CSV saved: dataframes/Archimedes%27_use_of_infinitesimals.csv
# CSV saved: dataframes/Birational_geometry.csv
# CSV saved: dataframes/Complex_geometry.csv
# CSV saved: dataframes/Combinatorial_geometry.csv
# CSV saved: dataframes/Computational_geometry.csv
# CSV saved: dataframes/Conformal_geometry.csv
# CSV saved: dataframes/Constructive_solid_geometry.csv
# CSV saved: dataframes/Contact_geometry.csv
# CSV saved: dataframes/Convex_geometry.csv
# CSV saved: dataframes/Descriptive_geometry.csv
# CSV saved: dataframes/Differential_geometry.csv
# CSV saved: dataframes/Digital_geometry.csv
# CSV saved: dataframes/Discrete_geometry.csv
# CSV saved: dataframes/Distance_geometry.csv
# CSV saved: dataframes/Elliptic_geometry.csv
# CSV saved: dataframes/Enumerative_geometry.csv
# CSV saved: dataframes/Epipolar_geometry.csv
# CSV saved: dataframes/Finite_geometry.csv
# CSV saved: dataframes/Fractal_geometry.csv
# CSV saved: dataframes/Geometry_of_numbers.csv
# CSV saved: dataframes/Hyperbolic_geometry.csv
# CSV saved: dataframes/Incidence_geometry.csv
# CSV saved: dataframes/Information_geometry.csv
# CSV saved: dataframes/Integral_geometry.csv
# CSV saved: dataframes/Inversive_geometry.csv
# CSV saved: dataframes/Inversive_ring_geometry.csv
# CSV saved: dataframes/Klein_geometry.csv
# CSV saved: dataframes/Lie_sphere_geometry.csv
# CSV saved: dataframes/Non-Euclidean_geometry.csv
# CSV saved: dataframes/Noncommutative_algebraic_geometry.csv
# CSV saved: dataframes/Noncommutative_geometry.csv
# CSV saved: dataframes/Computational_geometry#Numerical_computational_geometry.csv
# CSV saved: dataframes/Ordered_geometry.csv
# CSV saved: dataframes/Parabolic_geometry_(differential_geometry).csv
# CSV saved: dataframes/Euclidean_plane_geometry.csv
# CSV saved: dataframes/Projective_geometry.csv
# CSV saved: dataframes/Quantum_geometry.csv
# CSV saved: dataframes/Riemannian_geometry.csv
# CSV saved: dataframes/Ruppeiner_geometry.csv
# CSV saved: dataframes/Spherical_geometry.csv
# CSV saved: dataframes/Symplectic_geometry.csv
# CSV saved: dataframes/Synthetic_geometry.csv
# CSV saved: dataframes/Systolic_geometry.csv
# CSV saved: dataframes/Taxicab_geometry.csv
# CSV saved: dataframes/Toric_geometry.csv
# CSV saved: dataframes/Transformation_geometry.csv
# CSV saved: dataframes/Tropical_geometry.csv
# Link: https://en.wikipedia.org/wiki/Geometry, Title: Geometry
# Link: https://en.wikipedia.org/wiki/Analytic_geometry, Title: Analytic geometry
# Link: https://en.wikipedia.org/wiki/Differential_geometry, Title: Differential geometry
# Link: https://en.wikipedia.org/wiki/Euclidean_geometry, Title: Euclidean geometry
# Link: https://en.wikipedia.org/wiki/Non-Euclidean_geometry, Title: Non-Euclidean geometry
# Link: https://en.wikipedia.org/wiki/Projective_geometry, Title: Projective geometry
# Link: https://en.wikipedia.org/wiki/Riemannian_geometry, Title: Riemannian geometry
# CSV saved: dataframes/Geometry.csv
# CSV saved: dataframes/Analytic_geometry.csv
# CSV saved: dataframes/Differential_geometry.csv
# CSV saved: dataframes/Euclidean_geometry.csv
# CSV saved: dataframes/Non-Euclidean_geometry.csv
# CSV saved: dataframes/Projective_geometry.csv
# CSV saved: dataframes/Riemannian_geometry.csv
# Link: https://en.wikipedia.org/wiki/Geometry, Title: Geometry
# Link: https://en.wikipedia.org/wiki/Angle, Title: Angle
# Link: https://en.wikipedia.org/wiki/Ratio, Title: Ratio
# CSV saved: dataframes/Geometry.csv
# CSV saved: dataframes/Angle.csv
# CSV saved: dataframes/Ratio.csv
# Link: https://en.wikipedia.org/wiki/Geometry, Title: Geometry
# Link: https://en.wikipedia.org/wiki/Angle, Title: Angle
# Link: https://en.wikipedia.org/wiki/Ratio, Title: Ratio
# CSV saved: dataframes/Geometry.csv
# CSV saved: dataframes/Angle.csv
# CSV saved: dataframes/Ratio.csv
# Link: https://en.wikipedia.org/wiki/Natural_logarithm, Title: Natural logarithm
# Link: https://en.wikipedia.org/wiki/Arg_(mathematics), Title: Arg (mathematics)
# Link: https://en.wikipedia.org/wiki/Atan2, Title: Atan2
# CSV saved: dataframes/Natural_logarithm.csv
# CSV saved: dataframes/Arg_(mathematics).csv
# CSV saved: dataframes/Atan2.csv
# Link: https://en.wikipedia.org/wiki/List_of_mathematical_identities, Title: List of mathematical identities
# Link: https://en.wikipedia.org/wiki/Lists_of_mathematics_topics, Title: Lists of mathematics topics
# CSV saved: dataframes/List_of_mathematical_identities.csv
# CSV saved: dataframes/Lists_of_mathematics_topics.csv
# Link: https://en.wikipedia.org/wiki/Analytic-synthetic_distinction, Title: Analytic-synthetic distinction
# Link: https://en.wikipedia.org/wiki/Antinomy, Title: Antinomy
# Link: https://en.wikipedia.org/wiki/A_priori_and_a_posteriori, Title: A priori and a posteriori
# Link: https://en.wikipedia.org/wiki/Definition, Title: Definition
# Link: https://en.wikipedia.org/wiki/Description, Title: Description
# Link: https://en.wikipedia.org/wiki/Entailment, Title: Entailment
# Link: https://en.wikipedia.org/wiki/Identity_(philosophy), Title: Identity (philosophy)
# Link: https://en.wikipedia.org/wiki/Inference, Title: Inference
# Link: https://en.wikipedia.org/wiki/Logical_form, Title: Logical form
# Link: https://en.wikipedia.org/wiki/Logical_implication, Title: Logical implication
# Link: https://en.wikipedia.org/wiki/Logical_truth, Title: Logical truth
# Link: https://en.wikipedia.org/wiki/Logical_consequence, Title: Logical consequence
# Link: https://en.wikipedia.org/wiki/Name, Title: Name
# Link: https://en.wikipedia.org/wiki/Necessary_and_sufficient_condition, Title: Necessary and sufficient condition
# Link: https://en.wikipedia.org/wiki/Material_conditional, Title: Material conditional
# Link: https://en.wikipedia.org/wiki/Meaning_(linguistic), Title: Meaning (linguistic)
# Link: https://en.wikipedia.org/wiki/Meaning_(non-linguistic), Title: Meaning (non-linguistic)
# Link: https://en.wikipedia.org/wiki/Paradox, Title: Paradox
# Link: https://en.wikipedia.org/wiki/List_of_paradoxes, Title: List of paradoxes
# Link: https://en.wikipedia.org/wiki/Possible_world, Title: Possible world
# Link: https://en.wikipedia.org/wiki/Presupposition, Title: Presupposition
# Link: https://en.wikipedia.org/wiki/Probability, Title: Probability
# Link: https://en.wikipedia.org/wiki/Quantification_(logic), Title: Quantification (logic)
# Link: https://en.wikipedia.org/wiki/Reason, Title: Reason
# Link: https://en.wikipedia.org/wiki/Reasoning, Title: Reasoning
# Link: https://en.wikipedia.org/wiki/Reference, Title: Reference
# Link: https://en.wikipedia.org/wiki/Semantics, Title: Semantics
# Link: https://en.wikipedia.org/wiki/Strict_conditional, Title: Strict conditional
# Link: https://en.wikipedia.org/wiki/Syntax_(logic), Title: Syntax (logic)
# Link: https://en.wikipedia.org/wiki/Truth, Title: Truth
# Link: https://en.wikipedia.org/wiki/Truth_value, Title: Truth value
# Link: https://en.wikipedia.org/wiki/Validity_(logic), Title: Validity (logic)
# CSV saved: dataframes/Analytic-synthetic_distinction.csv
# CSV saved: dataframes/Antinomy.csv
# CSV saved: dataframes/A_priori_and_a_posteriori.csv
# CSV saved: dataframes/Definition.csv
# CSV saved: dataframes/Description.csv
# CSV saved: dataframes/Entailment.csv
# CSV saved: dataframes/Identity_(philosophy).csv
# CSV saved: dataframes/Inference.csv
# CSV saved: dataframes/Logical_form.csv
# CSV saved: dataframes/Logical_implication.csv
# CSV saved: dataframes/Logical_truth.csv
# CSV saved: dataframes/Logical_consequence.csv
# CSV saved: dataframes/Name.csv
# CSV saved: dataframes/Necessary_and_sufficient_condition.csv
# CSV saved: dataframes/Material_conditional.csv
# CSV saved: dataframes/Meaning_(linguistic).csv
# CSV saved: dataframes/Meaning_(non-linguistic).csv
# CSV saved: dataframes/Paradox.csv
# CSV saved: dataframes/List_of_paradoxes.csv
# CSV saved: dataframes/Possible_world.csv
# CSV saved: dataframes/Presupposition.csv
# CSV saved: dataframes/Probability.csv
# CSV saved: dataframes/Quantification_(logic).csv
# CSV saved: dataframes/Reason.csv
# CSV saved: dataframes/Reasoning.csv
# CSV saved: dataframes/Reference.csv
# CSV saved: dataframes/Semantics.csv
# CSV saved: dataframes/Strict_conditional.csv
# CSV saved: dataframes/Syntax_(logic).csv
# CSV saved: dataframes/Truth.csv
# CSV saved: dataframes/Truth_value.csv
# CSV saved: dataframes/Validity_(logic).csv

# %%
# Read the existing CSV file 'Ratio.csv' into a DataFrame
df = pd.read_csv('dataframes/Ratio.csv')

# Create a new DataFrame for the desired columns
new_df = pd.DataFrame(columns=['Language', 'Translation'])

# Add 'en' row with the formatted title
formatted_title = 'Ratio'
new_df = new_df.append({'Language': 'en', 'Translation': formatted_title}, ignore_index=True)

# Add 'es' row with the Spanish translation
spanish_translation = df[df['Language'] == 'es']['Title'].values[0] if 'es' in df['Language'].values else 'NaN'
new_df = new_df.append({'Language': 'es', 'Translation': spanish_translation}, ignore_index=True)

# Add 'de' row with the German translation
german_translation = df[df['Language'] == 'de']['Title'].values[0] if 'de' in df['Language'].values else 'NaN'
new_df = new_df.append({'Language': 'de', 'Translation': german_translation}, ignore_index=True)

# Save the new DataFrame to a CSV file
new_df.to_csv('Translated_Ratio.csv', index=False)
# Out:
# /var/folders/yg/vf04jxqn61n13pv3jz4p4l_h0000gn/T/ipykernel_1810/283408777.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df = new_df.append({'Language': 'en', 'Translation': formatted_title}, ignore_index=True)
# /var/folders/yg/vf04jxqn61n13pv3jz4p4l_h0000gn/T/ipykernel_1810/283408777.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df = new_df.append({'Language': 'es', 'Translation': spanish_translation}, ignore_index=True)
# /var/folders/yg/vf04jxqn61n13pv3jz4p4l_h0000gn/T/ipykernel_1810/283408777.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df = new_df.append({'Language': 'de', 'Translation': german_translation}, ignore_index=True)

# %%
import pandas as pd

# Read the existing CSV file 'Ratio.csv' into a DataFrame
df = pd.read_csv('dataframes/Ratio.csv')

# Create a new DataFrame for the desired columns
new_df = pd.DataFrame(columns=['Language', 'Translation'])

# Add 'en' row with the formatted title
formatted_title = 'Ratio'
new_row_en = pd.DataFrame({'Language': ['en'], 'Translation': [formatted_title]})
new_df = pd.concat([new_df, new_row_en], ignore_index=True)

# Add 'es' row with the Spanish translation
spanish_translation = df[df['Language'] == 'es']['Title'].values[0] if 'es' in df['Language'].values else 'NaN'
new_row_es = pd.DataFrame({'Language': ['es'], 'Translation': [spanish_translation]})
new_df = pd.concat([new_df, new_row_es], ignore_index=True)

# Add 'de' row with the German translation
german_translation = df[df['Language'] == 'de']['Title'].values[0] if 'de' in df['Language'].values else 'NaN'
new_row_de = pd.DataFrame({'Language': ['de'], 'Translation': [german_translation]})
new_df = pd.concat([new_df, new_row_de], ignore_index=True)

# Save the new DataFrame to a CSV file in the 'dataframes' folder
new_df.to_csv('dataframes/Translated_Ratio.csv', index=False)

# %%
import pandas as pd

def add_translated_row_to_csv(csv_file_path):
    
    original_csv_name = os.path.splitext(os.path.basename(csv_file_path))[0]

    # Read the existing CSV file into a DataFrame
    df = pd.read_csv(csv_file_path)

    # Create a new DataFrame for the desired columns
    new_df = pd.DataFrame(columns=['Language', 'Translation'])

    # Add 'en' row with the formatted title
    formatted_title = 'Ratio'
    new_row_en = pd.DataFrame({'Language': ['en'], 'Translation': [formatted_title]})
    new_df = pd.concat([new_df, new_row_en], ignore_index=True)

    # Add 'es' row with the Spanish translation
    spanish_translation = df[df['Language'] == 'es']['Title'].values[0] if 'es' in df['Language'].values else 'NaN'
    new_row_es = pd.DataFrame({'Language': ['es'], 'Translation': [spanish_translation]})
    new_df = pd.concat([new_df, new_row_es], ignore_index=True)

    # Add 'de' row with the German translation
    german_translation = df[df['Language'] == 'de']['Title'].values[0] if 'de' in df['Language'].values else 'NaN'
    new_row_de = pd.DataFrame({'Language': ['de'], 'Translation': [german_translation]})
    new_df = pd.concat([new_df, new_row_de], ignore_index=True)

    # Save the new DataFrame to a CSV file in the 'dataframes' folder
    translated_csv_path = os.path.join('dataframes', f'{original_csv_name}_translated.csv')
    new_df.to_csv(translated_csv_path, index=False)

# Example usage:
csv_file_path = 'dataframes/Transformation_geometry.csv'
add_translated_row_to_csv(csv_file_path)

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

def scrape_links_process_and_find_translation(webpage_url):
    csv_file_names = []  # Store the names of the created CSV files

    try:
        # Send an HTTP GET request to the webpage_url
        response = requests.get(webpage_url)

        # Check if the request was successful (status code 200)
        if response.status_code == 200:
            # Parse the HTML content of the webpage
            soup = BeautifulSoup(response.content, 'html.parser')

            # Find the <meta> tag with property="mw:PageProp/toc"
            toc_meta_tag = soup.find('meta', attrs={'property': 'mw:PageProp/toc'})

            # Check if the <meta> tag exists
            if toc_meta_tag:
                # Find the <ul> (unordered list) tag that follows the <meta> tag
                ul_tag = toc_meta_tag.find_next('ul')

                # Find all the <a> (anchor) tags within the <ul> tag
                links = ul_tag.find_all('a')

                # Extract and append the href attribute of each <a> tag to the formatted_links list
                formatted_links = []
                for link in links:
                    href = link.get('href')
                    formatted_link = f"https://en.wikipedia.org{href}"
                    formatted_links.append(formatted_link)  # Append the formatted URL to the list
                    title = link.get('title')
                    print(f"Link: {formatted_link}, Title: {title}")

                # Process each link
                for link in formatted_links:
                    response = requests.get(link)
                    soup = BeautifulSoup(response.content, 'html.parser')

                    # Find the interlanguage links
                    interlanguage_links = soup.find_all("li", class_="interlanguage-link")

                    # Initialize lists to store data for this link
                    languages = []
                    titles = []

                    # Extract and store the language and correct title of each interlanguage link
                    for interlanguage_link in interlanguage_links:
                        lang = interlanguage_link.find("a")['lang']
                        title = interlanguage_link.find("a")['title'].split(" – ")[0]
                        languages.append(lang)
                        titles.append(title)

                    # Create a pandas DataFrame for this link
                    data = {
                        "Language": languages,
                        "Title": titles
                    }
                    df = pd.DataFrame(data)

                    # Create a CSV file name based on the link title
                    csv_file_name = f"dataframes/{link.split('/')[-1]}.csv"

                    # Save the DataFrame as a CSV file
                    df.to_csv(csv_file_name, index=False)
                    add_translated_row_to_csv(csv_file_name)

                    print(f"CSV saved: {csv_file_name}")

                    # Append the created CSV file name to the list
                    csv_file_names.append(csv_file_name)

            else:
                print("No <meta> tag with property='mw:PageProp/toc' found on the page.")

        else:
            print(f"Failed to retrieve the webpage. Status code: {response.status_code}")

    except requests.exceptions.RequestException as e:
        print(f"Error: {e}")

    return csv_file_names  # Return the list of created CSV file names

webpage_url = 'https://en.wikipedia.org/wiki/List_of_geometry_topics'
created_csv_files = scrape_links_process_and_find_translation(webpage_url)
# Out:
# Link: https://en.wikipedia.org/wiki/Absolute_geometry, Title: Absolute geometry
# Link: https://en.wikipedia.org/wiki/Affine_geometry, Title: Affine geometry
# Link: https://en.wikipedia.org/wiki/Algebraic_geometry, Title: Algebraic geometry
# Link: https://en.wikipedia.org/wiki/Analytic_geometry, Title: Analytic geometry
# Link: https://en.wikipedia.org/wiki/Archimedes%27_use_of_infinitesimals, Title: Archimedes' use of infinitesimals
# Link: https://en.wikipedia.org/wiki/Birational_geometry, Title: Birational geometry
# Link: https://en.wikipedia.org/wiki/Complex_geometry, Title: Complex geometry
# Link: https://en.wikipedia.org/wiki/Combinatorial_geometry, Title: Combinatorial geometry
# Link: https://en.wikipedia.org/wiki/Computational_geometry, Title: Computational geometry
# Link: https://en.wikipedia.org/wiki/Conformal_geometry, Title: Conformal geometry
# Link: https://en.wikipedia.org/wiki/Constructive_solid_geometry, Title: Constructive solid geometry
# Link: https://en.wikipedia.org/wiki/Contact_geometry, Title: Contact geometry
# Link: https://en.wikipedia.org/wiki/Convex_geometry, Title: Convex geometry
# Link: https://en.wikipedia.org/wiki/Descriptive_geometry, Title: Descriptive geometry
# Link: https://en.wikipedia.org/wiki/Differential_geometry, Title: Differential geometry
# Link: https://en.wikipedia.org/wiki/Digital_geometry, Title: Digital geometry
# Link: https://en.wikipedia.org/wiki/Discrete_geometry, Title: Discrete geometry
# Link: https://en.wikipedia.org/wiki/Distance_geometry, Title: Distance geometry
# Link: https://en.wikipedia.org/wiki/Elliptic_geometry, Title: Elliptic geometry
# Link: https://en.wikipedia.org/wiki/Enumerative_geometry, Title: Enumerative geometry
# Link: https://en.wikipedia.org/wiki/Epipolar_geometry, Title: Epipolar geometry
# Link: https://en.wikipedia.org/wiki/Finite_geometry, Title: Finite geometry
# Link: https://en.wikipedia.org/wiki/Fractal_geometry, Title: Fractal geometry
# Link: https://en.wikipedia.org/wiki/Geometry_of_numbers, Title: Geometry of numbers
# Link: https://en.wikipedia.org/wiki/Hyperbolic_geometry, Title: Hyperbolic geometry
# Link: https://en.wikipedia.org/wiki/Incidence_geometry, Title: Incidence geometry
# Link: https://en.wikipedia.org/wiki/Information_geometry, Title: Information geometry
# Link: https://en.wikipedia.org/wiki/Integral_geometry, Title: Integral geometry
# Link: https://en.wikipedia.org/wiki/Inversive_geometry, Title: Inversive geometry
# Link: https://en.wikipedia.org/wiki/Inversive_ring_geometry, Title: Inversive ring geometry
# Link: https://en.wikipedia.org/wiki/Klein_geometry, Title: Klein geometry
# Link: https://en.wikipedia.org/wiki/Lie_sphere_geometry, Title: Lie sphere geometry
# Link: https://en.wikipedia.org/wiki/Non-Euclidean_geometry, Title: Non-Euclidean geometry
# Link: https://en.wikipedia.org/wiki/Noncommutative_algebraic_geometry, Title: Noncommutative algebraic geometry
# Link: https://en.wikipedia.org/wiki/Noncommutative_geometry, Title: Noncommutative geometry
# Link: https://en.wikipedia.org/wiki/Computational_geometry#Numerical_computational_geometry, Title: Computational geometry
# Link: https://en.wikipedia.org/wiki/Ordered_geometry, Title: Ordered geometry
# Link: https://en.wikipedia.org/wiki/Parabolic_geometry_(differential_geometry), Title: Parabolic geometry (differential geometry)
# Link: https://en.wikipedia.org/wiki/Euclidean_plane_geometry, Title: Euclidean plane geometry
# Link: https://en.wikipedia.org/wiki/Projective_geometry, Title: Projective geometry
# Link: https://en.wikipedia.org/wiki/Quantum_geometry, Title: Quantum geometry
# Link: https://en.wikipedia.org/wiki/Riemannian_geometry, Title: Riemannian geometry
# Link: https://en.wikipedia.org/wiki/Ruppeiner_geometry, Title: Ruppeiner geometry
# Link: https://en.wikipedia.org/wiki/Spherical_geometry, Title: Spherical geometry
# Link: https://en.wikipedia.org/wiki/Symplectic_geometry, Title: Symplectic geometry
# Link: https://en.wikipedia.org/wiki/Synthetic_geometry, Title: Synthetic geometry
# Link: https://en.wikipedia.org/wiki/Systolic_geometry, Title: Systolic geometry
# Link: https://en.wikipedia.org/wiki/Taxicab_geometry, Title: Taxicab geometry
# Link: https://en.wikipedia.org/wiki/Toric_geometry, Title: Toric geometry
# Link: https://en.wikipedia.org/wiki/Transformation_geometry, Title: Transformation geometry
# Link: https://en.wikipedia.org/wiki/Tropical_geometry, Title: Tropical geometry
# CSV saved: dataframes/Absolute_geometry.csv
# CSV saved: dataframes/Affine_geometry.csv
# CSV saved: dataframes/Algebraic_geometry.csv
# CSV saved: dataframes/Analytic_geometry.csv
# CSV saved: dataframes/Archimedes%27_use_of_infinitesimals.csv
# CSV saved: dataframes/Birational_geometry.csv
# CSV saved: dataframes/Complex_geometry.csv
# CSV saved: dataframes/Combinatorial_geometry.csv
# CSV saved: dataframes/Computational_geometry.csv
# CSV saved: dataframes/Conformal_geometry.csv
# CSV saved: dataframes/Constructive_solid_geometry.csv
# CSV saved: dataframes/Contact_geometry.csv
# CSV saved: dataframes/Convex_geometry.csv
# CSV saved: dataframes/Descriptive_geometry.csv
# CSV saved: dataframes/Differential_geometry.csv
# CSV saved: dataframes/Digital_geometry.csv
# CSV saved: dataframes/Discrete_geometry.csv
# CSV saved: dataframes/Distance_geometry.csv
# CSV saved: dataframes/Elliptic_geometry.csv
# CSV saved: dataframes/Enumerative_geometry.csv
# CSV saved: dataframes/Epipolar_geometry.csv
# CSV saved: dataframes/Finite_geometry.csv
# CSV saved: dataframes/Fractal_geometry.csv
# CSV saved: dataframes/Geometry_of_numbers.csv
# CSV saved: dataframes/Hyperbolic_geometry.csv
# CSV saved: dataframes/Incidence_geometry.csv
# CSV saved: dataframes/Information_geometry.csv
# CSV saved: dataframes/Integral_geometry.csv
# CSV saved: dataframes/Inversive_geometry.csv
# CSV saved: dataframes/Inversive_ring_geometry.csv
# CSV saved: dataframes/Klein_geometry.csv
# CSV saved: dataframes/Lie_sphere_geometry.csv
# CSV saved: dataframes/Non-Euclidean_geometry.csv
# CSV saved: dataframes/Noncommutative_algebraic_geometry.csv
# CSV saved: dataframes/Noncommutative_geometry.csv
# CSV saved: dataframes/Computational_geometry#Numerical_computational_geometry.csv
# CSV saved: dataframes/Ordered_geometry.csv
# CSV saved: dataframes/Parabolic_geometry_(differential_geometry).csv
# CSV saved: dataframes/Euclidean_plane_geometry.csv
# CSV saved: dataframes/Projective_geometry.csv
# CSV saved: dataframes/Quantum_geometry.csv
# CSV saved: dataframes/Riemannian_geometry.csv
# CSV saved: dataframes/Ruppeiner_geometry.csv
# CSV saved: dataframes/Spherical_geometry.csv
# CSV saved: dataframes/Symplectic_geometry.csv
# CSV saved: dataframes/Synthetic_geometry.csv
# CSV saved: dataframes/Systolic_geometry.csv
# CSV saved: dataframes/Taxicab_geometry.csv
# CSV saved: dataframes/Toric_geometry.csv
# CSV saved: dataframes/Transformation_geometry.csv
# CSV saved: dataframes/Tropical_geometry.csv

# %%
10+10
# Out:
# 20

# %%
def two_level_scrape_links_process_and_find_translation(webpage_url):
    links = get_links(webpage_url)
    
    for link in links:
        scrape_links_process_and_find_translation(link)

webpage_url = 'https://en.wikipedia.org/wiki/Lists_of_mathematics_topics'
two_level_scrape_links_and_process(webpage_url)
# Out:
# Link: https://en.wikipedia.org/wiki/Elementary_arithmetic, Title: Elementary arithmetic
# Link: https://en.wikipedia.org/wiki/Decimal_arithmetic, Title: Decimal arithmetic
# Link: https://en.wikipedia.org/wiki/Decimal_point, Title: Decimal point
# Link: https://en.wikipedia.org/wiki/Numeral_system, Title: Numeral system
# Link: https://en.wikipedia.org/wiki/Place_value, Title: Place value
# Link: https://en.wikipedia.org/wiki/Face_value, Title: Face value
# CSV saved: dataframes/Elementary_arithmetic.csv
# CSV saved: dataframes/Decimal_arithmetic.csv
# CSV saved: dataframes/Decimal_point.csv
# CSV saved: dataframes/Numeral_system.csv
# CSV saved: dataframes/Place_value.csv
# CSV saved: dataframes/Face_value.csv
# Link: https://en.wikipedia.org/wiki/Logic, Title: Logic
# CSV saved: dataframes/Logic.csv
# Link: https://en.wikipedia.org/wiki/Limit_(mathematics), Title: Limit (mathematics)
# Link: https://en.wikipedia.org/wiki/Limit_of_a_function, Title: Limit of a function
# Link: https://en.wikipedia.org/wiki/One-sided_limit, Title: One-sided limit
# Link: https://en.wikipedia.org/wiki/Limit_of_a_sequence, Title: Limit of a sequence
# Link: https://en.wikipedia.org/wiki/Indeterminate_form, Title: Indeterminate form
# Link: https://en.wikipedia.org/wiki/Orders_of_approximation, Title: Orders of approximation
# Link: https://en.wikipedia.org/wiki/(%CE%B5,_%CE%B4)-definition_of_limit, Title: (ε, δ)-definition of limit
# Link: https://en.wikipedia.org/wiki/Continuous_function, Title: Continuous function
# CSV saved: dataframes/Limit_(mathematics).csv
# CSV saved: dataframes/Limit_of_a_function.csv
# CSV saved: dataframes/One-sided_limit.csv
# CSV saved: dataframes/Limit_of_a_sequence.csv
# CSV saved: dataframes/Indeterminate_form.csv
# CSV saved: dataframes/Orders_of_approximation.csv
# CSV saved: dataframes/(%CE%B5,_%CE%B4)-definition_of_limit.csv
# CSV saved: dataframes/Continuous_function.csv
# Link: https://en.wikipedia.org/wiki/Absolute_geometry, Title: Absolute geometry
# Link: https://en.wikipedia.org/wiki/Affine_geometry, Title: Affine geometry
# Link: https://en.wikipedia.org/wiki/Algebraic_geometry, Title: Algebraic geometry
# Link: https://en.wikipedia.org/wiki/Analytic_geometry, Title: Analytic geometry
# Link: https://en.wikipedia.org/wiki/Archimedes%27_use_of_infinitesimals, Title: Archimedes' use of infinitesimals
# Link: https://en.wikipedia.org/wiki/Birational_geometry, Title: Birational geometry
# Link: https://en.wikipedia.org/wiki/Complex_geometry, Title: Complex geometry
# Link: https://en.wikipedia.org/wiki/Combinatorial_geometry, Title: Combinatorial geometry
# Link: https://en.wikipedia.org/wiki/Computational_geometry, Title: Computational geometry
# Link: https://en.wikipedia.org/wiki/Conformal_geometry, Title: Conformal geometry
# Link: https://en.wikipedia.org/wiki/Constructive_solid_geometry, Title: Constructive solid geometry
# Link: https://en.wikipedia.org/wiki/Contact_geometry, Title: Contact geometry
# Link: https://en.wikipedia.org/wiki/Convex_geometry, Title: Convex geometry
# Link: https://en.wikipedia.org/wiki/Descriptive_geometry, Title: Descriptive geometry
# Link: https://en.wikipedia.org/wiki/Differential_geometry, Title: Differential geometry
# Link: https://en.wikipedia.org/wiki/Digital_geometry, Title: Digital geometry
# Link: https://en.wikipedia.org/wiki/Discrete_geometry, Title: Discrete geometry
# Link: https://en.wikipedia.org/wiki/Distance_geometry, Title: Distance geometry
# Link: https://en.wikipedia.org/wiki/Elliptic_geometry, Title: Elliptic geometry
# Link: https://en.wikipedia.org/wiki/Enumerative_geometry, Title: Enumerative geometry
# Link: https://en.wikipedia.org/wiki/Epipolar_geometry, Title: Epipolar geometry
# Link: https://en.wikipedia.org/wiki/Finite_geometry, Title: Finite geometry
# Link: https://en.wikipedia.org/wiki/Fractal_geometry, Title: Fractal geometry
# Link: https://en.wikipedia.org/wiki/Geometry_of_numbers, Title: Geometry of numbers
# Link: https://en.wikipedia.org/wiki/Hyperbolic_geometry, Title: Hyperbolic geometry
# Link: https://en.wikipedia.org/wiki/Incidence_geometry, Title: Incidence geometry
# Link: https://en.wikipedia.org/wiki/Information_geometry, Title: Information geometry
# Link: https://en.wikipedia.org/wiki/Integral_geometry, Title: Integral geometry
# Link: https://en.wikipedia.org/wiki/Inversive_geometry, Title: Inversive geometry
# Link: https://en.wikipedia.org/wiki/Inversive_ring_geometry, Title: Inversive ring geometry
# Link: https://en.wikipedia.org/wiki/Klein_geometry, Title: Klein geometry
# Link: https://en.wikipedia.org/wiki/Lie_sphere_geometry, Title: Lie sphere geometry
# Link: https://en.wikipedia.org/wiki/Non-Euclidean_geometry, Title: Non-Euclidean geometry
# Link: https://en.wikipedia.org/wiki/Noncommutative_algebraic_geometry, Title: Noncommutative algebraic geometry
# Link: https://en.wikipedia.org/wiki/Noncommutative_geometry, Title: Noncommutative geometry
# Link: https://en.wikipedia.org/wiki/Computational_geometry#Numerical_computational_geometry, Title: Computational geometry
# Link: https://en.wikipedia.org/wiki/Ordered_geometry, Title: Ordered geometry
# Link: https://en.wikipedia.org/wiki/Parabolic_geometry_(differential_geometry), Title: Parabolic geometry (differential geometry)
# Link: https://en.wikipedia.org/wiki/Euclidean_plane_geometry, Title: Euclidean plane geometry
# Link: https://en.wikipedia.org/wiki/Projective_geometry, Title: Projective geometry
# Link: https://en.wikipedia.org/wiki/Quantum_geometry, Title: Quantum geometry
# Link: https://en.wikipedia.org/wiki/Riemannian_geometry, Title: Riemannian geometry
# Link: https://en.wikipedia.org/wiki/Ruppeiner_geometry, Title: Ruppeiner geometry
# Link: https://en.wikipedia.org/wiki/Spherical_geometry, Title: Spherical geometry
# Link: https://en.wikipedia.org/wiki/Symplectic_geometry, Title: Symplectic geometry
# Link: https://en.wikipedia.org/wiki/Synthetic_geometry, Title: Synthetic geometry
# Link: https://en.wikipedia.org/wiki/Systolic_geometry, Title: Systolic geometry
# Link: https://en.wikipedia.org/wiki/Taxicab_geometry, Title: Taxicab geometry
# Link: https://en.wikipedia.org/wiki/Toric_geometry, Title: Toric geometry
# Link: https://en.wikipedia.org/wiki/Transformation_geometry, Title: Transformation geometry
# Link: https://en.wikipedia.org/wiki/Tropical_geometry, Title: Tropical geometry
# CSV saved: dataframes/Absolute_geometry.csv
# CSV saved: dataframes/Affine_geometry.csv
# CSV saved: dataframes/Algebraic_geometry.csv
# CSV saved: dataframes/Analytic_geometry.csv
# CSV saved: dataframes/Archimedes%27_use_of_infinitesimals.csv
# CSV saved: dataframes/Birational_geometry.csv
# CSV saved: dataframes/Complex_geometry.csv
# CSV saved: dataframes/Combinatorial_geometry.csv
# CSV saved: dataframes/Computational_geometry.csv
# CSV saved: dataframes/Conformal_geometry.csv
# CSV saved: dataframes/Constructive_solid_geometry.csv
# CSV saved: dataframes/Contact_geometry.csv
# CSV saved: dataframes/Convex_geometry.csv
# CSV saved: dataframes/Descriptive_geometry.csv
# CSV saved: dataframes/Differential_geometry.csv
# CSV saved: dataframes/Digital_geometry.csv
# CSV saved: dataframes/Discrete_geometry.csv
# CSV saved: dataframes/Distance_geometry.csv
# CSV saved: dataframes/Elliptic_geometry.csv
# CSV saved: dataframes/Enumerative_geometry.csv
# CSV saved: dataframes/Epipolar_geometry.csv
# CSV saved: dataframes/Finite_geometry.csv
# CSV saved: dataframes/Fractal_geometry.csv
# CSV saved: dataframes/Geometry_of_numbers.csv
# CSV saved: dataframes/Hyperbolic_geometry.csv
# CSV saved: dataframes/Incidence_geometry.csv
# CSV saved: dataframes/Information_geometry.csv
# CSV saved: dataframes/Integral_geometry.csv
# CSV saved: dataframes/Inversive_geometry.csv
# CSV saved: dataframes/Inversive_ring_geometry.csv
# CSV saved: dataframes/Klein_geometry.csv
# CSV saved: dataframes/Lie_sphere_geometry.csv
# CSV saved: dataframes/Non-Euclidean_geometry.csv
# CSV saved: dataframes/Noncommutative_algebraic_geometry.csv
# CSV saved: dataframes/Noncommutative_geometry.csv
# CSV saved: dataframes/Computational_geometry#Numerical_computational_geometry.csv
# CSV saved: dataframes/Ordered_geometry.csv
# CSV saved: dataframes/Parabolic_geometry_(differential_geometry).csv
# CSV saved: dataframes/Euclidean_plane_geometry.csv
# CSV saved: dataframes/Projective_geometry.csv
# CSV saved: dataframes/Quantum_geometry.csv
# CSV saved: dataframes/Riemannian_geometry.csv
# CSV saved: dataframes/Ruppeiner_geometry.csv
# CSV saved: dataframes/Spherical_geometry.csv
# CSV saved: dataframes/Symplectic_geometry.csv
# CSV saved: dataframes/Synthetic_geometry.csv
# CSV saved: dataframes/Systolic_geometry.csv
# CSV saved: dataframes/Taxicab_geometry.csv
# CSV saved: dataframes/Toric_geometry.csv
# CSV saved: dataframes/Transformation_geometry.csv
# CSV saved: dataframes/Tropical_geometry.csv
# Link: https://en.wikipedia.org/wiki/Geometry, Title: Geometry
# Link: https://en.wikipedia.org/wiki/Analytic_geometry, Title: Analytic geometry
# Link: https://en.wikipedia.org/wiki/Differential_geometry, Title: Differential geometry
# Link: https://en.wikipedia.org/wiki/Euclidean_geometry, Title: Euclidean geometry
# Link: https://en.wikipedia.org/wiki/Non-Euclidean_geometry, Title: Non-Euclidean geometry
# Link: https://en.wikipedia.org/wiki/Projective_geometry, Title: Projective geometry
# Link: https://en.wikipedia.org/wiki/Riemannian_geometry, Title: Riemannian geometry
# CSV saved: dataframes/Geometry.csv
# CSV saved: dataframes/Analytic_geometry.csv
# CSV saved: dataframes/Differential_geometry.csv
# CSV saved: dataframes/Euclidean_geometry.csv
# CSV saved: dataframes/Non-Euclidean_geometry.csv
# CSV saved: dataframes/Projective_geometry.csv
# CSV saved: dataframes/Riemannian_geometry.csv
# Link: https://en.wikipedia.org/wiki/Geometry, Title: Geometry
# Link: https://en.wikipedia.org/wiki/Angle, Title: Angle
# Link: https://en.wikipedia.org/wiki/Ratio, Title: Ratio
# CSV saved: dataframes/Geometry.csv
# CSV saved: dataframes/Angle.csv
# CSV saved: dataframes/Ratio.csv
# Link: https://en.wikipedia.org/wiki/Geometry, Title: Geometry
# Link: https://en.wikipedia.org/wiki/Angle, Title: Angle
# Link: https://en.wikipedia.org/wiki/Ratio, Title: Ratio
# CSV saved: dataframes/Geometry.csv
# CSV saved: dataframes/Angle.csv
# CSV saved: dataframes/Ratio.csv
# Link: https://en.wikipedia.org/wiki/Natural_logarithm, Title: Natural logarithm
# Link: https://en.wikipedia.org/wiki/Arg_(mathematics), Title: Arg (mathematics)
# Link: https://en.wikipedia.org/wiki/Atan2, Title: Atan2
# CSV saved: dataframes/Natural_logarithm.csv
# CSV saved: dataframes/Arg_(mathematics).csv
# CSV saved: dataframes/Atan2.csv
# Link: https://en.wikipedia.org/wiki/List_of_mathematical_identities, Title: List of mathematical identities
# Link: https://en.wikipedia.org/wiki/Lists_of_mathematics_topics, Title: Lists of mathematics topics
# CSV saved: dataframes/List_of_mathematical_identities.csv
# CSV saved: dataframes/Lists_of_mathematics_topics.csv
# Link: https://en.wikipedia.org/wiki/Analytic-synthetic_distinction, Title: Analytic-synthetic distinction
# Link: https://en.wikipedia.org/wiki/Antinomy, Title: Antinomy
# Link: https://en.wikipedia.org/wiki/A_priori_and_a_posteriori, Title: A priori and a posteriori
# Link: https://en.wikipedia.org/wiki/Definition, Title: Definition
# Link: https://en.wikipedia.org/wiki/Description, Title: Description
# Link: https://en.wikipedia.org/wiki/Entailment, Title: Entailment
# Link: https://en.wikipedia.org/wiki/Identity_(philosophy), Title: Identity (philosophy)
# Link: https://en.wikipedia.org/wiki/Inference, Title: Inference
# Link: https://en.wikipedia.org/wiki/Logical_form, Title: Logical form
# Link: https://en.wikipedia.org/wiki/Logical_implication, Title: Logical implication
# Link: https://en.wikipedia.org/wiki/Logical_truth, Title: Logical truth
# Link: https://en.wikipedia.org/wiki/Logical_consequence, Title: Logical consequence
# Link: https://en.wikipedia.org/wiki/Name, Title: Name
# Link: https://en.wikipedia.org/wiki/Necessary_and_sufficient_condition, Title: Necessary and sufficient condition
# Link: https://en.wikipedia.org/wiki/Material_conditional, Title: Material conditional
# Link: https://en.wikipedia.org/wiki/Meaning_(linguistic), Title: Meaning (linguistic)
# Link: https://en.wikipedia.org/wiki/Meaning_(non-linguistic), Title: Meaning (non-linguistic)
# Link: https://en.wikipedia.org/wiki/Paradox, Title: Paradox
# Link: https://en.wikipedia.org/wiki/List_of_paradoxes, Title: List of paradoxes
# Link: https://en.wikipedia.org/wiki/Possible_world, Title: Possible world
# Link: https://en.wikipedia.org/wiki/Presupposition, Title: Presupposition
# Link: https://en.wikipedia.org/wiki/Probability, Title: Probability
# Link: https://en.wikipedia.org/wiki/Quantification_(logic), Title: Quantification (logic)
# Link: https://en.wikipedia.org/wiki/Reason, Title: Reason
# Link: https://en.wikipedia.org/wiki/Reasoning, Title: Reasoning
# Link: https://en.wikipedia.org/wiki/Reference, Title: Reference
# Link: https://en.wikipedia.org/wiki/Semantics, Title: Semantics
# Link: https://en.wikipedia.org/wiki/Strict_conditional, Title: Strict conditional
# Link: https://en.wikipedia.org/wiki/Syntax_(logic), Title: Syntax (logic)
# Link: https://en.wikipedia.org/wiki/Truth, Title: Truth
# Link: https://en.wikipedia.org/wiki/Truth_value, Title: Truth value
# Link: https://en.wikipedia.org/wiki/Validity_(logic), Title: Validity (logic)
# CSV saved: dataframes/Analytic-synthetic_distinction.csv
# CSV saved: dataframes/Antinomy.csv
# CSV saved: dataframes/A_priori_and_a_posteriori.csv
# CSV saved: dataframes/Definition.csv
# CSV saved: dataframes/Description.csv
# CSV saved: dataframes/Entailment.csv
# CSV saved: dataframes/Identity_(philosophy).csv
# CSV saved: dataframes/Inference.csv
# CSV saved: dataframes/Logical_form.csv
# CSV saved: dataframes/Logical_implication.csv
# CSV saved: dataframes/Logical_truth.csv
# CSV saved: dataframes/Logical_consequence.csv
# CSV saved: dataframes/Name.csv
# CSV saved: dataframes/Necessary_and_sufficient_condition.csv
# CSV saved: dataframes/Material_conditional.csv
# CSV saved: dataframes/Meaning_(linguistic).csv
# CSV saved: dataframes/Meaning_(non-linguistic).csv
# CSV saved: dataframes/Paradox.csv
# CSV saved: dataframes/List_of_paradoxes.csv
# CSV saved: dataframes/Possible_world.csv
# CSV saved: dataframes/Presupposition.csv
# CSV saved: dataframes/Probability.csv
# CSV saved: dataframes/Quantification_(logic).csv
# CSV saved: dataframes/Reason.csv
# CSV saved: dataframes/Reasoning.csv
# CSV saved: dataframes/Reference.csv
# CSV saved: dataframes/Semantics.csv
# CSV saved: dataframes/Strict_conditional.csv
# CSV saved: dataframes/Syntax_(logic).csv
# CSV saved: dataframes/Truth.csv
# CSV saved: dataframes/Truth_value.csv
# CSV saved: dataframes/Validity_(logic).csv

# %% [markdown]
# Final Versions for one layer

# %%
def add_translated_row_to_csv(csv_file_path, original_title):
    # Read the existing CSV file into a DataFrame
    df = pd.read_csv(csv_file_path)

    # Create a new DataFrame for the desired columns
    new_df = pd.DataFrame(columns=['Language', 'Translation'])

    # Add 'en' row with the original title as the formatted title
    new_row_en = pd.DataFrame({'Language': ['en'], 'Translation': [original_title]})
    new_df = pd.concat([new_df, new_row_en], ignore_index=True)

    # Add 'es' row with the Spanish translation
    spanish_translation = df[df['Language'] == 'es']['Title'].values[0] if 'es' in df['Language'].values else 'NaN'
    new_row_es = pd.DataFrame({'Language': ['es'], 'Translation': [spanish_translation]})
    new_df = pd.concat([new_df, new_row_es], ignore_index=True)

    # Add 'de' row with the German translation
    german_translation = df[df['Language'] == 'de']['Title'].values[0] if 'de' in df['Language'].values else 'NaN'
    new_row_de = pd.DataFrame({'Language': ['de'], 'Translation': [german_translation]})
    new_df = pd.concat([new_df, new_row_de], ignore_index=True)

    # Define the path to the 'translations' folder within the 'dataframes' directory
    translations_folder = os.path.join('dataframes', 'translations')

    # Create the 'translations' folder if it doesn't exist
    os.makedirs(translations_folder, exist_ok=True)

    # Save the new DataFrame to a CSV file in the 'translations' folder
    translated_csv_path = os.path.join(translations_folder, f'{original_title}_translated.csv')
    new_df.to_csv(translated_csv_path, index=False)

# %%
def scrape_links_process_and_find_translation(webpage_url):
    csv_file_names = []  # Store the names of the created CSV files

    try:
        # Send an HTTP GET request to the webpage_url
        response = requests.get(webpage_url)

        # Check if the request was successful (status code 200)
        if response.status_code == 200:
            # Parse the HTML content of the webpage
            soup = BeautifulSoup(response.content, 'html.parser')

            # Find the <meta> tag with property="mw:PageProp/toc"
            toc_meta_tag = soup.find('meta', attrs={'property': 'mw:PageProp/toc'})

            # Check if the <meta> tag exists
            if toc_meta_tag:
                # Find the <ul> (unordered list) tag that follows the <meta> tag
                ul_tag = toc_meta_tag.find_next('ul')

                # Find all the <a> (anchor) tags within the <ul> tag
                links = ul_tag.find_all('a')

                # Extract and append the href attribute of each <a> tag to the formatted_links list
                formatted_links = []
                for link in links:
                    href = link.get('href')
                    formatted_link = f"https://en.wikipedia.org{href}"
                    formatted_links.append(formatted_link)  # Append the formatted URL to the list
                    title = link.get('title')
                    print(f"Link: {formatted_link}, Title: {title}")

                # Process each link
                for link in formatted_links:
                    response = requests.get(link)
                    soup = BeautifulSoup(response.content, 'html.parser')

                    # Find the interlanguage links
                    interlanguage_links = soup.find_all("li", class_="interlanguage-link")

                    # Initialize lists to store data for this link
                    languages = []
                    titles = []

                    # Extract and store the language and correct title of each interlanguage link
                    for interlanguage_link in interlanguage_links:
                        lang = interlanguage_link.find("a")['lang']
                        title = interlanguage_link.find("a")['title'].split(" – ")[0]
                        languages.append(lang)
                        titles.append(title)

                    # Create a pandas DataFrame for this link
                    data = {
                        "Language": languages,
                        "Title": titles
                    }
                    df = pd.DataFrame(data)

                    # Create a CSV file name based on the link title
                    csv_file_name = f"dataframes/{link.split('/')[-1]}.csv"

                    # Save the DataFrame as a CSV file
                    df.to_csv(csv_file_name, index=False)

                    # Get the original title from the link
                    original_title = title  # Replace with the logic to extract the title from the link

                    # Call add_translated_row_to_csv with csv_file_name and original_title as arguments
                    add_translated_row_to_csv(csv_file_name, original_title)

                    print(f"CSV saved: {csv_file_name}")

                    # Append the created CSV file name to the list
                    csv_file_names.append(csv_file_name)

            else:
                print("No <meta> tag with property='mw:PageProp/toc' found on the page.")

        else:
            print(f"Failed to retrieve the webpage. Status code: {response.status_code}")

    except requests.exceptions.RequestException as e:
        print(f"Error: {e}")

    return csv_file_names  # Return the list of created CSV file names

webpage_url = 'https://en.wikipedia.org/wiki/List_of_geometry_topics'
created_csv_files = scrape_links_process_and_find_translation(webpage_url)
# Out:
# Link: https://en.wikipedia.org/wiki/Absolute_geometry, Title: Absolute geometry
# Link: https://en.wikipedia.org/wiki/Affine_geometry, Title: Affine geometry
# Link: https://en.wikipedia.org/wiki/Algebraic_geometry, Title: Algebraic geometry
# Link: https://en.wikipedia.org/wiki/Analytic_geometry, Title: Analytic geometry
# Link: https://en.wikipedia.org/wiki/Archimedes%27_use_of_infinitesimals, Title: Archimedes' use of infinitesimals
# Link: https://en.wikipedia.org/wiki/Birational_geometry, Title: Birational geometry
# Link: https://en.wikipedia.org/wiki/Complex_geometry, Title: Complex geometry
# Link: https://en.wikipedia.org/wiki/Combinatorial_geometry, Title: Combinatorial geometry
# Link: https://en.wikipedia.org/wiki/Computational_geometry, Title: Computational geometry
# Link: https://en.wikipedia.org/wiki/Conformal_geometry, Title: Conformal geometry
# Link: https://en.wikipedia.org/wiki/Constructive_solid_geometry, Title: Constructive solid geometry
# Link: https://en.wikipedia.org/wiki/Contact_geometry, Title: Contact geometry
# Link: https://en.wikipedia.org/wiki/Convex_geometry, Title: Convex geometry
# Link: https://en.wikipedia.org/wiki/Descriptive_geometry, Title: Descriptive geometry
# Link: https://en.wikipedia.org/wiki/Differential_geometry, Title: Differential geometry
# Link: https://en.wikipedia.org/wiki/Digital_geometry, Title: Digital geometry
# Link: https://en.wikipedia.org/wiki/Discrete_geometry, Title: Discrete geometry
# Link: https://en.wikipedia.org/wiki/Distance_geometry, Title: Distance geometry
# Link: https://en.wikipedia.org/wiki/Elliptic_geometry, Title: Elliptic geometry
# Link: https://en.wikipedia.org/wiki/Enumerative_geometry, Title: Enumerative geometry
# Link: https://en.wikipedia.org/wiki/Epipolar_geometry, Title: Epipolar geometry
# Link: https://en.wikipedia.org/wiki/Finite_geometry, Title: Finite geometry
# Link: https://en.wikipedia.org/wiki/Fractal_geometry, Title: Fractal geometry
# Link: https://en.wikipedia.org/wiki/Geometry_of_numbers, Title: Geometry of numbers
# Link: https://en.wikipedia.org/wiki/Hyperbolic_geometry, Title: Hyperbolic geometry
# Link: https://en.wikipedia.org/wiki/Incidence_geometry, Title: Incidence geometry
# Link: https://en.wikipedia.org/wiki/Information_geometry, Title: Information geometry
# Link: https://en.wikipedia.org/wiki/Integral_geometry, Title: Integral geometry
# Link: https://en.wikipedia.org/wiki/Inversive_geometry, Title: Inversive geometry
# Link: https://en.wikipedia.org/wiki/Inversive_ring_geometry, Title: Inversive ring geometry
# Link: https://en.wikipedia.org/wiki/Klein_geometry, Title: Klein geometry
# Link: https://en.wikipedia.org/wiki/Lie_sphere_geometry, Title: Lie sphere geometry
# Link: https://en.wikipedia.org/wiki/Non-Euclidean_geometry, Title: Non-Euclidean geometry
# Link: https://en.wikipedia.org/wiki/Noncommutative_algebraic_geometry, Title: Noncommutative algebraic geometry
# Link: https://en.wikipedia.org/wiki/Noncommutative_geometry, Title: Noncommutative geometry
# Link: https://en.wikipedia.org/wiki/Computational_geometry#Numerical_computational_geometry, Title: Computational geometry
# Link: https://en.wikipedia.org/wiki/Ordered_geometry, Title: Ordered geometry
# Link: https://en.wikipedia.org/wiki/Parabolic_geometry_(differential_geometry), Title: Parabolic geometry (differential geometry)
# Link: https://en.wikipedia.org/wiki/Euclidean_plane_geometry, Title: Euclidean plane geometry
# Link: https://en.wikipedia.org/wiki/Projective_geometry, Title: Projective geometry
# Link: https://en.wikipedia.org/wiki/Quantum_geometry, Title: Quantum geometry
# Link: https://en.wikipedia.org/wiki/Riemannian_geometry, Title: Riemannian geometry
# Link: https://en.wikipedia.org/wiki/Ruppeiner_geometry, Title: Ruppeiner geometry
# Link: https://en.wikipedia.org/wiki/Spherical_geometry, Title: Spherical geometry
# Link: https://en.wikipedia.org/wiki/Symplectic_geometry, Title: Symplectic geometry
# Link: https://en.wikipedia.org/wiki/Synthetic_geometry, Title: Synthetic geometry
# Link: https://en.wikipedia.org/wiki/Systolic_geometry, Title: Systolic geometry
# Link: https://en.wikipedia.org/wiki/Taxicab_geometry, Title: Taxicab geometry
# Link: https://en.wikipedia.org/wiki/Toric_geometry, Title: Toric geometry
# Link: https://en.wikipedia.org/wiki/Transformation_geometry, Title: Transformation geometry
# Link: https://en.wikipedia.org/wiki/Tropical_geometry, Title: Tropical geometry
# CSV saved: dataframes/Absolute_geometry.csv
# CSV saved: dataframes/Affine_geometry.csv
# CSV saved: dataframes/Algebraic_geometry.csv
# CSV saved: dataframes/Analytic_geometry.csv
# CSV saved: dataframes/Archimedes%27_use_of_infinitesimals.csv
# CSV saved: dataframes/Birational_geometry.csv
# CSV saved: dataframes/Complex_geometry.csv
# CSV saved: dataframes/Combinatorial_geometry.csv
# CSV saved: dataframes/Computational_geometry.csv
# CSV saved: dataframes/Conformal_geometry.csv
# CSV saved: dataframes/Constructive_solid_geometry.csv
# CSV saved: dataframes/Contact_geometry.csv
# CSV saved: dataframes/Convex_geometry.csv
# CSV saved: dataframes/Descriptive_geometry.csv
# CSV saved: dataframes/Differential_geometry.csv
# CSV saved: dataframes/Digital_geometry.csv
# CSV saved: dataframes/Discrete_geometry.csv
# CSV saved: dataframes/Distance_geometry.csv
# CSV saved: dataframes/Elliptic_geometry.csv
# CSV saved: dataframes/Enumerative_geometry.csv
# CSV saved: dataframes/Epipolar_geometry.csv
# CSV saved: dataframes/Finite_geometry.csv
# CSV saved: dataframes/Fractal_geometry.csv
# CSV saved: dataframes/Geometry_of_numbers.csv
# CSV saved: dataframes/Hyperbolic_geometry.csv
# CSV saved: dataframes/Incidence_geometry.csv
# CSV saved: dataframes/Information_geometry.csv
# CSV saved: dataframes/Integral_geometry.csv
# CSV saved: dataframes/Inversive_geometry.csv
# CSV saved: dataframes/Inversive_ring_geometry.csv
# CSV saved: dataframes/Klein_geometry.csv
# CSV saved: dataframes/Lie_sphere_geometry.csv
# CSV saved: dataframes/Non-Euclidean_geometry.csv
# CSV saved: dataframes/Noncommutative_algebraic_geometry.csv
# CSV saved: dataframes/Noncommutative_geometry.csv
# CSV saved: dataframes/Computational_geometry#Numerical_computational_geometry.csv
# CSV saved: dataframes/Ordered_geometry.csv
# CSV saved: dataframes/Parabolic_geometry_(differential_geometry).csv
# CSV saved: dataframes/Euclidean_plane_geometry.csv
# CSV saved: dataframes/Projective_geometry.csv
# CSV saved: dataframes/Quantum_geometry.csv
# CSV saved: dataframes/Riemannian_geometry.csv
# CSV saved: dataframes/Ruppeiner_geometry.csv
# CSV saved: dataframes/Spherical_geometry.csv
# CSV saved: dataframes/Symplectic_geometry.csv
# CSV saved: dataframes/Synthetic_geometry.csv
# CSV saved: dataframes/Systolic_geometry.csv
# CSV saved: dataframes/Taxicab_geometry.csv
# CSV saved: dataframes/Toric_geometry.csv
# CSV saved: dataframes/Transformation_geometry.csv
# CSV saved: dataframes/Tropical_geometry.csv

# %%
def two_level_scrape_links_process_and_find_translation(webpage_url):
    links = get_links(webpage_url)
    
    for link in links:
        scrape_links_process_and_find_translation(link)

webpage_url = 'https://en.wikipedia.org/wiki/Lists_of_mathematics_topics'
two_level_scrape_links_and_process(webpage_url)
# Out:
# Link: https://en.wikipedia.org/wiki/Elementary_arithmetic, Title: Elementary arithmetic
# Link: https://en.wikipedia.org/wiki/Decimal_arithmetic, Title: Decimal arithmetic
# Link: https://en.wikipedia.org/wiki/Decimal_point, Title: Decimal point
# Link: https://en.wikipedia.org/wiki/Numeral_system, Title: Numeral system
# Link: https://en.wikipedia.org/wiki/Place_value, Title: Place value
# Link: https://en.wikipedia.org/wiki/Face_value, Title: Face value
# CSV saved: dataframes/Elementary_arithmetic.csv
# CSV saved: dataframes/Decimal_arithmetic.csv
# CSV saved: dataframes/Decimal_point.csv
# CSV saved: dataframes/Numeral_system.csv
# CSV saved: dataframes/Place_value.csv
# CSV saved: dataframes/Face_value.csv
# Link: https://en.wikipedia.org/wiki/Logic, Title: Logic
# CSV saved: dataframes/Logic.csv
# Link: https://en.wikipedia.org/wiki/Limit_(mathematics), Title: Limit (mathematics)
# Link: https://en.wikipedia.org/wiki/Limit_of_a_function, Title: Limit of a function
# Link: https://en.wikipedia.org/wiki/One-sided_limit, Title: One-sided limit
# Link: https://en.wikipedia.org/wiki/Limit_of_a_sequence, Title: Limit of a sequence
# Link: https://en.wikipedia.org/wiki/Indeterminate_form, Title: Indeterminate form
# Link: https://en.wikipedia.org/wiki/Orders_of_approximation, Title: Orders of approximation
# Link: https://en.wikipedia.org/wiki/(%CE%B5,_%CE%B4)-definition_of_limit, Title: (ε, δ)-definition of limit
# Link: https://en.wikipedia.org/wiki/Continuous_function, Title: Continuous function
# CSV saved: dataframes/Limit_(mathematics).csv
# CSV saved: dataframes/Limit_of_a_function.csv
# CSV saved: dataframes/One-sided_limit.csv
# CSV saved: dataframes/Limit_of_a_sequence.csv
# CSV saved: dataframes/Indeterminate_form.csv
# CSV saved: dataframes/Orders_of_approximation.csv
# CSV saved: dataframes/(%CE%B5,_%CE%B4)-definition_of_limit.csv
# CSV saved: dataframes/Continuous_function.csv
# Link: https://en.wikipedia.org/wiki/Absolute_geometry, Title: Absolute geometry
# Link: https://en.wikipedia.org/wiki/Affine_geometry, Title: Affine geometry
# Link: https://en.wikipedia.org/wiki/Algebraic_geometry, Title: Algebraic geometry
# Link: https://en.wikipedia.org/wiki/Analytic_geometry, Title: Analytic geometry
# Link: https://en.wikipedia.org/wiki/Archimedes%27_use_of_infinitesimals, Title: Archimedes' use of infinitesimals
# Link: https://en.wikipedia.org/wiki/Birational_geometry, Title: Birational geometry
# Link: https://en.wikipedia.org/wiki/Complex_geometry, Title: Complex geometry
# Link: https://en.wikipedia.org/wiki/Combinatorial_geometry, Title: Combinatorial geometry
# Link: https://en.wikipedia.org/wiki/Computational_geometry, Title: Computational geometry
# Link: https://en.wikipedia.org/wiki/Conformal_geometry, Title: Conformal geometry
# Link: https://en.wikipedia.org/wiki/Constructive_solid_geometry, Title: Constructive solid geometry
# Link: https://en.wikipedia.org/wiki/Contact_geometry, Title: Contact geometry
# Link: https://en.wikipedia.org/wiki/Convex_geometry, Title: Convex geometry
# Link: https://en.wikipedia.org/wiki/Descriptive_geometry, Title: Descriptive geometry
# Link: https://en.wikipedia.org/wiki/Differential_geometry, Title: Differential geometry
# Link: https://en.wikipedia.org/wiki/Digital_geometry, Title: Digital geometry
# Link: https://en.wikipedia.org/wiki/Discrete_geometry, Title: Discrete geometry
# Link: https://en.wikipedia.org/wiki/Distance_geometry, Title: Distance geometry
# Link: https://en.wikipedia.org/wiki/Elliptic_geometry, Title: Elliptic geometry
# Link: https://en.wikipedia.org/wiki/Enumerative_geometry, Title: Enumerative geometry
# Link: https://en.wikipedia.org/wiki/Epipolar_geometry, Title: Epipolar geometry
# Link: https://en.wikipedia.org/wiki/Finite_geometry, Title: Finite geometry
# Link: https://en.wikipedia.org/wiki/Fractal_geometry, Title: Fractal geometry
# Link: https://en.wikipedia.org/wiki/Geometry_of_numbers, Title: Geometry of numbers
# Link: https://en.wikipedia.org/wiki/Hyperbolic_geometry, Title: Hyperbolic geometry
# Link: https://en.wikipedia.org/wiki/Incidence_geometry, Title: Incidence geometry
# Link: https://en.wikipedia.org/wiki/Information_geometry, Title: Information geometry
# Link: https://en.wikipedia.org/wiki/Integral_geometry, Title: Integral geometry
# Link: https://en.wikipedia.org/wiki/Inversive_geometry, Title: Inversive geometry
# Link: https://en.wikipedia.org/wiki/Inversive_ring_geometry, Title: Inversive ring geometry
# Link: https://en.wikipedia.org/wiki/Klein_geometry, Title: Klein geometry
# Link: https://en.wikipedia.org/wiki/Lie_sphere_geometry, Title: Lie sphere geometry
# Link: https://en.wikipedia.org/wiki/Non-Euclidean_geometry, Title: Non-Euclidean geometry
# Link: https://en.wikipedia.org/wiki/Noncommutative_algebraic_geometry, Title: Noncommutative algebraic geometry
# Link: https://en.wikipedia.org/wiki/Noncommutative_geometry, Title: Noncommutative geometry
# Link: https://en.wikipedia.org/wiki/Computational_geometry#Numerical_computational_geometry, Title: Computational geometry
# Link: https://en.wikipedia.org/wiki/Ordered_geometry, Title: Ordered geometry
# Link: https://en.wikipedia.org/wiki/Parabolic_geometry_(differential_geometry), Title: Parabolic geometry (differential geometry)
# Link: https://en.wikipedia.org/wiki/Euclidean_plane_geometry, Title: Euclidean plane geometry
# Link: https://en.wikipedia.org/wiki/Projective_geometry, Title: Projective geometry
# Link: https://en.wikipedia.org/wiki/Quantum_geometry, Title: Quantum geometry
# Link: https://en.wikipedia.org/wiki/Riemannian_geometry, Title: Riemannian geometry
# Link: https://en.wikipedia.org/wiki/Ruppeiner_geometry, Title: Ruppeiner geometry
# Link: https://en.wikipedia.org/wiki/Spherical_geometry, Title: Spherical geometry
# Link: https://en.wikipedia.org/wiki/Symplectic_geometry, Title: Symplectic geometry
# Link: https://en.wikipedia.org/wiki/Synthetic_geometry, Title: Synthetic geometry
# Link: https://en.wikipedia.org/wiki/Systolic_geometry, Title: Systolic geometry
# Link: https://en.wikipedia.org/wiki/Taxicab_geometry, Title: Taxicab geometry
# Link: https://en.wikipedia.org/wiki/Toric_geometry, Title: Toric geometry
# Link: https://en.wikipedia.org/wiki/Transformation_geometry, Title: Transformation geometry
# Link: https://en.wikipedia.org/wiki/Tropical_geometry, Title: Tropical geometry
# CSV saved: dataframes/Absolute_geometry.csv
# CSV saved: dataframes/Affine_geometry.csv
# CSV saved: dataframes/Algebraic_geometry.csv
# CSV saved: dataframes/Analytic_geometry.csv
# CSV saved: dataframes/Archimedes%27_use_of_infinitesimals.csv
# CSV saved: dataframes/Birational_geometry.csv
# CSV saved: dataframes/Complex_geometry.csv
# CSV saved: dataframes/Combinatorial_geometry.csv
# CSV saved: dataframes/Computational_geometry.csv
# CSV saved: dataframes/Conformal_geometry.csv
# CSV saved: dataframes/Constructive_solid_geometry.csv
# CSV saved: dataframes/Contact_geometry.csv
# CSV saved: dataframes/Convex_geometry.csv
# CSV saved: dataframes/Descriptive_geometry.csv
# CSV saved: dataframes/Differential_geometry.csv
# CSV saved: dataframes/Digital_geometry.csv
# CSV saved: dataframes/Discrete_geometry.csv
# CSV saved: dataframes/Distance_geometry.csv
# CSV saved: dataframes/Elliptic_geometry.csv
# CSV saved: dataframes/Enumerative_geometry.csv
# CSV saved: dataframes/Epipolar_geometry.csv
# CSV saved: dataframes/Finite_geometry.csv
# CSV saved: dataframes/Fractal_geometry.csv
# CSV saved: dataframes/Geometry_of_numbers.csv
# CSV saved: dataframes/Hyperbolic_geometry.csv
# CSV saved: dataframes/Incidence_geometry.csv
# CSV saved: dataframes/Information_geometry.csv
# CSV saved: dataframes/Integral_geometry.csv
# CSV saved: dataframes/Inversive_geometry.csv
# CSV saved: dataframes/Inversive_ring_geometry.csv
# CSV saved: dataframes/Klein_geometry.csv
# CSV saved: dataframes/Lie_sphere_geometry.csv
# CSV saved: dataframes/Non-Euclidean_geometry.csv
# CSV saved: dataframes/Noncommutative_algebraic_geometry.csv
# CSV saved: dataframes/Noncommutative_geometry.csv
# CSV saved: dataframes/Computational_geometry#Numerical_computational_geometry.csv
# CSV saved: dataframes/Ordered_geometry.csv
# CSV saved: dataframes/Parabolic_geometry_(differential_geometry).csv
# CSV saved: dataframes/Euclidean_plane_geometry.csv
# CSV saved: dataframes/Projective_geometry.csv
# CSV saved: dataframes/Quantum_geometry.csv
# CSV saved: dataframes/Riemannian_geometry.csv
# CSV saved: dataframes/Ruppeiner_geometry.csv
# CSV saved: dataframes/Spherical_geometry.csv
# CSV saved: dataframes/Symplectic_geometry.csv
# CSV saved: dataframes/Synthetic_geometry.csv
# CSV saved: dataframes/Systolic_geometry.csv
# CSV saved: dataframes/Taxicab_geometry.csv
# CSV saved: dataframes/Toric_geometry.csv
# CSV saved: dataframes/Transformation_geometry.csv
# CSV saved: dataframes/Tropical_geometry.csv
# Link: https://en.wikipedia.org/wiki/Geometry, Title: Geometry
# Link: https://en.wikipedia.org/wiki/Analytic_geometry, Title: Analytic geometry
# Link: https://en.wikipedia.org/wiki/Differential_geometry, Title: Differential geometry
# Link: https://en.wikipedia.org/wiki/Euclidean_geometry, Title: Euclidean geometry
# Link: https://en.wikipedia.org/wiki/Non-Euclidean_geometry, Title: Non-Euclidean geometry
# Link: https://en.wikipedia.org/wiki/Projective_geometry, Title: Projective geometry
# Link: https://en.wikipedia.org/wiki/Riemannian_geometry, Title: Riemannian geometry
# CSV saved: dataframes/Geometry.csv
# CSV saved: dataframes/Analytic_geometry.csv
# CSV saved: dataframes/Differential_geometry.csv
# CSV saved: dataframes/Euclidean_geometry.csv
# CSV saved: dataframes/Non-Euclidean_geometry.csv
# CSV saved: dataframes/Projective_geometry.csv
# CSV saved: dataframes/Riemannian_geometry.csv
# Link: https://en.wikipedia.org/wiki/Geometry, Title: Geometry
# Link: https://en.wikipedia.org/wiki/Angle, Title: Angle
# Link: https://en.wikipedia.org/wiki/Ratio, Title: Ratio
# CSV saved: dataframes/Geometry.csv
# CSV saved: dataframes/Angle.csv
# CSV saved: dataframes/Ratio.csv
# Link: https://en.wikipedia.org/wiki/Geometry, Title: Geometry
# Link: https://en.wikipedia.org/wiki/Angle, Title: Angle
# Link: https://en.wikipedia.org/wiki/Ratio, Title: Ratio
# CSV saved: dataframes/Geometry.csv
# CSV saved: dataframes/Angle.csv
# CSV saved: dataframes/Ratio.csv
# Link: https://en.wikipedia.org/wiki/Natural_logarithm, Title: Natural logarithm
# Link: https://en.wikipedia.org/wiki/Arg_(mathematics), Title: Arg (mathematics)
# Link: https://en.wikipedia.org/wiki/Atan2, Title: Atan2
# CSV saved: dataframes/Natural_logarithm.csv
# CSV saved: dataframes/Arg_(mathematics).csv
# CSV saved: dataframes/Atan2.csv
# Link: https://en.wikipedia.org/wiki/List_of_mathematical_identities, Title: List of mathematical identities
# Link: https://en.wikipedia.org/wiki/Lists_of_mathematics_topics, Title: Lists of mathematics topics
# CSV saved: dataframes/List_of_mathematical_identities.csv
# CSV saved: dataframes/Lists_of_mathematics_topics.csv
# Link: https://en.wikipedia.org/wiki/Analytic-synthetic_distinction, Title: Analytic-synthetic distinction
# Link: https://en.wikipedia.org/wiki/Antinomy, Title: Antinomy
# Link: https://en.wikipedia.org/wiki/A_priori_and_a_posteriori, Title: A priori and a posteriori
# Link: https://en.wikipedia.org/wiki/Definition, Title: Definition
# Link: https://en.wikipedia.org/wiki/Description, Title: Description
# Link: https://en.wikipedia.org/wiki/Entailment, Title: Entailment
# Link: https://en.wikipedia.org/wiki/Identity_(philosophy), Title: Identity (philosophy)
# Link: https://en.wikipedia.org/wiki/Inference, Title: Inference
# Link: https://en.wikipedia.org/wiki/Logical_form, Title: Logical form
# Link: https://en.wikipedia.org/wiki/Logical_implication, Title: Logical implication
# Link: https://en.wikipedia.org/wiki/Logical_truth, Title: Logical truth
# Link: https://en.wikipedia.org/wiki/Logical_consequence, Title: Logical consequence
# Link: https://en.wikipedia.org/wiki/Name, Title: Name
# Link: https://en.wikipedia.org/wiki/Necessary_and_sufficient_condition, Title: Necessary and sufficient condition
# Link: https://en.wikipedia.org/wiki/Material_conditional, Title: Material conditional
# Link: https://en.wikipedia.org/wiki/Meaning_(linguistic), Title: Meaning (linguistic)
# Link: https://en.wikipedia.org/wiki/Meaning_(non-linguistic), Title: Meaning (non-linguistic)
# Link: https://en.wikipedia.org/wiki/Paradox, Title: Paradox
# Link: https://en.wikipedia.org/wiki/List_of_paradoxes, Title: List of paradoxes
# Link: https://en.wikipedia.org/wiki/Possible_world, Title: Possible world
# Link: https://en.wikipedia.org/wiki/Presupposition, Title: Presupposition
# Link: https://en.wikipedia.org/wiki/Probability, Title: Probability
# Link: https://en.wikipedia.org/wiki/Quantification_(logic), Title: Quantification (logic)
# Link: https://en.wikipedia.org/wiki/Reason, Title: Reason
# Link: https://en.wikipedia.org/wiki/Reasoning, Title: Reasoning
# Link: https://en.wikipedia.org/wiki/Reference, Title: Reference
# Link: https://en.wikipedia.org/wiki/Semantics, Title: Semantics
# Link: https://en.wikipedia.org/wiki/Strict_conditional, Title: Strict conditional
# Link: https://en.wikipedia.org/wiki/Syntax_(logic), Title: Syntax (logic)
# Link: https://en.wikipedia.org/wiki/Truth, Title: Truth
# Link: https://en.wikipedia.org/wiki/Truth_value, Title: Truth value
# Link: https://en.wikipedia.org/wiki/Validity_(logic), Title: Validity (logic)
# CSV saved: dataframes/Analytic-synthetic_distinction.csv
# CSV saved: dataframes/Antinomy.csv
# CSV saved: dataframes/A_priori_and_a_posteriori.csv
# CSV saved: dataframes/Definition.csv
# CSV saved: dataframes/Description.csv
# CSV saved: dataframes/Entailment.csv
# CSV saved: dataframes/Identity_(philosophy).csv
# CSV saved: dataframes/Inference.csv
# CSV saved: dataframes/Logical_form.csv
# CSV saved: dataframes/Logical_implication.csv
# CSV saved: dataframes/Logical_truth.csv
# CSV saved: dataframes/Logical_consequence.csv
# CSV saved: dataframes/Name.csv
# CSV saved: dataframes/Necessary_and_sufficient_condition.csv
# CSV saved: dataframes/Material_conditional.csv
# CSV saved: dataframes/Meaning_(linguistic).csv
# CSV saved: dataframes/Meaning_(non-linguistic).csv
# CSV saved: dataframes/Paradox.csv
# CSV saved: dataframes/List_of_paradoxes.csv
# CSV saved: dataframes/Possible_world.csv
# CSV saved: dataframes/Presupposition.csv
# CSV saved: dataframes/Probability.csv
# CSV saved: dataframes/Quantification_(logic).csv
# CSV saved: dataframes/Reason.csv
# CSV saved: dataframes/Reasoning.csv
# CSV saved: dataframes/Reference.csv
# CSV saved: dataframes/Semantics.csv
# CSV saved: dataframes/Strict_conditional.csv
# CSV saved: dataframes/Syntax_(logic).csv
# CSV saved: dataframes/Truth.csv
# CSV saved: dataframes/Truth_value.csv
# CSV saved: dataframes/Validity_(logic).csv

# %%
def add_translated_row_to_csv(csv_file_path, original_title):
    # Read the existing CSV file into a DataFrame
    df = pd.read_csv(csv_file_path)

    # Create a new DataFrame for the desired columns
    new_df = pd.DataFrame(columns=['Language', 'Translation'])

    # Add 'en' row with the original title as the formatted title
    new_row_en = pd.DataFrame({'Language': ['en'], 'Translation': [original_title]})
    new_df = pd.concat([new_df, new_row_en], ignore_index=True)

    # Add 'es' row with the Spanish translation
    spanish_translation = df[df['Language'] == 'es']['Title'].values[0] if 'es' in df['Language'].values else 'NaN'
    new_row_es = pd.DataFrame({'Language': ['es'], 'Translation': [spanish_translation]})
    new_df = pd.concat([new_df, new_row_es], ignore_index=True)

    # Add 'de' row with the German translation
    german_translation = df[df['Language'] == 'de']['Title'].values[0] if 'de' in df['Language'].values else 'NaN'
    new_row_de = pd.DataFrame({'Language': ['de'], 'Translation': [german_translation]})
    new_df = pd.concat([new_df, new_row_de], ignore_index=True)

    # Define the path to the 'translations' folder within the 'dataframes' directory
    translations_folder = os.path.join('dataframes', 'translations')

    # Create the 'translations' folder if it doesn't exist
    os.makedirs(translations_folder, exist_ok=True)

    # Save the new DataFrame to a CSV file in the 'translations' folder
    translated_csv_path = os.path.join(translations_folder, f'{original_title}_translated.csv')
    new_df.to_csv(translated_csv_path, index=False)

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

def scrape_links_process_and_find_translation(webpage_url):
    csv_file_names = []  # Store the names of the created CSV files
    titles_list = []  # Store the titles extracted from the links

    try:
        # Send an HTTP GET request to the webpage_url
        response = requests.get(webpage_url)

        # Check if the request was successful (status code 200)
        if response.status_code == 200:
            # Parse the HTML content of the webpage
            soup = BeautifulSoup(response.content, 'html.parser')

            # Find the <meta> tag with property="mw:PageProp/toc"
            toc_meta_tag = soup.find('meta', attrs={'property': 'mw:PageProp/toc'})

            # Check if the <meta> tag exists
            if toc_meta_tag:
                # Find the <ul> (unordered list) tag that follows the <meta> tag
                ul_tag = toc_meta_tag.find_next('ul')

                # Find all the <a> (anchor) tags within the <ul> tag
                links = ul_tag.find_all('a')

                # Extract and append the href attribute of each <a> tag to the formatted_links list
                formatted_links = []
                for link in links:
                    href = link.get('href')
                    formatted_link = f"https://en.wikipedia.org{href}"
                    formatted_links.append(formatted_link)  # Append the formatted URL to the list
                    title = link.get('title')
                    titles_list.append(title)  # Append the extracted title to the list
                    print(f"Link: {formatted_link}, Title: {title}")

                # Rest of your code...

            else:
                print("No <meta> tag with property='mw:PageProp/toc' found on the page.")

        else:
            print(f"Failed to retrieve the webpage. Status code: {response.status_code}")

    except requests.exceptions.RequestException as e:
        print(f"Error: {e}")

    return csv_file_names, titles_list  # Return the list of created CSV file names and titles

webpage_url = 'https://en.wikipedia.org/wiki/List_of_geometry_topics'
created_csv_files, titles = scrape_links_process_and_find_translation(webpage_url)

# Print the list of titles
print(titles)
# Out:
# Link: https://en.wikipedia.org/wiki/Absolute_geometry, Title: Absolute geometry
# Link: https://en.wikipedia.org/wiki/Affine_geometry, Title: Affine geometry
# Link: https://en.wikipedia.org/wiki/Algebraic_geometry, Title: Algebraic geometry
# Link: https://en.wikipedia.org/wiki/Analytic_geometry, Title: Analytic geometry
# Link: https://en.wikipedia.org/wiki/Archimedes%27_use_of_infinitesimals, Title: Archimedes' use of infinitesimals
# Link: https://en.wikipedia.org/wiki/Birational_geometry, Title: Birational geometry
# Link: https://en.wikipedia.org/wiki/Complex_geometry, Title: Complex geometry
# Link: https://en.wikipedia.org/wiki/Combinatorial_geometry, Title: Combinatorial geometry
# Link: https://en.wikipedia.org/wiki/Computational_geometry, Title: Computational geometry
# Link: https://en.wikipedia.org/wiki/Conformal_geometry, Title: Conformal geometry
# Link: https://en.wikipedia.org/wiki/Constructive_solid_geometry, Title: Constructive solid geometry
# Link: https://en.wikipedia.org/wiki/Contact_geometry, Title: Contact geometry
# Link: https://en.wikipedia.org/wiki/Convex_geometry, Title: Convex geometry
# Link: https://en.wikipedia.org/wiki/Descriptive_geometry, Title: Descriptive geometry
# Link: https://en.wikipedia.org/wiki/Differential_geometry, Title: Differential geometry
# Link: https://en.wikipedia.org/wiki/Digital_geometry, Title: Digital geometry
# Link: https://en.wikipedia.org/wiki/Discrete_geometry, Title: Discrete geometry
# Link: https://en.wikipedia.org/wiki/Distance_geometry, Title: Distance geometry
# Link: https://en.wikipedia.org/wiki/Elliptic_geometry, Title: Elliptic geometry
# Link: https://en.wikipedia.org/wiki/Enumerative_geometry, Title: Enumerative geometry
# Link: https://en.wikipedia.org/wiki/Epipolar_geometry, Title: Epipolar geometry
# Link: https://en.wikipedia.org/wiki/Finite_geometry, Title: Finite geometry
# Link: https://en.wikipedia.org/wiki/Fractal_geometry, Title: Fractal geometry
# Link: https://en.wikipedia.org/wiki/Geometry_of_numbers, Title: Geometry of numbers
# Link: https://en.wikipedia.org/wiki/Hyperbolic_geometry, Title: Hyperbolic geometry
# Link: https://en.wikipedia.org/wiki/Incidence_geometry, Title: Incidence geometry
# Link: https://en.wikipedia.org/wiki/Information_geometry, Title: Information geometry
# Link: https://en.wikipedia.org/wiki/Integral_geometry, Title: Integral geometry
# Link: https://en.wikipedia.org/wiki/Inversive_geometry, Title: Inversive geometry
# Link: https://en.wikipedia.org/wiki/Inversive_ring_geometry, Title: Inversive ring geometry
# Link: https://en.wikipedia.org/wiki/Klein_geometry, Title: Klein geometry
# Link: https://en.wikipedia.org/wiki/Lie_sphere_geometry, Title: Lie sphere geometry
# Link: https://en.wikipedia.org/wiki/Non-Euclidean_geometry, Title: Non-Euclidean geometry
# Link: https://en.wikipedia.org/wiki/Noncommutative_algebraic_geometry, Title: Noncommutative algebraic geometry
# Link: https://en.wikipedia.org/wiki/Noncommutative_geometry, Title: Noncommutative geometry
# Link: https://en.wikipedia.org/wiki/Computational_geometry#Numerical_computational_geometry, Title: Computational geometry
# Link: https://en.wikipedia.org/wiki/Ordered_geometry, Title: Ordered geometry
# Link: https://en.wikipedia.org/wiki/Parabolic_geometry_(differential_geometry), Title: Parabolic geometry (differential geometry)
# Link: https://en.wikipedia.org/wiki/Euclidean_plane_geometry, Title: Euclidean plane geometry
# Link: https://en.wikipedia.org/wiki/Projective_geometry, Title: Projective geometry
# Link: https://en.wikipedia.org/wiki/Quantum_geometry, Title: Quantum geometry
# Link: https://en.wikipedia.org/wiki/Riemannian_geometry, Title: Riemannian geometry
# Link: https://en.wikipedia.org/wiki/Ruppeiner_geometry, Title: Ruppeiner geometry
# Link: https://en.wikipedia.org/wiki/Spherical_geometry, Title: Spherical geometry
# Link: https://en.wikipedia.org/wiki/Symplectic_geometry, Title: Symplectic geometry
# Link: https://en.wikipedia.org/wiki/Synthetic_geometry, Title: Synthetic geometry
# Link: https://en.wikipedia.org/wiki/Systolic_geometry, Title: Systolic geometry
# Link: https://en.wikipedia.org/wiki/Taxicab_geometry, Title: Taxicab geometry
# Link: https://en.wikipedia.org/wiki/Toric_geometry, Title: Toric geometry
# Link: https://en.wikipedia.org/wiki/Transformation_geometry, Title: Transformation geometry
# Link: https://en.wikipedia.org/wiki/Tropical_geometry, Title: Tropical geometry
# ['Absolute geometry', 'Affine geometry', 'Algebraic geometry', 'Analytic geometry', "Archimedes' use of infinitesimals", 'Birational geometry', 'Complex geometry', 'Combinatorial geometry', 'Computational geometry', 'Conformal geometry', 'Constructive solid geometry', 'Contact geometry', 'Convex geometry', 'Descriptive geometry', 'Differential geometry', 'Digital geometry', 'Discrete geometry', 'Distance geometry', 'Elliptic geometry', 'Enumerative geometry', 'Epipolar geometry', 'Finite geometry', 'Fractal geometry', 'Geometry of numbers', 'Hyperbolic geometry', 'Incidence geometry', 'Information geometry', 'Integral geometry', 'Inversive geometry', 'Inversive ring geometry', 'Klein geometry', 'Lie sphere geometry', 'Non-Euclidean geometry', 'Noncommutative algebraic geometry', 'Noncommutative geometry', 'Computational geometry', 'Ordered geometry', 'Parabolic geometry (differential geometry)', 'Euclidean plane geometry', 'Projective geometry', 'Quantum geometry', 'Riemannian geometry', 'Ruppeiner geometry', 'Spherical geometry', 'Symplectic geometry', 'Synthetic geometry', 'Systolic geometry', 'Taxicab geometry', 'Toric geometry', 'Transformation geometry', 'Tropical geometry']

# %%
10
# Out:
# 10
