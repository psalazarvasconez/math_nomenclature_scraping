# %%
import os
import csv
import numpy as np


def merge_all_csv_files_in_directory(directory_path):
    """
    Merge all CSV files in a directory into a single CSV file.

    Args:
        directory_path (str): Path to the directory containing CSV files.

    Returns:
        None
    """
    merged_data = {}
    languages = set()

    # List all files in the directory
    csv_files = [file for file in os.listdir(directory_path) if file.endswith('.csv')]

    # Iterate through CSV files and gather data
    for file_name in csv_files:
        file_path = os.path.join(directory_path, file_name)
        with open(file_path, mode='r', encoding='utf-8') as csv_file:
            csv_reader = csv.DictReader(csv_file)
            for row in csv_reader:
                language = row['Language']
                title = row['Title']
                if language not in merged_data:
                    merged_data[language] = {}
                merged_data[language][file_name] = title
                languages.add(language)

    # Create a list of dictionaries for the merged data
    merged_list = []
    for language in languages:
        merged_dict = {'Language': language}
        for file_name in csv_files:
            title = merged_data.get(language, {}).get(file_name, '')
            merged_dict[file_name] = title
        merged_list.append(merged_dict)

    # Create a merged CSV file
    merged_csv_path = os.path.join(directory_path, 'merged_translations.csv')
    with open(merged_csv_path, mode='w', encoding='utf-8', newline='') as merged_csv_file:
        fieldnames = ['Language'] + csv_files
        csv_writer = csv.DictWriter(merged_csv_file, fieldnames=fieldnames)
        csv_writer.writeheader()
        csv_writer.writerows(merged_list)

# Directory path where the CSV files are located
csv_directory = 'dataframes/clean_translations/'

# Merge all CSV files into a single CSV file
merge_all_csv_files_in_directory(csv_directory)

print("Merged data saved to 'merged_translations.csv'")

# %%
import pandas as pd

df = pd.read_csv('dataframes/clean_translations/merged_translations.csv', encoding='utf-8')

# %%
df.transpose()
# Out:
#                                                                                   0  \
# Language                                                                         es
# Logical connective_translated.csv                                  Conectiva lógica
# Basis (linear algebra)_translated.csv                                Base (álgebra)
# Ternary operation_translated.csv                                 Operación ternaria
# Description logic_translated.csv                              Lógica de descripción
# ...                                                                             ...
# (ε, δ)-definition of limit_translated.csv                     Límite de una función
# Limit (mathematics)_translated.csv                              Límite (matemática)
# Zeros and poles_translated.csv                             Polo (análisis complejo)
# A priori and a posteriori_translated.csv                    A priori y a posteriori
# Limit superior and limit inferior_translated.csv  Límite superior y límite inferior
#
#                                                                                   1  \
# Language                                                                         de
# Logical connective_translated.csv                              Logische Verknüpfung
# Basis (linear algebra)_translated.csv                            Basis (Vektorraum)
# Ternary operation_translated.csv                                  Ternärer Operator
# Description logic_translated.csv                                 Beschreibungslogik
# ...                                                                             ...
# (ε, δ)-definition of limit_translated.csv                      Grenzwert (Funktion)
# Limit (mathematics)_translated.csv                                        Grenzwert
# Zeros and poles_translated.csv                                            Polstelle
# A priori and a posteriori_translated.csv                               Vor und nach
# Limit superior and limit inferior_translated.csv  Limes superior und Limes inferior
#
#                                                                                   2
# Language                                                                         en
# Logical connective_translated.csv                                Logical connective
# Basis (linear algebra)_translated.csv                        Basis (linear algebra)
# Ternary operation_translated.csv                                  Ternary operation
# Description logic_translated.csv                                  Description logic
# ...                                                                             ...
# (ε, δ)-definition of limit_translated.csv                (ε, δ)-definition of limit
# Limit (mathematics)_translated.csv                              Limit (mathematics)
# Zeros and poles_translated.csv                                      Zeros and poles
# A priori and a posteriori_translated.csv                  A priori and a posteriori
# Limit superior and limit inferior_translated.csv  Limit superior and limit inferior
#
# [224 rows x 3 columns]

# %%
import numpy as np
df = df.replace('NaN', np.nan)

# Count NaN values in each column
nan_count = df.isna().sum()

# Filter columns with NaN values
columns_with_nan = nan_count[nan_count > 0]

print(columns_with_nan)
# Out:
# Series([], dtype: int64)

# %%
df.shape
# Out:
# (3, 224)

# %%
trans_df=df.transpose()

# %%
# Specify the file path where you want to save the CSV file
file_path = 'dictionary_data.csv'

# Use the to_csv method to write the DataFrame to a CSV file
trans_df.to_csv(file_path, index=False)  # Set index=False to exclude the index column in the CSV

# %%
import pandas as pd

# Read data from the CSV file
df = pd.read_csv('dictionary_data.csv')

def search_dataframe(language, search_string):
    if language == 'es':
        column = 'es'
    elif language == 'de':
        column = 'de'
    elif language == 'en':
        column = 'en'
    else:
        return "Invalid language code. Please use 'es', 'de', or 'en'."

    # Perform the partial string match search
    result = df[df[column].str.contains(search_string, case=False, na=False)]
    
    return result

# Example usage:
language = input("Enter language code (es/de/en): ")
search_string = input("Enter search string: ")

result = search_dataframe(language, search_string)

if not result.empty:
    print(result)
else:
    print("No matching rows found.")
# Out:
# Enter language code (es/de/en):  es
# Enter search string:  geo
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/opt/anaconda3/envs/DictionaryWebScrapingPorcess/lib/python3.9/site-packages/pandas/core/indexes/base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'es'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[16], line 25
#      22 language = input("Enter language code (es/de/en): ")
#      23 search_string = input("Enter search string: ")
# ---> 25 result = search_dataframe(language, search_string)
#      27 if not result.empty:
#      28     print(result)
#
# Cell In[16], line 17, in search_dataframe(language, search_string)
#      14     return "Invalid language code. Please use 'es', 'de', or 'en'."
#      16 # Perform the partial string match search
# ---> 17 result = df[df[column].str.contains(search_string, case=False, na=False)]
#      19 return result
#
# File ~/opt/anaconda3/envs/DictionaryWebScrapingPorcess/lib/python3.9/site-packages/pandas/core/frame.py:3896, in DataFrame.__getitem__(self, key)
#    3894 if self.columns.nlevels > 1:
#    3895     return self._getitem_multilevel(key)
# -> 3896 indexer = self.columns.get_loc(key)
#    3897 if is_integer(indexer):
#    3898     indexer = [indexer]
#
# File ~/opt/anaconda3/envs/DictionaryWebScrapingPorcess/lib/python3.9/site-packages/pandas/core/indexes/base.py:3797, in Index.get_loc(self, key)
#    3792     if isinstance(casted_key, slice) or (
#    3793         isinstance(casted_key, abc.Iterable)
#    3794         and any(isinstance(x, slice) for x in casted_key)
#    3795     ):
#    3796         raise InvalidIndexError(key)
# -> 3797     raise KeyError(key) from err
#    3798 except TypeError:
#    3799     # If we have a listlike key, _check_indexing_error will raise
#    3800     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3801     #  the TypeError.
#    3802     self._check_indexing_error(key)
#
# KeyError: 'es'

# %%
import pandas as pd

# Read data from the CSV file
df = pd.read_csv('dictionary_data.csv')

def search_dataframe(language, search_string):
    if language == 'es':
        column = 'es'
    elif language == 'de':
        column = 'de'
    elif language == 'en':
        column = 'en'
    else:
        return "Invalid language code. Please use 'es', 'de', or 'en'."

    # Perform the partial string match search
    result = df[df[column].str.contains(search_string, case=False, na=False)]
    
    return result

def display_options(result):
    if result.empty:
        print("No matching rows found.")
        return

    print("Choose an option:")
    for i, option in enumerate(result.iterrows(), 1):
        index, row = option
        print(f"{i}. {row[language]}")

    choice = int(input("Enter the number of your choice: "))

    if choice < 1 or choice > len(result):
        print("Invalid choice.")
    else:
        chosen_option = result.iloc[choice - 1]
        print("\nChosen Option:")
        print(f"{chosen_option[language]}\n")
        for col in df.columns:
            if col != language:
                print(f"{col}: {chosen_option[col]}")

# Example usage:
language = input("Enter language code (es/de/en): ")
search_string = input("Enter search string: ")

result = search_dataframe(language, search_string)
display_options(result)
# Out:
# Enter language code (es/de/en):  es
# Enter search string:  lími
# Choose an option:
# 1. Límite de una función
# 2. Límite de una sucesión
# 3. Límite de una función
# 4. Límite (matemática)
# 5. Límite superior y límite inferior
# Enter the number of your choice:  5
# Chosen Option:
# Límite superior y límite inferior
#
# de: Limes superior und Limes inferior
# en: Limit superior and limit inferior

# %%
import pandas as pd
from unidecode import unidecode  # Import unidecode

# Read data from the CSV file
df = pd.read_csv('dictionary_data.csv')

# Define a function to remove accents from a string
def remove_accents(input_str):
    return unidecode(input_str)

def search_dataframe(language, search_string):
    # Remove accents from the search string
    search_string = remove_accents(search_string)
    
    if language == 'es':
        column = 'es'
    elif language == 'de':
        column = 'de'
    elif language == 'en':
        column = 'en'
    else:
        return "Invalid language code. Please use 'es', 'de', or 'en'."

    # Remove accents from the data in the selected column
    df[column] = df[column].apply(remove_accents)

    # Perform the partial string match search
    result = df[df[column].str.contains(search_string, case=False, na=False)]
    
    return result

def display_options(result):
    if result.empty:
        print("No matching rows found.")
        return

    print("Choose an option:")
    for i, option in enumerate(result.iterrows(), 1):
        index, row = option
        print(f"{i}. {row[language]}")

    choice = int(input("Enter the number of your choice: "))

    if choice < 1 or choice > len(result):
        print("Invalid choice.")
    else:
        chosen_option = result.iloc[choice - 1]
        print("\nChosen Option:")
        print(f"{chosen_option[language]}\n")
        for col in df.columns:
            if col != language:
                print(f"{col}: {chosen_option[col]}")

# Example usage:
language = input("Enter language code (es/de/en): ")
search_string = input("Enter search string: ")

result = search_dataframe(language, search_string)
display_options(result)
# Out:
# Enter language code (es/de/en):  es
# Enter search string:  limi
# Choose an option:
# 1. Limite de una funcion
# 2. Limite de una sucesion
# 3. Limite de una funcion
# 4. Limite (matematica)
# 5. Limite superior y limite inferior
# Enter the number of your choice:  4
# Chosen Option:
# Limite (matematica)
#
# de: Grenzwert
# en: Limit (mathematics)

# %%
import pandas as pd
from unidecode import unidecode

# Read data from the CSV file
df = pd.read_csv('dictionary_data.csv')

# Define a function to remove accents from a string
def remove_accents(input_str):
    return unidecode(input_str)

def search_dataframe(language, search_string):
    # Remove accents from the search string
    search_string = remove_accents(search_string)
    
    if language == 'es':
        column = 'es'
    elif language == 'de':
        column = 'de'
    elif language == 'en':
        column = 'en'
    else:
        return "Invalid language code. Please use 'es', 'de', or 'en'."

    # Remove accents from the data in the selected column
    df[column] = df[column].apply(remove_accents)

    # Perform the partial string match search
    result = df[df[column].str.contains(search_string, case=False, na=False)]
    
    return result

def display_options(result):
    if result.empty:
        print("No matching rows found.")
        return

    print("Choose an option:")
    options = []
    for i, option in enumerate(result.iterrows(), 1):
        index, row = option
        options.append(row[language])

    for i, option in enumerate(options, 1):
        print(f"{i}. {option}")

    choice = input("Enter the number of your choice: ")

    if not choice.isdigit() or int(choice) < 1 or int(choice) > len(options):
        print("Invalid choice.")
    else:
        choice = int(choice)
        chosen_option = result.iloc[choice - 1]
        print("\nChosen Option:")
        print(f"{chosen_option[language]}\n")
        for col in df.columns:
            if col != language:
                print(f"{col}: {chosen_option[col]}")

# Language options for the dropdown list
languages = ['es', 'de', 'en']

# Prompt the user to select a language from the menu
while True:
    print("Select a language:")
    for i, lang in enumerate(languages, 1):
        print(f"{i}. {lang}")

    choice = input("Enter the number of your choice: ")

    if not choice.isdigit() or int(choice) < 1 or int(choice) > len(languages):
        print("Invalid choice. Please select a valid language.")
    else:
        language = languages[int(choice) - 1]
        break

search_string = input("Enter search string: ")

result = search_dataframe(language, search_string)
display_options(result)
# Out:
# Select a language:
# 1. es
# 2. de
# 3. en
# Enter the number of your choice:  1
# Enter search string:  e
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/opt/anaconda3/envs/DictionaryWebScrapingPorcess/lib/python3.9/site-packages/pandas/core/indexes/base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'es'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[15], line 78
#      74         break
#      76 search_string = input("Enter search string: ")
# ---> 78 result = search_dataframe(language, search_string)
#      79 display_options(result)
#
# Cell In[15], line 25, in search_dataframe(language, search_string)
#      22     return "Invalid language code. Please use 'es', 'de', or 'en'."
#      24 # Remove accents from the data in the selected column
# ---> 25 df[column] = df[column].apply(remove_accents)
#      27 # Perform the partial string match search
#      28 result = df[df[column].str.contains(search_string, case=False, na=False)]
#
# File ~/opt/anaconda3/envs/DictionaryWebScrapingPorcess/lib/python3.9/site-packages/pandas/core/frame.py:3896, in DataFrame.__getitem__(self, key)
#    3894 if self.columns.nlevels > 1:
#    3895     return self._getitem_multilevel(key)
# -> 3896 indexer = self.columns.get_loc(key)
#    3897 if is_integer(indexer):
#    3898     indexer = [indexer]
#
# File ~/opt/anaconda3/envs/DictionaryWebScrapingPorcess/lib/python3.9/site-packages/pandas/core/indexes/base.py:3797, in Index.get_loc(self, key)
#    3792     if isinstance(casted_key, slice) or (
#    3793         isinstance(casted_key, abc.Iterable)
#    3794         and any(isinstance(x, slice) for x in casted_key)
#    3795     ):
#    3796         raise InvalidIndexError(key)
# -> 3797     raise KeyError(key) from err
#    3798 except TypeError:
#    3799     # If we have a listlike key, _check_indexing_error will raise
#    3800     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3801     #  the TypeError.
#    3802     self._check_indexing_error(key)
#
# KeyError: 'es'

# %%
from unidecode import unidecode

def remove_accents(input_str):
    return unidecode(input_str)

def search_and_display(language, search_string, df_path='dictionary_data.csv'):
    try:
        # Read data from the CSV file
        df = pd.read_csv(df_path)

        # Remove accents from the search string
        search_string = remove_accents(search_string)

        if language not in ['es', 'de', 'en']:
            return "Invalid language code. Please use 'es', 'de', or 'en'."

        # Define the column based on the selected language
        column = language

        # Remove accents from the data in the selected column
        df[column] = df[column].apply(remove_accents)

        # Perform the partial string match search
        result = df[df[column].str.contains(search_string, case=False, na=False)]

        if result.empty:
            return "No matching rows found."

        print("Choose an option:")
        options = []
        for i, (_, row) in enumerate(result.iterrows(), 1):
            options.append(row[language])
            print(f"{i}. {row[language]}")

        choice = input("Enter the number of your choice: ")

        if not choice.isdigit() or int(choice) < 1 or int(choice) > len(options):
            return "Invalid choice."
        else:
            choice = int(choice)
            chosen_option = result.iloc[choice - 1]
            output = f"\nChosen Option:\n{chosen_option[language]}\n"
            for col in df.columns:
                if col != language:
                    output += f"{col}: {chosen_option[col]}\n"
            return output

    except Exception as e:
        return str(e)

# Language options for the dropdown list
languages = ['es', 'de', 'en']

# Prompt the user to select a language from the menu
while True:
    print("Select a language:")
    for i, lang in enumerate(languages, 1):
        print(f"{i}. {lang}")

    choice = input("Enter the number of your choice: ")

    if not choice.isdigit() or int(choice) < 1 or int(choice) > len(languages):
        print("Invalid choice. Please select a valid language.")
    else:
        language = languages[int(choice) - 1]
        break

search_string = input("Enter search string: ")

result = search_and_display(language, search_string)

print(result)
# Out:
# Select a language:
# 1. es
# 2. de
# 3. en
# Enter the number of your choice:  2
# Enter search string:  gro
# 'de'

# %%
import pandas as pd
from unidecode import unidecode

# Read data from the CSV file
df = pd.read_csv('dictionary_data.csv')

# Define a function to remove accents from a string
def remove_accents(input_str):
    return unidecode(input_str)

def search_dataframe(df, language, search_string):
    # Remove accents from the search string
    search_string = remove_accents(search_string)
    
    if language == 'es':
        column = 'es'
    elif language == 'de':
        column = 'de'
    elif language == 'en':
        column = 'en'
    else:
        return "Invalid language code. Please use 'es', 'de', or 'en'."

    # Remove accents from the data in the selected column
    df[column] = df[column].apply(remove_accents)

    # Perform the partial string match search
    result = df[df[column].str.contains(search_string, case=False, na=False)]
    
    return result

def display_options(result, language):
    if result.empty:
        print("No matching rows found.")
        return

    print("Choose an option:")
    options = []
    for i, option in enumerate(result.iterrows(), 1):
        index, row = option
        options.append(row[language])

    for i, option in enumerate(options, 1):
        print(f"{i}. {option}")

    choice = input("Enter the number of your choice: ")

    if not choice.isdigit() or int(choice) < 1 or int(choice) > len(options):
        print("Invalid choice.")
    else:
        choice = int(choice)
        chosen_option = result.iloc[choice - 1]
        print("\nChosen Option:")
        print(f"{chosen_option[language]}\n")
        for col in df.columns:
            if col != language:
                print(f"{col}: {chosen_option[col]}")

# Language options for the dropdown list
languages = ['es', 'de', 'en']

# Prompt the user to select a language from the menu
while True:
    print("Select a language:")
    for i, lang in enumerate(languages, 1):
        print(f"{i}. {lang}")

    choice = input("Enter the number of your choice: ")

    if not choice.isdigit() or int(choice) < 1 or int(choice) > len(languages):
        print("Invalid choice. Please select a valid language.")
    else:
        language = languages[int(choice) - 1]
        break

search_string = input("Enter search string: ")

result = search_dataframe(df, language, search_string)
display_options(result, language)
# Out:
# Select a language:
# 1. es
# 2. de
# 3. en
# Enter the number of your choice:  1
# Enter search string:  geo
# Choose an option:
# 1. Geometria sintetica
# 2. Geometria binacional
# 3. Nichtkommutative algebraische Geometrie
# 4. Geometria discreta
# 5. Geometria analitica
# 6. Geometria constructiva de solidos
# 7. Geometria computacional
# 8. Geometria proyectiva
# 9. Geometria de Riemann
# 10. Geometria tropical
# 11. Geometria euclidiana
# 12. Geometria de numeros
# 13. Geometria compleja
# 14. Geometria afin
# 15. Geometria de las transformaciones
# 16. Geometria Epipolar
# 17. Geometria algebraica
# 18. Geometria euclidiana
# 19. Geometria esferica
# 20. Geometria hiperbolica
# 21. Geometria eliptica
# 22. Geometria convexa
# 23. Media aritmetico-geometrica
# 24. Geometria descriptiva
# 25. Geometria integral
# 26. Geometria finita
# 27. Geometria
# 28. Geometria no euclidiana
# 29. Geometria diferencial
# 30. Geometria de contacto
# 31. Geometria absoluta
# 32. Geometria ordenada
# 33. Geometria enumerativa
# 34. Geometria de incidencia
# 35. Geometria cuantica
# 36. Geometria digital
# 37. Geometria del taxista
# 38. Geometria no conmutativa
# 39. Geometria discreta
# Enter the number of your choice:  39
# Chosen Option:
# Geometria discreta
#
# de: Diskrete Geometrie
# en: Discrete geometry
