# %%
import os
import csv
import numpy as np

def merge_all_csv_files_in_directory(directory_path):
    """
    Merge all CSV files in a directory into a single CSV file.

    Args:
        directory_path (str): Path to the directory containing CSV files.

    Returns:
        None
    """
    merged_data = {}
    languages = set()

    # List all files in the directory
    csv_files = [file for file in os.listdir(directory_path) if file.endswith('.csv')]

    # Iterate through CSV files and gather data
    for file_name in csv_files:
        file_path = os.path.join(directory_path, file_name)
        with open(file_path, mode='r', encoding='utf-8') as csv_file:
            csv_reader = csv.DictReader(csv_file)
            for row in csv_reader:
                language = row['Language']
                title = row['Title']
                if language not in merged_data:
                    merged_data[language] = {}
                merged_data[language][file_name] = title
                languages.add(language)

    # Create a list of dictionaries for the merged data
    merged_list = []
    for language in languages:
        merged_dict = {'Language': language}
        for file_name in csv_files:
            title = merged_data.get(language, {}).get(file_name, '')
            merged_dict[file_name] = title
        merged_list.append(merged_dict)

    # Create a merged CSV file
    merged_csv_path = os.path.join(directory_path, 'merged_translations.csv')
    with open(merged_csv_path, mode='w', encoding='utf-8', newline='') as merged_csv_file:
        fieldnames = ['Language'] + csv_files
        csv_writer = csv.DictWriter(merged_csv_file, fieldnames=fieldnames)
        csv_writer.writeheader()
        csv_writer.writerows(merged_list)

# Directory path where the CSV files are located
csv_directory = 'dataframes/translations/'

# Merge all CSV files into a single CSV file
merge_all_csv_files_in_directory(csv_directory)

print("Merged data saved to 'merged_translations.csv'")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [47], in <cell line: 55>()
#      52 csv_directory = 'dataframes/translations/'
#      54 # Merge all CSV files into a single CSV file
# ---> 55 merge_all_csv_files_in_directory(csv_directory)
#      57 print("Merged data saved to 'merged_translations.csv'")
#
# Input In [47], in merge_all_csv_files_in_directory(directory_path)
#      26 for row in csv_reader:
#      27     language = row['Language']
# ---> 28     title = row['Title']
#      29     if language not in merged_data:
#      30         merged_data[language] = {}
#
# KeyError: 'Title'

# %%
df = pd.read_csv('dataframes/translations/merged_translations.csv', encoding='utf-8')

# %%
df
# Out:
#                        english  spanish  german
# 0                Decimal point      NaN     NaN
# 1            Separador decimal      NaN     NaN
# 2          Dezimaltrennzeichen      NaN     NaN
# 3           Inversive geometry      NaN     NaN
# 4                          NaN      NaN     NaN
# ..                         ...      ...     ...
# 313        Límite (matemática)      NaN     NaN
# 314                        NaN      NaN     NaN
# 315  A priori and a posteriori      NaN     NaN
# 316    A priori y a posteriori      NaN     NaN
# 317                        NaN      NaN     NaN
#
# [318 rows x 3 columns]

# %%
import os
import csv
import pandas as pd

def merge_all_csv_files_in_directory(directory_path):
    """
    Merge all CSV files in a directory into a single CSV file.

    Args:
        directory_path (str): Path to the directory containing CSV files.

    Returns:
        pd.DataFrame: A DataFrame containing the merged data.
    """
    merged_data = {}
    languages = set()

    # List all files in the directory
    csv_files = [file for file in os.listdir(directory_path) if file.endswith('.csv')]

    # Iterate through CSV files and gather data
    for file_name in csv_files:
        file_path = os.path.join(directory_path, file_name)
        with open(file_path, mode='r', encoding='utf-8') as csv_file:
            csv_reader = csv.DictReader(csv_file)
            for row in csv_reader:
                language = row['Language']
                title = row['Title']
                if language not in merged_data:
                    merged_data[language] = {}
                merged_data[language][file_name] = title
                languages.add(language)

    # Create a list of dictionaries for the merged data
    merged_list = []
    for language in languages:
        merged_dict = {'Language': language}
        for file_name in csv_files:
            title = merged_data.get(language, {}).get(file_name, '')
            merged_dict[file_name] = title
        merged_list.append(merged_dict)

    # Create a merged CSV file
    merged_csv_path = os.path.join(directory_path, 'merged_translations.csv')
    with open(merged_csv_path, mode='w', encoding='utf-8', newline='') as merged_csv_file:
        fieldnames = ['Language'] + csv_files
        csv_writer = csv.DictWriter(merged_csv_file, fieldnames=fieldnames)
        csv_writer.writeheader()
        csv_writer.writerows(merged_list)

    # Create a DataFrame from the merged data
    merged_df = pd.DataFrame(merged_list)

    return merged_df

# Directory path where the CSV files are located
csv_directory = 'dataframes/translations/'

# Merge all CSV files into a single CSV file and save as a DataFrame
merged_dataframe = merge_all_csv_files_in_directory(csv_directory)
merged_dataframe.to_csv('merged_translations_dataframe.csv', index=False, encoding='utf-8')

print("Merged data saved to 'merged_translations.csv' and 'merged_translations_dataframe.csv'")
# Out:
# Merged data saved to 'merged_translations.csv' and 'merged_translations_dataframe.csv'

# %%
merged_dataframe
# Out:
#   Language Decimal point_translated.csv Inversive geometry_translated.csv  \
# 0       de          Dezimaltrennzeichen                               NaN
# 1       es            Separador decimal                               NaN
# 2       en                Decimal point                Inversive geometry
#
#   Synthetic geometry_translated.csv Limit of a function_translated.csv  \
# 0            Synthetische Geometrie               Grenzwert (Funktion)
# 1               Geometría sintética              Límite de una función
# 2                Synthetic geometry                Limit of a function
#
#   Logical truth_translated.csv Lie sphere geometry_translated.csv  \
# 0                          NaN                                NaN
# 1                Verdad lógica                                NaN
# 2                Logical truth                Lie sphere geometry
#
#   Reason_translated.csv Birational geometry_translated.csv  \
# 0              Vernunft             Birationale Äquivalenz
# 1                 Razón                                NaN
# 2                Reason                Birational geometry
#
#   Antinomy_translated.csv  ... Digital geometry_translated.csv  \
# 0               Antinomie  ...              Digitale Geometrie
# 1               Antinomia  ...               Geometría digital
# 2                Antinomy  ...                Digital geometry
#
#   Taxicab geometry_translated.csv Noncommutative geometry_translated.csv  \
# 0                Manhattan-Metrik             Nichtkommutative Geometrie
# 1           Geometría del taxista               Geometría no conmutativa
# 2                Taxicab geometry                Noncommutative geometry
#
#   Toric geometry_translated.csv Combinatorial geometry_translated.csv  \
# 0             Torische Varietät                                   NaN
# 1                           NaN                    Geometría discreta
# 2                Toric geometry                Combinatorial geometry
#
#   Distance geometry_translated.csv Syntax (logic)_translated.csv  \
# 0                              NaN                           NaN
# 1                              NaN                           NaN
# 2                Distance geometry                Syntax (logic)
#
#   (ε, δ)-definition of limit_translated.csv  \
# 0                      Grenzwert (Funktion)
# 1                     Límite de una función
# 2                (ε, δ)-definition of limit
#
#   Limit (mathematics)_translated.csv A priori and a posteriori_translated.csv
# 0                                NaN                                      NaN
# 1                Límite (matemática)                  A priori y a posteriori
# 2                Limit (mathematics)                A priori and a posteriori
#
# [3 rows x 107 columns]

# %%
df = merged_dataframe.reset_index(drop=True)

# %%
df
# Out:
#   Language Decimal point_translated.csv Inversive geometry_translated.csv  \
# 0       de          Dezimaltrennzeichen                               NaN
# 1       es            Separador decimal                               NaN
# 2       en                Decimal point                Inversive geometry
#
#   Synthetic geometry_translated.csv Limit of a function_translated.csv  \
# 0            Synthetische Geometrie               Grenzwert (Funktion)
# 1               Geometría sintética              Límite de una función
# 2                Synthetic geometry                Limit of a function
#
#   Logical truth_translated.csv Lie sphere geometry_translated.csv  \
# 0                          NaN                                NaN
# 1                Verdad lógica                                NaN
# 2                Logical truth                Lie sphere geometry
#
#   Reason_translated.csv Birational geometry_translated.csv  \
# 0              Vernunft             Birationale Äquivalenz
# 1                 Razón                                NaN
# 2                Reason                Birational geometry
#
#   Antinomy_translated.csv  ... Digital geometry_translated.csv  \
# 0               Antinomie  ...              Digitale Geometrie
# 1               Antinomia  ...               Geometría digital
# 2                Antinomy  ...                Digital geometry
#
#   Taxicab geometry_translated.csv Noncommutative geometry_translated.csv  \
# 0                Manhattan-Metrik             Nichtkommutative Geometrie
# 1           Geometría del taxista               Geometría no conmutativa
# 2                Taxicab geometry                Noncommutative geometry
#
#   Toric geometry_translated.csv Combinatorial geometry_translated.csv  \
# 0             Torische Varietät                                   NaN
# 1                           NaN                    Geometría discreta
# 2                Toric geometry                Combinatorial geometry
#
#   Distance geometry_translated.csv Syntax (logic)_translated.csv  \
# 0                              NaN                           NaN
# 1                              NaN                           NaN
# 2                Distance geometry                Syntax (logic)
#
#   (ε, δ)-definition of limit_translated.csv  \
# 0                      Grenzwert (Funktion)
# 1                     Límite de una función
# 2                (ε, δ)-definition of limit
#
#   Limit (mathematics)_translated.csv A priori and a posteriori_translated.csv
# 0                                NaN                                      NaN
# 1                Límite (matemática)                  A priori y a posteriori
# 2                Limit (mathematics)                A priori and a posteriori
#
# [3 rows x 107 columns]

# %%
df = df.replace('NaN', np.nan)

# Count NaN values in each column
nan_count = df.isna().sum()

# Filter columns with NaN values
columns_with_nan = nan_count[nan_count > 0]

print(columns_with_nan)
# Out:
# Inversive geometry_translated.csv                            2
# Logical truth_translated.csv                                 1
# Lie sphere geometry_translated.csv                           2
# Birational geometry_translated.csv                           1
# Inversive ring geometry_translated.csv                       2
# Parabolic geometry (differential geometry)_translated.csv    2
# Reference_translated.csv                                     1
# Logical form_translated.csv                                  1
# Strict conditional_translated.csv                            1
# Archimedes' use of infinitesimals_translated.csv             1
# Orders of approximation_translated.csv                       2
# Noncommutative algebraic geometry_translated.csv             2
# List of mathematical identities_translated.csv               2
# Discrete geometry_translated.csv                             1
# Symplectic geometry_translated.csv                           1
# One-sided limit_translated.csv                               2
# Meaning (linguistic)_translated.csv                          1
# Complex geometry_translated.csv                              2
# Analytic-synthetic distinction_translated.csv                1
# Arg (mathematics)_translated.csv                             1
# Meaning (non-linguistic)_translated.csv                      2
# Description_translated.csv                                   2
# Ruppeiner geometry_translated.csv                            2
# Epipolar geometry_translated.csv                             1
# Information geometry_translated.csv                          1
# Klein geometry_translated.csv                                2
# Semantics_translated.csv                                     1
# Conformal geometry_translated.csv                            2
# Elementary arithmetic_translated.csv                         1
# Presupposition_translated.csv                                1
# List of paradoxes_translated.csv                             1
# Contact geometry_translated.csv                              1
# Lists of mathematics topics_translated.csv                   2
# Systolic geometry_translated.csv                             1
# Ordered geometry_translated.csv                              1
# Enumerative geometry_translated.csv                          1
# Quantum geometry_translated.csv                              1
# Toric geometry_translated.csv                                1
# Combinatorial geometry_translated.csv                        1
# Distance geometry_translated.csv                             2
# Syntax (logic)_translated.csv                                2
# Limit (mathematics)_translated.csv                           1
# A priori and a posteriori_translated.csv                     1
# dtype: int64

# %%
df.shape
# Out:
# (3, 107)
